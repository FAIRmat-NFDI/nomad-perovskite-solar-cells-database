# %%
import asyncio
import getpass
import json
import os
from collections import Counter

import aiohttp
import requests

# %%
base_url = 'https://nomad-lab.eu/prod/v1/oasis/api/v1'

username = os.getenv('NOMAD_USERNAME') or input('Username: ')
password = os.getenv('NOMAD_PASSWORD') or getpass.getpass('Password: ')

response = requests.post(
    f'{base_url}/auth/token',
    data={'username': username, 'password': password},
)
token = response.json()['access_token']

# %%
semaphore = asyncio.Semaphore(5)  # Limit to 5 concurrent requests


async def fetch_page(session, url, json_body, headers):
    async with semaphore:
        async with session.post(url, json=json_body, headers=headers) as resp:
            return await resp.json()


async def fetch_entry_ids_paginated_semaphore(token, max_entries=70):
    url = f'{base_url}/entries/query'
    json_body = {
        'owner': 'visible',
        'pagination': {
            'page_size': 100,
        },
        'required': {'include': ['entry_id']},
        'query': {
            'and': [
                {'upload_id:any': ['C4ynD5c9RXesSXOJf6oq_Q']},
                {
                    'section_defs.definition_qualified_name:all': [
                        'perovskite_solar_cell_database.llm_extraction_schema.LLMExtractedPerovskiteSolarCell'
                    ]
                },
            ]
        },
    }
    headers = {'Authorization': f'Bearer {token}'}
    entry_ids = set()
    async with aiohttp.ClientSession() as session:
        while len(entry_ids) < max_entries:
            response_json = await fetch_page(session, url, json_body, headers)
            for data in response_json['data']:
                entry_ids.add(data['entry_id'])
            next_value = response_json.get('pagination', {}).get(
                'next_page_after_value'
            )
            if not next_value:
                break
            json_body['pagination']['page_after_value'] = next_value
    return list(entry_ids)


payload = {
    'required': {
        'data': {
            'layers': {
                'name': '*',
                'functionality': '*',
                'deposition': {
                    'method': '*',
                },
            }
        }
    }
}


async def fetch_entry(session, entry_id, token, retries=3, delay=2):
    async with semaphore:
        url = f'{base_url}/entries/{entry_id}/archive/query'
        headers = {'Authorization': f'Bearer {token}'}
        for attempt in range(retries):
            async with session.post(url, json=payload, headers=headers) as resp:
                if resp.status == 200:
                    return await resp.json()
                else:
                    text = await resp.text()
                    print(
                        f'Error {resp.status} for entry {entry_id} (attempt {attempt + 1}): {text}'
                    )
                    if resp.status in [429, 500, 502, 503, 504]:
                        await asyncio.sleep(delay * (attempt + 1))
                    else:
                        break
        return None


async def fetch_entry_data(entry_ids, token):
    layer_names = {
        'Substrate': [],
        'Absorber': [],
        'Contact': [],
        'Electron-transport': [],
        'Hole-transport': [],
        'Other': [],
        'Unknown': [],
    }
    deposition_methods = []
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_entry(session, eid, token) for eid in entry_ids]
        results = await asyncio.gather(*tasks)
        for response_json in results:
            if not response_json:
                continue
            layers = (
                response_json.get('data', {})
                .get('archive', {})
                .get('data', {})
                .get('layers', [])
            )
            for layer in layers:
                name = layer.get('name', 'Unknown')
                functionality = layer.get('functionality', 'Unknown')
                if functionality not in layer_names:
                    functionality = 'Other'
                deposition_methods.extend(
                    deposition.get('method', 'Unknown')
                    for deposition in layer.get('deposition', [])
                )
                layer_names[functionality].append(name)
    return layer_names, deposition_methods

# %%
entry_ids = await fetch_entry_ids_paginated_semaphore(token, max_entries=20000)
print(f'Fetched {len(entry_ids)} unique entry IDs.')
# Out:
# Fetched 11395 unique entry IDs.

# %%
layer_names, deposition_methods = await fetch_entry_data(entry_ids, token)
# Out:
# Error 503 for entry h5bQ8JkbK1KwOAm8uUzTKW6qdmfB (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry V0ivRmP2jC6JKhK2EoBjA1ueLclV (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 6UbsL2GAbmx3RPltzlN0SX_LV8Pe (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry QDx5DMAikmfeVSRqqKVFmf4m5pmF (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry fhkVTuuNu7O8KY9bu1nC4yBbkpbW (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry UD-j7qFJm8TssI3aJqYqtolv8uvk (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 6Mt_-mSLi79pfAQgX8XFYk_QPbiX (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry kwmmr052ziMU8SdJAxXbMqw58oQU (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry SPgDNV0L_frSkdxWp8JnqngDrg7L (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry h_mP5hr3A7g-OMyhmaa5Hf25-xI7 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry kAv5sJppUljZR8K-ND1xU7200XSi (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry PPCzb12O42ULLaH111V4wykQNthT (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 8I84P72dxE1DY39fwrXiLra_UUhp (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 4fUs6PZ3BYYhBpHupjMGdl_t11T8 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 5gGDQKhD-l2-CX_nyOBLKUgSy8EA (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry FdbOaHngihN0WDlmxSEXMyJYL1Y1 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry HXtCWf0Tf-ipDvOhxiF5Hwpc5OEt (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 5TR1QT-UlIkGDuf5HJ5eb1wVsWT3 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Kg2Gdc8PBfYNabxv62IoxbgoSnrN (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ZCR1tUBc-WjyL4TLuPDR_Cdq1-zF (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry TXfSZT5zo-_8nCa3Kl_DR6be_-Zg (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry wegT3hkWEpliKrfMyMbXsHhuPY65 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry IpITJD5PM40malcDBlPWcd_UT68- (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 98Q3nSIuDJk3iHAg04vdxjQL6pce (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry LWPcpS6mUfLkCvC0O0Ad5ctGNL-G (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry hx12fcS1d-dZTtvdGnmJjRNa5FRL (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry sBvwbSwR3RVPQr0WZyH2GBEnUK9z (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry rHKxTuAAPjfQ5_lmCp1Y7CQfNkJa (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry mP1ig42L8lo0TvtEzv7ChEdNXV6T (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry eKexGMuim5yVNqGFVYm5oooc0tem (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry v7mwSMdLgP8dSrk37RauBKjy5ZrV (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry W7ROvknjW3buAuDVtrZkAeg0fz6x (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry G7_60YaWUgixYpg5t9eYiK1vydv- (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry PULevb1HOscz7GsX83e1aULAlCcy (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry VS3P_UgP48kTz9kQc_texjdsd1jn (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry x8IzKLyyasgHOMAnj5r4aF8UhcEu (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry eg9U2KJY2B1orNaAOULrV2GB9CkS (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 6a0wZ93DbkLkj8uCyV5V3ZhIfxx0 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry wKOBYuwyOfXRS579XtvEullgeFRC (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Z9oUDrBk0jbUoBx1NI0Fd2D1WlT1 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry XX9uswSr0-wg4YM70SrAyKiUQxVM (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Fgkry9xUlNY_Mx2ZYWZKby-_ap08 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry -WeghxOAI1BJsiyr4oa9toiTl1jm (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry DD0zUT0Z2IxK9RoHC_GzJJc5BYS0 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry pI0c_dOKHtVdKMWpSvlDwoLhngyl (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry V3Adx_9G57_FglppnMYwd4UtnVFA (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry X1cP9NEXLD7wFzgi26nkMVjsD_AS (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry aJn1KXjM2N8hwqPI6XzVuAcpRpL6 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry UWebD9G3sWDXHdA7MhaJL3uMDF1c (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 5Cv2OA701BRHjjP1XW4vnQHJXRHI (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry UjVna6cOCHgoOLPepFJp3yuDRD3v (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry CYHZmMZ0T16j1kH78ygC0U1K8xGO (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry iOGo_x_Tg2MOL_Eh8au8qiPB5yPP (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 1bsQF43FL90hxr8civiY5JaWAuPY (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 1nVGkJtNsZ5n-bxAm_oCmpaq1kpH (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry SQQLJqrd9tdjPCqKKrUKuQXGMHKl (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry yxiaArPZJZHjY9GTpoTu6yE57yHl (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry QcdXiaNE7l3ukpRqAKDPa1-ZPkV6 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry iWvL6t45UNLfbCaNl9aDayAoRIxP (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 5a5X_27kuwksjGiUjfNNtWPwoxXp (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry zwR0GfysmQRq-7XLgEIFjEuxRWG4 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ucwAdOQpZpWIHIbqwUN1Y8GwSB_b (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Yus7vTLs4Dcd8NDMZkNVTidLoa57 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry fLYNJ3sUEq1qRPP7wA5KY_su36Hy (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry FOFKrg73k-7Hex0QqbGUsCfpxksM (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry e_EQUf4IUdeV9C7Qxh8NoJ0MJwOL (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry uf4_Ucb-v2m2nk5dASzBdWWT7WhU (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry mKIDQZx8LnDCkjI4K52XJu7rJKnD (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry kyYDzCNavo908lmuVKKXC-jM-h4y (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry dwdKzCcl0BWW8cIUgR1NIJwIaoKz (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry XWA9d-lUvyjcSUo0nXaxt0jckkbV (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Nu23ERXoAhfPrvQks_3m_zOTlcw6 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ALagApZmPgEMF9N1i8zxbzrHpc4F (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry oVscT9RYV0qrh4VQmQdmErmCTwmP (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry -XJ62sqKfJilmKuDOYdTGzKCHRrf (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry YC3z7rYRJv74UYW0I-ng-3zUh_E1 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry p4x7R9t4aF2tgSPLSH9cudka3tuf (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 8Q0E_N8SxMRUR6BUuNQEj7zmPKud (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry EUbwKZS5QMl1Ct1Z8T2NObVQiHm8 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 6pD0c7nV8jgOfXlh4jkFovIS7_x1 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry hKUnO3KIg1O92eVnVB9N53MqCIF8 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry DajP00UYPFfwPM4W7jSQn9SUO4KK (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry f0xDQllWpaxoSG83FIUL-56zYQZk (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry GWtdMY8uygFRXPlc5-FNYJCnzP31 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry yfP4KeNKcb6uWhHn4VXserVevwR_ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry r3pR-8UKNZNc72C7AsRz7ZD27yKg (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry dWotDhI7hZ_-QRhMQsDoKLOJrSG7 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 7IShLKY3Lzn-xtRB6vsTtydWax7I (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 4D1c_67AYBBkcqyTFsixfbOj-ho3 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry wBdLxdbLjpGMy77e6XJeo9T1xciu (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry u68EdsL5trxmw714FQ_l_FhIWylx (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry GC8rX05kMc5tgYlIY096_pVsESC9 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry v2dJ_YdxpE2-dzNbz1QU8j_e85E7 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 6pE4i8_cAc6QOYkYr8m8MBICR6WS (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 1h20C49QejdzXMKCc2fPfCGsfO9w (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry jTzFlNfb60EJ-PYzfeNT8FglATWW (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry tPJw1dV1PpoOKnIjlrBo2Oyl_pXQ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ce5Ijtx7lGtTBQMV-Dw6z7Y9tjrT (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry uD4nx2TSSedkuQzGLCXlnKKf9J_4 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry iwpqtblJi_O9O1ngSVAS0RZN4JVu (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry CUcux7_2S5UxwGwxqMTTVMtfQNFq (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ksqyBagdlldQXnmmgXUk_5hWIW6r (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 3C0P7e9pcy2Ugz7052xOZtfCx9tM (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry zHm9GZAdq49i48jJuuU7jiAhicVS (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry H9l-lSc6hSeXoSYx6l7wwYaYTRas (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry G4X1q4MXZYSs3rqentAABI6jMi3Z (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry mxUujka50KANGa8qP56l4PZgqghC (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry sM1zHxIGX6dKrXqOOo9_qua_t-Ue (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry iy9nAwfHSzkc2yvXNNnkwK5cTOz5 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry diBGqN8al8cTdkcHogiCfyRey13t (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry jG7tKvlDoSxBKz95sWCKXbVFW5Ru (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry jmH9m9iocYKV9xH4HZ6OJzKRWi3q (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry IvX3ZqoxvTPMlomBce07dbOBbcMe (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry cIgLClcJ8R3fhpzxsco6Evjo1MY- (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry qsvzZ-ORnU-JKQAUgFLIQNcbEZKh (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry dbhRJwF1LZMoxZLzax3YFGsPmEv4 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry bcOHpUt4k7si2lAsK4Re1KbTJzEK (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry f4esY-Gv1yV2mstJPI2mTt-pEnNh (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ek3oXTf1yVAlLEz7Fl3rDb4PT15L (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry U4k3uOhagfYEB4BMAoPsQW1MksMm (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry DgNVCwPvmuz6wxgK5kj9zU44KzZl (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry k_oa67kFPZWiDLyvWeDYmYlZl2fT (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry r1t63fAD78GFJzdbuWMwWXQ6YNll (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry t_SjPSlbi-TbsDyzY5KzHG1_ceE0 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 31XK8xZVPwsJ-OLQ4F-8cAwYBgdT (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry erF5ymkcLyhohtvPVNv0EUdSkNjk (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry pwXSz8SKCVSMBFhxwN7RuT2umWDW (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ZIbbes7LuyIHukUUSoZ5nkL_Gduo (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry _kD-CX7w3CXnnXVVZ5nv0KpSMvpo (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry vgeVA0Z199MRJITjDmdsAuFtjugQ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Sf2iLqrUcwOfZCcabzsWMvsumykf (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry pb6ijHuIF3R8xUqJNEFXsHRc48dN (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ZalS0qGWEvf-bfALiNvzN8Rb5qON (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Fb4j80Rbwu20YKEMwzbXniaKfGPl (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry FKY3Rs3KkGZmUFJ6FE7DtqBlhQ7J (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Fv9Z0mvxIEBxGycEgvKck07aJA4e (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry yZ27nJ2AKxXU0a3umwoBUFmb8rYI (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 0aGaFKgzmZW4tQWzL1LYkd_YJyNG (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry sBr13Ae4PTRGx93robwGTug3wGPr (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Z5evQUGgRhSL1WG80EurWz9PoN0L (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry BPKJWDuwM0BaAi_ma17OxC4BdsuZ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry fZvmyB7j0TPjYOg83dzbzyf5Bjyo (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry tqeR8eDhbQssaOWFgixOKl35HZO_ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Z2Teh-obGM1ts_-9IOVDiRGN-rUK (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry qhL5SLjN85gNsG4fLRuqtXj2Cz1n (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry udibQHAZm8JtaGiJTcASfPzWl6L8 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry pJJiV7Xo8-V35MD3wqiRsVgT_lmu (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 4Ug_Wx1dW9FG-QHVJnWXQGP0I7IS (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry V4qeKYzB7s7COf4ndGx0t0Am2ZFC (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 6pm2EwzT4iUp_TWa3sXsEtnsfsk2 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Ku_WZ9sR2oJeFnkShty8QIk9WRpu (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 1yUY-_b4HdXTUrlCmPh_UKanqm2M (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 0smuH7PqSO9MaryPq4UK3XB2CB6r (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry oYHA28Keg45Da7oYaROP2K4tZ4Kq (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry r1kJc74FjKETvXTO9wrVshTdprUG (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry kw-xAiB2AyulnJWu4QOuZYM4st4M (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry HZiqkccLy4jMVM-dnrpLs4pPyuF5 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry BnnrYopaKSWJiEqhfOwMVPP6zazF (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry QihI0GWP3pDOM1Kolnp62bK74brQ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry obK-Qk6J0SMjSWoWQ3bNWrYaURME (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry wdcDkVxE7K5I9933kSVms4g0TjQa (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry DqcQnI9RkIKsyuqT1nuVL5hB4cdV (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 7LW5gUdZIWDvvfhDIzuaMMvbWYFs (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 2ERQGSnznNlzgUOewv9hJpRVSpe2 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 9XLKQS5rEdANPQe9RwQK_xaxp9n6 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 0gDUZ4uaf7zaUjqSnS7ZCCAkNKJW (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry XlsN570yb0u0J4l-5xu3HK_uNNwj (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry hodt-R-qDt0C-JwzclJ9TGV3P2_G (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry geVW1AkgQeeZTYmmdyJ4YR9eM11v (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry pYs4wHXlHTHsI4kI-y2dfWe8_AJB (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 9AtKzIAvfsks7H4G0Hp7HsY77J1X (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry U7_q7CSDsIbAhtYw6OAiaWHwI2l3 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry _Qoik2wWkfO1HB06Rho1ObUyZmpW (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry dC6jzKiFzNMy1hHXnYPr4AKIjOZL (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 2K0XbkR2W_7erwuhVx1njMQReRSo (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 7BC5gi5Xlt7TtsnJ1hVonJzbpUGJ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 9p_e2cDHfa6rIASnYegwwShQM65g (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 5DYmRLolkzqyNMsNyENkNl2TjEaE (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry beZOOm04sEeRhu2vAPVLIUIWOSIq (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry t8v48ZyEQ3R-0hCjjzh4hua98bvE (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry fHaVAZG2ulnBp_9cfZGG1DyOlQIf (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry br94ZbKuGC4jU6p39XEMVgT42X14 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ZvKvjb-1Fo3-UfCyS7R2ybviM90q (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Vw0wSR-wp5mMfloqDHkBpgpyorB9 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry MyqX5Y5RfsxKZOtkNLkiiw4fd9j4 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ZkbZ1iPewAd99UzpaE9kJAAXeN8B (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry U36hzXlwxnvmY5P-yrqt_dKxzHV2 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry v0-laKO6q3tALx8wTZc7vSKKIyzD (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry qhv3hN3kK2EeCboS8xBE-If_8yGU (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Xc9JukF_aWUx1iLK6912bkncxvIB (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry Pb-OtOtAovsuvzisf2pDneMSEBU8 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry UcoZxXNHBdS5TOEBZgP0gi3zW6ZP (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry y5DpZ_YqyzlX16-hLF5ke-5jshzb (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry N_i5jzoqwjDgQ5-MAjBRcUdEQrxj (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry L3PeqKxO5GwZQ9U56mjnriMqMJFu (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# ...
# </html>
#
# Error 503 for entry PPSDvEPxc-inuZMJMQ9C73QndcI7 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry pimt9Cpr0uHINP591TYzamawHCF7 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry IFReXwhu2TeKcshqRtvDgTACyzf9 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry DhDDz3QW1RbSk7jcDTsaRW_cJvAD (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry qyrLgfai5NkB24bmZtoSIs6ovNTj (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry MwgYtLOv-b3KPj-1Z1zxtZSCC3Q4 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry YrpLNoAUmM1YpwempvRtUPXx9CQp (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry J881nTq_i-IO1cjssqCGS9SHZjJW (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ZcIQs31UVm3dCBJoWSmVsyxVxnsq (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry J3-xRFPP48bOMf1tRX68hpK9cKWY (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 0YUs9XGYVuNGsEJEHB57bZ86mGD4 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ndZxZQClxOyRFKl9hJ7D7UCU0Vtp (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 94NnFWsVd0YBg5hQfIKBHx_myY8O (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry D9e5Sjdw_ROcPZPgoO0luuiLL_rO (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry NeaSjVsRn5UE2OLJVqphFlOu9zYX (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry UaEioMBMNWoN40DjjwtacstSpXCG (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry X6LqDNSPHzziBT9eWxglXj4IoU-- (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry DBbKF2IiUlOwzAFY9TDnSF51SkXi (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry vPnq-YsvUoNoIvR7j6uuylj7Ob7d (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry mrpuaRu3_CgzGxY0clwnAkmUCD8C (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 15Sm1kxvVCnq4k3INRykDgcm-3sB (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry jOcYsQRo_8IJkqFm6x3ElCpZ9cYs (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry HsI8Fi0XCjL-AgtE_CaC6bx5NH89 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry _J9J-fzoAh5ylM5AJfAVV-IErCYr (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry sSdRTG50CATPHSEjzgpTpDd2Fb4L (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry joCCiLem97dUADDh97s3oiUh6HE6 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry j3tmujSDCMHSkQLKYTFlbWA30Ask (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry ofmpaOjW7DXcF2pPX5e022fAAHjf (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry uyB0R0zUQeE3ai5fMhppshwFiwmq (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry iUxbZxkDIcK3lIK7tM8Pqb4ol54H (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry lg6mHRhxAgsY8_IOTlTsPXCTWq9d (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 8Fsqv3f0cWFAGg-zKH8oc3WOnqoE (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry XDQcJcaVUb5mdEH0XjdxAB__r9jf (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry QsPYCfezgPcCKDsSGJDwfWq_Nsza (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry d5sRKEzcaHAAnxxW83llZsmbrhTs (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry UwZnFJp9-6KFENisSgdhDpO02reZ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry C_tTiTcpIKxnnWpNxNq0GyUQvC26 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 1iirAWYDS_l5E2YTSRd7-lwKfEm- (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry vT7_idggrYkdqSkEe856e4HUuhG7 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry -rDu_0Pb7Z7eFjsBJxfGlWo2dKNJ (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry MJbZYb6cVkhg82EKkdRNuWDP0Juv (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry vpSOnQv5t9m5uNQTMZrKakK8YJbI (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 1Ign8ux-zx7ObH6F4B80nookbVYK (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry IQh6OQLfng3vp32D2KMjqpliLzxK (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry DHwrpLwzPMwHu3HA6GkCd1FNqbCX (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 4mKbVMn9GZXe0FpFP3wqgWqlYczv (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry iXugGUGjZ3eCqjFj-5nEIbXG7S5U (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry yRdlJdbbW43YOPcSztz_XlzsLkfz (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry DsxT-ITnRzLcr8apNcbKdFWyw080 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry qVNFjQJP55KuuLZdlXMt4Br5-I97 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 9Aiwppk0RwaLeix189VeH52yuURA (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 5ySHXl4UT2qqAwr2KbE_31hRynD5 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 6BFwE36xcyQ2ariymFQ3g8VB9OSY (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry FfPhDHQRrmoDwrTidKto-Y3TdMsn (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry UdFYQOgDJvNlUA0ULwTU2GJkXh3H (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 9X2FD2cJmKirBqPLdeg1AF4wM9h0 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry GZX5k0nh8hQPGKvxaSAc9QJwbmHK (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry BsssdBfPP6ms6FmelwJ5Kd2m8yOi (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry t7RBT2PGY47f8pGyTwB-oIQZ4TSL (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry CGGDiiRpX7TXaVNxV9dklm_87XVK (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry TluONwlcMvZ01-zqcVPfs2tXr5Aq (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry fnK3K5LLrIr1xHPBpqGNq93Ds41T (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry 4aX4RGPtsfj2u-drAYf4NU8e9qK9 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry GONYlEFQWhHfI8O_Gyd-q_akjwdG (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
#
# Error 503 for entry -17OHetAAt4fnXeXAHPC5aTe4fI1 (attempt 1): <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>

# %%
unique_names = {}
for func, names in layer_names.items():
    name_counts = Counter(names)
    sorted_names = sorted(name_counts.items(), key=lambda x: x[1], reverse=True)
    print(f'{func} ({len(name_counts)}): {[name for name, _ in sorted_names]}')
    unique_names[func] = sorted_names
method_counts = Counter(deposition_methods)
sorted_methods = sorted(method_counts.items(), key=lambda x: x[1], reverse=True)
print(f'Deposition methods ({len(method_counts)}): {[m for m, _ in sorted_methods]}')
unique_names['Deposition methods'] = sorted_methods
# Out:
# Substrate (101): ['FTO', 'ITO', 'Glass', 'PET', 'PEN', 'PEN/ITO', 'PET/ITO', 'FTO glass', 'Glass/ITO', 'ITO/PET', 'ITO/PEN', 'Quartz', 'FTO/glass', 'IZO', 'PEN-ITO', 'ITO-glass', 'Glass/FTO', 'ITO-PET', 'PDMS', 'TCO', 'p-type silicon', 'ITO glass', 'MgF2/Glass', 'c-Si', 'Ti', 'FTO-30', 'FTO-70', 'Flexible substrate', 'glass', 'HPMC', 'Silicon', 'Kapton', 'FTO-50', 'FTO-glass', 'ITO-PEN', 'Parylene', 'Silicon heterojunction', 'PSi', 'Ni', 'PET-IZO', 'n-type silicon', 'TCO/glass', 'Al-foil', 'Sapphire', 'Stainless steel', 'ITO/glass', 'Cellophane paper', 'PI-SWNT', 'FTO-A', 'SiO2', 'SWNT-PI', 'NOA 63', 'PET:ITO', 'CFRP', 'ITP-coated Glass', 'FTO-HA', 'FTO-N', 'PI', 'PET/IMI', 'MgF2/PET/ITO', 'Cu foil', 'Polymer', 'Si', 'SiO2/Si', 'FTO Glass', 'SLG', 'Ti metal-coated glass', 'LiF/FTO', 'FTO substrate with Sm3+-Ce3+ co-doped glass-ceramic waveguides', 'Textured silicon', 'Graphene', 'n-Si', 'OPV8', 'sm-ITO', 'Willow glass', 'ITO-coated PEN', 'Silk-Ag nanowires', 'Carbon cloth', 'TLHA-coated glass', 'SiO2/PET/SiO2', 'MgF2/FTO', 'GaN', 'Transparent wood', 'PEN/Cu', 'uFTE with iSPM', 'Elastic fiber', 'FTO substrate with 4,7-diphenyl-1,10-phenanthroline coordinated Eu3+ complex', 'Silicon wafer', 'uFTE', 'FTO substrate with Eu(TTA)2(Phen)MAA DC layer', 'Ti foil', 'Steel yarn', 'PEN/ITO strip', 'p-type Cz silicon', 'p-Si', 'PET with nanograting', 'DS-TOPCon silicon subcell', 'PC', 'High-transparency FTO', 'n+Si', 'Si substrate']
# Absorber (3001): ['MAPbI3', 'FAPbI3', 'CH3NH3PbI3', 'FA0.85MA0.15PbI2.55Br0.45', 'CsPbI2Br', 'CsPbI3', 'Perovskite', 'CsPbBr3', 'FASnI3', '(FAPbI3)0.95(MAPbBr3)0.05', 'Cs0.05(FA0.85MA0.15)0.95Pb(I0.85Br0.15)3', 'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3', 'Cs2AgBiBr6', 'Cs0.05FA0.95PbI3', 'Cs0.05(MA0.17FA0.83)0.95Pb(I0.83Br0.17)3', 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3', '(FAPbI3)0.85(MAPbBr3)0.15', 'CH3NH3SnI3', 'CsPbIBr2', 'CsSnI3', 'MAPbI3-xClx', 'MASnI3', '(FAPbI3)0.97(MAPbBr3)0.03', 'Cs0.05(FA0.98MA0.02)0.95Pb(I0.98Br0.02)3', 'Cs0.1FA0.9PbI3', 'Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3', 'CH3NH3PbI3-xClx', 'FA0.95Cs0.05PbI3', 'Cs0.05(FA0.92MA0.08)0.95Pb(I0.92Br0.08)3', 'Cs0.05FA0.81MA0.14PbI2.55Br0.45', 'FAMAPbI3', 'CsFAMA', 'FA1-xMAxPbI3', 'FA0.9Cs0.1PbI3', 'FAPbI3 w/ MACl', 'Rb0.02(FA0.95Cs0.05)0.98PbI2.91Br0.03Cl0.06', 'CsFAMAPbIBr', 'CsPbI3-xBrx', 'Cs3Bi2I9', 'PEA0.15FA0.85SnI3', 'FA0.7MA0.3Pb0.5Sn0.5I3', 'FA0.92MA0.08PbI3', 'MAPbBr3', 'Cs0.17FA0.83Pb(I0.83Br0.17)3', 'CsSnBr3', 'FA0.85MA0.15PbI3', '(FASnI3)0.6(MAPbI3)0.4', 'BaZrS3', 'FAPbBr3', '(FAPbI3)0.992(MAPbBr3)0.008', 'FA0.85Cs0.15PbI3', 'Triple Cation', 'Cs2TiI6', 'Cs0.05(FA0.9MA0.1)0.95Pb(I0.9Br0.1)3', 'Cs0.05FA0.85MA0.1PbI3', 'CsBi3I10', '(MAPbI3)0.95(FAPbIBr2)0.05', 'Cs0.05MA0.05FA0.9PbI3', 'FA0.9Cs0.07MA0.03Pb(I0.92Br0.08)3', 'MAGeI3', 'FA0.75MA0.25SnI3', 'Cs0.15FA0.85PbI3', 'perovskite', 'FACsPbI3', 'Cs0.18FA0.82Pb(I0.8Br0.2)3', 'FA0.6MA0.4PbI3', 'CsGeI3', 'MA0.4FA0.6PbI3', 'CsPbI3 QDs', 'CsPbI3 Pe-CQDs', 'FA0.8Cs0.2PbI1.8Br1.2', 'CsFAPbI3', '(FAPbI3)0.99(MAPbBr3)0.01', 'Cs0.15FA0.85Pb(I0.98Br0.02)3', 'KGeCl3', 'FA0.9MA0.05Cs0.05PbI3', 'PVSK', 'Sb2S3', '(FA0.98MA0.02)0.95Cs0.05Pb(I0.95Br0.05)3', 'Cs2SnI6', 'FA0.85MA0.1Cs0.05PbI3', 'FA0.8Cs0.2Pb(I0.6Br0.4)3', 'FA0.95MA0.05PbI2.85Br0.15', 'Cs0.25FA0.75Pb(I0.85Br0.15)3', 'MA3Bi2I9', 'FA0.84MA0.11Cs0.05Pb(I0.987Br0.013)3', 'Cs0.05FA0.88MA0.07PbI3', 'Cs0.05FA0.81MA0.14Pb(Br0.15I0.85)3', 'RbGeI3', '(FAPbI3)0.875(MAPbBr3)0.075(CsPbI3)0.05(PbI2)0.03', '(FAPbI3)0.92(MAPbBr3)0.08', 'Cs0.17FA0.83PbI3', 'Cs0.05FA0.78MA0.17PbI2.53Br0.47', 'Cs0.07Rb0.03FA0.765MA0.135PbI2.55Br0.45', 'CsSn0.5Ge0.5I3', 'RbCsFAMA perovskite', '(FAPbI3)1-x(MAPbBr3)x', 'FAxMA1-xPbI3', 'Ca3NCl3', 'Cs0.05(FA0.77MA0.23)0.95Pb(I0.77Br0.23)3', 'FA0.95MA0.05Pb(I0.95Br0.05)3', 'Cs0.12FA0.88PbI3', 'Ag2BiI5', '(BDA)(MA)4Pb5I16', 'Cs0.05FA0.95PbI2.55Br0.45', 'Cs0.05MA0.1FA0.85PbI3', 'Cs0.2FA0.8Pb(I0.6Br0.4)3', '(CsPbI3)0.05(FAPbI3)0.95', 'FA0.85MA0.15Pb(I0.85Br0.15)3', '(FAPbI3)0.83(MAPbBr3)0.17', 'Cs2BiAgI6', 'Cs2PtI6', '(5-AVA)x(MA)1-xPbI3', 'FA0.8Cs0.2Sn0.5Pb0.5I3', 'FAPbI3-xBrx', 'CsPbI2.85Br0.15', 'Cs2AgSbBr6', 'CsFAMAPbI3', 'BA2MA3Pb4I13', '(CH3NH3)2CuCl0.5Br3.5', 'Cs0.05(MA0.1FA0.9)0.95Pb(I0.9Br0.1)3', '(BA)2(MA)4Pb5I16', 'BiFeO3', 'FA0.9MA0.1Pb(Br0.1I0.9)3', 'FA0.945MA0.025Cs0.03Pb(I0.975Br0.025)3', 'PEA0.13FA0.87SnI3', 'PM6:Y6', 'FA0.5MA0.5PbI3', 'FA0.85PEA0.15SnI3', 'Cs0.1FA0.9PbI2Br', 'FA0.7MA0.3Sn0.5Pb0.5I3', 'MAPb(I0.9Cl0.1)3', 'FA0.3MA0.7PbI3', 'MAPbI3(n)', 'MAPbI3(p)', 'MA0.7FA0.3PbI3', 'Triple-cation perovskite', 'Cs2CuBiCl6', 'Cs0.05(MA0.15FA0.85)0.95Pb(I0.85Br0.15)3', 'MA0.6FA0.4PbI2.9Br0.1', 'Cs2AgInBr6', 'Cs0.05FA0.85MA0.10Pb(I0.88Br0.04Cl0.08)3', 'FA0.9MA0.03Cs0.07PbBr0.24I2.76', '(Cs0.05FA0.75MA0.20)Pb(I0.96Br0.04)3', 'FA0.85MA0.1Cs0.05Pb(I0.97Br0.03)3', 'FA0.90MA0.05Cs0.05PbI2.85Br0.15', 'Cs0.05(FA0.9MA0.1)0.95Pb(Br0.1I0.9)3', '(CsPbI3)0.04(FAPbI3)0.93(MAPbBr3)0.04', 'PbS/CdS/ZnS', '(BA)2PbI4', 'Cs0.05FA0.8MA0.15Pb(I0.75Br0.25)3', 'Rb0.05Cs0.05MA0.05FA0.85Pb(I0.95Br0.05)3', 'FA0.15MA0.85PbI3', 'Cs0.05(FA0.87MA0.13)0.95Pb(I0.87Br0.13)3', 'MAxFA1-xPbI3', '(FA0.83MA0.17)0.95Cs0.05PbI2.5Br0.5', 'FA0.95-xMAxCs0.05PbI3', 'CuBiS2', 'MAxCs1-xPbI3', 'FA0.88Cs0.12PbI2.64Br0.36', '(FAPbI3)x(MAPbI3)y', 'PEA2MA3Pb4I13', 'Cs0.1FA0.9PbI3 w/ 4-TFTBA', 'MAPbI3 w/ PEAI', 'Cs0.15FA0.85Pb(I0.92Br0.08)3', 'Triple cation perovskite', 'P3HT:PC61BM', 'P3HT:PCBM', 'FA0.6MA0.3Cs0.1Pb0.5Sn0.5I3', 'FA0.1MA0.9PbI3', 'CsxFA1-xPbI3-yBry', 'Cs0.06FA0.78MA0.16Pb(I0. ...
# Contact (239): ['Au', 'Ag', 'ITO', 'Carbon', 'Cu', 'MoO3', 'Al', 'FTO', 'Ni', 'MoOx', 'IZO', 'LiF', 'C', 'Pt', 'Cr', 'carbon', 'Carbon paste', 'Ta-WOx', 'Silver', 'TCO', 'IO:H', 'AgNWs', 'Carbon electrode', 'Ti wire', 'Back contact', 'Graphite', 'AZO', 'C-rCP', 'Mo', 'Gold', 'Cathode', 'Anode', 'Au/Ag', 'Ag-grid', 'Silver paste', 'Cu2S', 'rGO', 'Metal', 'Se', 'SWCNT@85%', 'Pd', 'TCE', 'Graphene', 'H2PtCl6', 'TETA-Gr', 'ZrAcac', 'Au:Pd', 'Ag grid', 'WO3', 'Ta4C3F2', 'Ti4N3', 'mp-Carbon', 'VOx', 'BCP', 'RGO', 'ITO/Au gold finger', 'Platinum', 'nanocarbon', 'NiO/Ag/NiO', 'Carbon mesoporous', 'C-G', 'AgAl', 'Carbon black electrode', 'ALD ITO', 'Ag/Au', 'SWCNT', 'Pt coated FTO', 'CNT sheet', 'LIG@NiOX', 'AgNW', 'DMD', 'Back electrode', 'Copper', 'Metal electrode', 'DWNT', 'ICO:H', 'W', 'MoOx/Au/MoOx', 'Ca', 'Carbon/conductive cloth', 'm-Carbon', 'F-CE', 'm-carbon electrode', 'WO3/Ag/WO3', 'Gr/CB', 'PEDOT:F', 'Carbon w/ 30 wt% Mn3O4', 'TiO2/ultrathin Ag/TiO2', 'Ag paste', 'CNTs', 'CNT', 'Cu2S/brass', 'silver', 'PEDOT', 'Front electrode', 'Cu wire', 'Au-mesh/PEDOT:PSS', 'graphene', 'Ag/MoO3', 'ITO-r', 'porous carbon', 'IZTO', 'Ag NWs', 'MoOx/Al', 'IZVO', 'PEI', 'Carbon w/ o-xylene', 'Ag-mesh/PH1000', 'In:SnO2', 'HAT-CN', 'Mg/Ag', 'Ti1-rGO', 'Boron-doped graphite-based carbon', 'Cu-Ni/graphene composite', 'PH1000:Ag NWs', 'Co1/CN', 'CNF', 'm-SWCNTs', 'carbon framework', 'Rhodamine-Ag-MoO3', 'PDMS/Ag grids', 'AgNWs/TiO2', 'Silver grid', 'Carbon w/ OAI', 'BCP:Ag', 'AgNWs/graphene', 'Graphite-based carbon', 'orthogonal AgNWs', 'a-ITO', 'PH1000', 'PEDOT:PSS', 'Bathocuproine', 'CN', 'Carbon + CNTs + Ti3C2-MXene', 'CB', 'Carbon electrode w/ BAI', 'IOH', 'Ag/MgF2/Ag micro-cavity cathode', 'Pt-FTO', 'AZO/Cu/Ag/AZO', 'Carbon w/ 5 wt% waste toner carbon', 'Carbon with SWCNTs', 'Ca/Al', 'Ti', 'MOM (20/75/30)', 'ffBT-F3N', 'HC-PEDOT', 'TWCNT w/ L-PTAA', 'SnOX/ZTO', 'Cr2O3/Cr', 'MoO3/Au/Ag/MoO3', 'Carbon electrode w/ DDAI', 'MOM (25/75/25)', 'Ni foil', 'DPP-PhN', 'MoO3/Ag/Cu/MoO3', 'CNW', 'Au grids/PH1000', 'ZnO-Al', 'Ti1/CB', 'm-CNF', 'Graphite/CB', 'Carbon with CuPc', 'In:ZnO', 'B0.5%-CP', 'CB+Graphite', 'GO', 'IAI', 'TiN+Graphite', 'Bi', 'TWCNT', 'M0.1%-CP', 'graphene aerogel/Au', 'MC/Ti', 'Carbon w/ NiO', 'MoOx/ITO/Ag/ITO', 'AuCl3-doped monolayer graphene', 'Carbon w/ 17 wt% waste toner carbon', 'MOM (30/75/20)', 'GS', 'Ti/Au', 'LIG', 'ITO bilayer', 'PbZrO3', 'CP', 'PoA-PbZrO3', 'VO@CNF', 'Gold contact', 'VS4@CNF', 'Commercial Carbon', 'PNMPy-PoA-PbZrO3', 'NC', 'B0.1%-CP', 'Carbon w/ 23 wt% waste toner carbon', 'Liq', 'Textured front contact with nanoholes', 'Au buffer layer', 'GCEP', 'Pt-Ti foil', 'SA:c-ITO', 'CQDs', 'MoO3/Au/Cu/MoO3', 'Carbon w/ IPA', 'Au electrode with embedded NaYF4:Yb3+,Er3+ UCNPs', 'MoOx/ITO', 'Carbon Control', 'n++/p++ tunnel junction', 'Ag nanowires', 'N-Ti3C2@carbon', 'Sb', 'FTO-Glass', 'M0.5%-CP', 'Pearl carbon', 'Carbon electrode w/ OAI', 'AgNW:Ti3C2Tx', 'Carbon electrode w/ HDAI', 'NiO/Ag/NiO transparent electrode with UC layer', 'rGO/AgNWs/rGO', 'Carbon w/ 10 wt% waste toner carbon', 'MoOX', 'Ag yarn', 'DPP-F3N', 'MXene-V3C2F2', 'PNMPy-PbZrO3', 'Fe', 'Expanded graphite', 'Cr/Au', 'm-BCNF', 'Commercial Carbon w/ NiO', 'Ti3C2Tx', 'Ag fingers', 'Carbon w/ CB', 'BMG ITO', 'Carbon electrode w/ DAI', 'Pearl carbon w/ CAISSe NPs', 'TWCNT w/ H-PTAA', 'Ag front contact', 'Ti/Ag back contact', 'ITO/Au fingers']
# Electron-transport (811): ['SnO2', 'TiO2', 'C60', 'PCBM', 'c-TiO2', 'BCP', 'PC61BM', 'm-TiO2', 'mp-TiO2', 'ZnO', 'ICBA', 'CdS', 'TiO2 mesoporous', 'SnOx', 'PC60BM', 'bl-TiO2', 'mesoporous TiO2', 'WS2', 'SnS2', 'ZnSe', 'Compact TiO2', 'TPBi', 'compact-TiO2', 'SnO2 QD', 'AZO', 'IGZO', 'ZnO NPs', 'Mesoporous TiO2', 'mesoporous-TiO2', 'TiO2-NPs', 'In2S3', 'ZnOS', 'C60-ETPA', 'cp-TiO2', 'C-TiO2', 'ZnO nanorods', 'Bphen', 'meso-TiO2', 'PC71BM', 'PFN-Br', 'ALD-SnO2', 'ETL', 'c-SnO2', 'compact TiO2', 'TiO2 nanorods', 'WO3', 'LiF', 'SnO2-KBr', 'PEI', 'PC61BM + C60', 'SnO2 QDs', 'TiOx', 'GO', 'SnO2-SnOx', 'b-TiO2', 'bathocuproine', 'CeO2', 'Mesoscopic TiO2', 'C60-SAM', 'ZnS', 'F8', 'PC61BM-C60', 'CdZnS', 'compacted TiO2', 'ZnMgO', 'SnO2-Cl', 'SnO2 NP', 'mp TiO2', 'LBSO', 'ZnO NP', 'SnO2 w/ urea', 'RbF-SnO2', 'NDP', 'TiO2/ZnO', 'Fe2O3', 'SnO2 NPs', 'TiO2 compact', 'CPTA', 'Li-TiO2', 'n-CsGeI3', 'Cd0.5Zn0.5S', 'i-ZnO', 'Bathocuproine', 'Meo-2PACz', 'ZnO@TiO2 NAs', 'PC61BM + TBABF4', 'AT-TiO2 NPs', 'Au/SnO2', 'TiO2 w/ AlCl3', 'SnO2-PbO', 'ZnO@ZnSe NAs', 'PCBM@DCBP', 'PDI', 'TiO2 paste', 'PC70BM w/ N-DMBI', 'SnO2-TiOxCl4-2x', 'BF4-SnO2', 'Li-treated c-TiO2', 'AH-SnO2', '2,9-dimethyl-4,7-diphenyl-1,10 phenanthroline', 'PbTiO3/TiO2', 'cTiO2', 'PCBM:EVA', 'TiO2 NRs', 'PY-DFT', 'PAA-EA-SnO2', 'SrSnO3', 'IZGO', 'PCBM:C60', 'SnO2-MXene', 'PC61BM:C60', 'C60MC12', 'Zn0.75Mg0.25O', 'SnO2 w/ GLDA and βA', 'OC', 'S,N-CQDs-SnO2', 'SnO2 w/ RbF', 'PCBM w/ TMDS', 'SnO2 w/ IGQDs', 'PCBM@TPP', 'PDIN', 'NDI-C4F', 'SnO2:PEIE', 'PCBM:PMMA', 'fullerene', 'TiO2 nanowires', 'ms-TiO2', 'SnO2-NiCl2', 'PCBM w/ DMAPF and N-DMBI', 'TAc-SnO2', 'TiO2:Al2O3', 'SnO2 w/ AC', 'M13-SnO2', 'Al-SnO2', 'SnO2-FACl', 'doped C60', 'SnCl2', 'SnO2/TMPU', '2PACz', 'ITO', 'Cl-SubPcF6', 'SnO2/PCBM', 'm-TiO2 w/ PCBM', 'CeOX', 'Ti2O3:Nb', 'SnO2-TiO2', 'SnO2/EGT', 'SnO2 w/ 3-AS', 'PM6:Y6:PC61BM', 'TiO2 w/ CDA', 'Y-doped TiO2', 'TiO2 compact layer', 'SnO2 w/ BEPBF4', 'Ti_Oxd', 'Li-doped mesoporous-TiO2', 'G-SnO2', 'α-Fe2O3', 'SnO2/NdCl3', 'PCBM+PMMA', 'SrTiO3', 'np-SnO2', 'PDADI', 'ITO/SnO2', 'MoS2', 'SnO2-DAC-AA', 'TiS2', 'SnO2/m-TiO2', 'Sb2O5@SnO2', 'SnO2:BPQDs', 'SnO2-STRS', 'SnO2 w/ GADET', 'SnO2 w/ LiF', 'PCBM:DTPTCY', 'TiO2 NRs w/ TCA', 'HATIC', 'AA-TiO2', 'SnO2:C-EDTA', 'BK TiO2 NPs', 'SAM', 'ZnO NPs w/ PVA', 'Bis-PC', 'Nb:TiO2', 'SnO2-x', 'ChCl-SnO2', 'Zn(O0.3,S0.7)', 'Sb-ZnO', 'S-PASP:SnO2', 'PANDI', 'SnO2 w/ MDACl2', 'FI-SnO2', 'Ti0.936O2@TiO2', 'FR-TiO2', 'SnO2-LHHM', 'TiO2:MXene', 'r-SnOx', 'PNDIT-F3N', 'BK TiO2 NPs w/ CsI', 'ZnTiO3-ZnS', 'PC70BM', 'a-Si:H (i/n)', 'hTiO2', 'mTiO2', 'SnO2-Li2CO3', 'SnO2@ZnO', 'V-doped ZnO', 'CeOx', 'ho-TiO2', 'SnO2+Gd', 'SnO2 w/ PAAm', 'SnO2-BCA', 'SnO2 w/ KMsO', 'QD-SnO2', 'Y6', 'C-SnO2', 'TiO2 nanowire arrays', 'ZTO', 'NP-SnO2', 'ALD-SnOx', 'PCBM:N2200', 'SnO2-Nb2C', 'PC61BM:BCP', 'SnS2/SnS', 'SnO2-KCl', 'Ti3C2Tx', 'CBD-SnO2', 'SnO2 w/ HCOONH4', 'TiO2-Li2CO3', 'BaTiO3', 'TiO2/Mg-SnO2', 'SnO2-PEIE', 'PCBM/MnSO4', 'CPTA-passivated SnO2', 'SnO2 w/ PASP', 'PFN-Br2', 'SnO2 w/ LiOTf', 'SnO2 w/ NHS', 'CN-TPACl', 'Sb2Ox', 'SnO2 w/ NCS', 'SnO2-poly(DAC-AA)', 'CPAN', 'PC-SnO2', 'SnO2-MH', 'SnO2 w/ CsPbBr3 nanocrystals', 'ZTO-ICN', 'MZO', 'SnO2/KF', 'SnO2 w/ BA', 'SnO2-NRs/Cl-BSM', 'Y-CE', 'TiON', 'Acac-TiO2 NPs', 'STO', 'TiO2-Cl', 'CSCO', 'c-TiO2/m-TiO2', 'Cr2O3/SnO2', 'MXene/CoS-SnO2', 'SnO2-GL', 'TiO2-SDBA-SnO2', 'FADD:ZnO', 'TiO2 NPs', 'SnO2 w/ PCC', 'Al2O3-graphene', 'SnO2 w/ KSCN-PEO', 'SnO2-TBHCl', 'TiO2/SnO2', 'H-SnO2', 'PCBM + C60', 'ZnO-ZnS', 'PDA: SnO2', 'F-TiOx-SnO2', 'Graded-TiO2:N', 'SnO2@ZnO.PANI 4%', 'BPQDs', 'ZnONPs', 'ZnO@ZnS core-shell nanorods', 'SnO2 w/ g-C3N5', 'CuO@PANI (1:1)', 'ALD SnOx', 'graphene-incorporating m-TiO2', 'SnO2 w/ ELAA', 'SnO2-HCl', 'SnO2/KBr', 'TiO2 NFs', 'SnO2 w/ KF', 'Er-TiO2', 'SnO2 w/ GQDs', 'TiO2-Cou', 'TiO2:5%Er3+, 5%Yb3+ + TiO2 + TiO2:1%Er3+, 3%Yb3+', 'Sn(S0.92Se0.08)2', 'SnO2 QDs-TQDs', 'TiO2 CL', 'AT TiO2 NPs', 'SnO2-PA', 'c&m-TiO2', 'SnO2-SA', 'TiOX', 'SnO2-BD', 'NDI-B:SnO2', 'PCBM+C60', 'SnO2-RbCl', 'OA ...
# Hole-transport (1080): ['Spiro-OMeTAD', 'spiro-OMeTAD', 'NiOx', 'PTAA', 'PEDOT:PSS', 'Spiro-MeOTAD', 'MeO-2PACz', 'P3HT', 'NiO', 'Me-4PACz', 'CuSCN', 'Cu2O', '2PACz', 'CuI', 'spiro-MeOTAD', 'SAM', 'MeO-4PACz', 'NiOX', 'MoO3', 'P3CT-N', 'CBTS', 'HTL', '4PADCB', 'CuInS2', 'TaTm', 'PDCBT', 'SpiroOMeTAD', 'CuPc', 'CFTS', 'CuO', 'PEDOT', 'CdTe', 'PTAA:F4-TCNQ', 'Cu:NiOx', 'V2O5', 'Carbon', 'CZTS', 'Spiro-TTB', 'CuSbS2', 'PTB7', 'PBDB-T', 'GO', 'CuOx', 'poly-TPD', 'CuAlO2', 'PolyTPD', 'SAMs', 'CbzNaph', 'Me-4PAcz', 'Spiro-OMETAD', 'Spiro-OmeTAD', 'MoOx', 'Me4PACz', 'Spiro', 'MASnBr3', 'PTAA:F4TCNQ', 'TFB', 'Spiro-OMeOTAD', 'VNPB', 'cp-NiOx', 'LaNiO3', 'CZTSe', 'PANI-PAMPSA', 'MoS2', 'MPA-CPA', 'MoTe2', '4PACz', 'MeO-2PACz:Me-4PACz', 'Ph-4PACz', 'Cu:NiOX', 'TAPC', 'PTA', 'PM6', 'BDT-C8-3O', 'rGO', 'PVA + F-127 + KI + I2', 'A-PEDOT:PSS', 'poly(triarylamine)', 'NiOx:Sr', 'CuCrO2', 'NiO NPs', 'SAM (2PACz and Me-4PACz)', '2PACZ', 'spiroOMeTAD', 'D18-Cl', 'Spiro-OMeTAD w/ TCPO', 'p-CsGeI3', 'VB-FNPD', 'EMIC-PEDOT:PSS', 'PTB7-Th', 'NiOx@VNPB', 'SAB', 'Cu2ZnSnS4', 'PTAA:Ce3+', 'PTPD', 'MeO-2PACZ', 'PEDOT:PSS w/ PM6', 'FTPE-OSMe', 'PbS-EDT', 'ZnTe', 'Spiro-OMeTAD w/ Co(III)TFSI', 'PCBM', 'Eu:NiOx', 'I-/I3- electrolyte', 'P3CT-Cs', 'D-PBTTT-14', 'spiro-OMeTAD w/ Mn complex', 'Mg-CuCrO2', 'Spiro-OMeTAD w/ C@NiO', 'Bz-PhpPACz', 'PTAA-P1', 'TTPA-mF', 'Cl-2PACz', 'TTPA-iF', 'CuSeCN', 'CuScO2', 'P1', 'Spiro-OMeTAD w/ C8A', 'TPA-NiOx', 'polyTPD', 'Spiro-OMeTAD:PTAA', 'Poly-TPD', 'Ph-2PACz', 'MeO-2PACz SAM', 'MeO-2PACz:2PACz', 'PFI', 'CbzNaphPPA', '2PACz-3-UA', 'DC-TMPS', 'I-2PACz', 'CPDA 1', 'H101', 'SMe-TPA-CuPc', 'NiO@SAM', 'spiro-OMeTAD w/ SnSO', 'BTP1', 'MB-NiO', '2FMPA-BT-BA', 'BCzSPA', 'DFBT-PMTP', 'NiOx w/ CsI', 'Cs2SnI6', 'spiroMeOTAD', 'PEDOT/PSS', 'SpiroMeOTAD', 'PEDOT:PSS-N0.12GO', 'HTM', 'Carbon electrode from waste tires', 'PCPDTBT', 'Me-4PACz/AG', 'NiOx w/ KBr', 'PEDOT:PSS w/ CEPA', 'PTAA-BCF', 'NiOx w/ [EMIM]PF6', 'hc-PEDOT:PSS', 'PEDOT:PSS w/ CG', '4PACDF', 'CuS', 'Spiro-OMeTAD w/ Li-TFSI', 'Li-P3HT', 'MAP-CPA', 'CbzBT', 'P3HT-COOH', 'compact NiO', 'PTPY', 'MeO-2PACz w/ MXene', 'c-NiOx', 'PEDOT:PSS PH 1000 w/ OPC', '79', 'Ni/NiOx', 'Spiro-OMeTAD w/ TA', 'Mx-SAM', 'SBF-FC with TBPHTFSI', 'PEDOT:PSS w/ D-glucamine', 'Sb2S3', 'PFNBr', 'Mixed SAM (MeO-2PACz:Me-4PACz 3:1)', 'FTPE-ST', 'NiCo2O4', 'Spin-NiOx', 'NP-NiOx', 'B-20', 'Cu2GeS3', 'MeO-BTBT', 'Spiro-OMeTAD w/ GADET', 'LaFeO3@C/C', 'MeO-PhPACz', 'PVK', 'Meo-2PACz', 'SWPC-PEDOT:PSS', 'spiro-TTB', 'Mixed SAM', 'X60', 'NY-04', 'CuInS2 QDs', 'NiOx@Me-2PACz', 'PTZ-CPA', 'FeS2', 'P3HT w/ 4-ABA', 'P3HT:5CB', 'spiro-OMeTAD w/ O2- doping', 'PEDN', 'BTDC', 'optNiOx', 'spiro-OMeTAD w/ TA', 'CI-TTIN-2F', 'PH1000', 'NiO:Cu', 'Mg:CoOx', 'P3HT/c-MWCNT', 'Al2CdSe4', 'DMAcPA', 'NiOBu-MeAMD', 'Al:NiOBu-MeAMD', 'PTAA w/ PFN-Br', 'spiro-OMeTAD/BQX-2', 'PF', 'PFBTI', 'MD', 'DTTP-ThSO', 'spiro-OMETAD', 'CMTS', 'p-DM', 'P3HT 338 kDa/76%', 'MPA-Ph-CA', 'spiro-OMeTAD/BQX-1', 'IDIDF2', 'SF71', 'Spiro-OMeTAD w/ Tp-Azo-COF', 'APTES/TFSA-doped graphene', 'Spiro-OMeTAD w/ LiTFSI and t-BP', 'CuGaO2', 'T2', 'CuInSe2', 'Zn-BL54', 'NiPc', 'NCz-DM', 'DC-PA', 'phthalocyanine derivative', 'NY-03', 'HL38', 'P3HT-PTAA', 'p-BM', 'P3BT', 'IDIDF', 'TEA-NiOx', '2-layered graphene', 'CZTSSe', 'YJS003', 'BD', 'Mg:CuCrO2', 'PPTZ', 'PTAA w/ Al2O3', 'graphene/MoO3', 'spiro-OSMeTAD', 'WBH-P3HT', 'LiTSO', 'CzAn', 'MnS', 'CIS', 'NiOx/Trp', 'DM', 'WH01', 'FTPE-OMe', 'Br-2EPSe', 'CuxO', 'PEDOT:Cx', 'P2', 'Nap-SiBTA', 'SWCNTs', 'CB', 'CbzPPA', 'CNTS', 'SFX-MeOTAD', 'MeO-2PACz/Me-4PACz', 'PPE2', '82', 'Water-free PEDOT', 'MePA-CPA', 'NiOx:Cu', 'PE10', 'Organic electrolyte', 'M:CCO', 'TaTm/PEDOT', 'NiO w/ Ala', 'HTL with 0.1 wt% Li(Gd/Y)F4:Yb/Er UCNPs', 'spiro-mCl', 'n-NiOx', 'JY6', 'WO3', 'spiro-OMeTAD w/ LiTFSI', 'XF3', '83', 'p-O5H-E-POZ-E', 'a-BTC', 'NY-02', 'a-BTBC', 'PEDOT-PSS', 'PDBD-T', 'Br-2EPT', 'HYC-oF', 'YJS001', 'NiOx NPs', 'SL22', 'SpiroPT', 'ISC-HTL', 'Py-DB', 'CzCOPXZ:PTAA', 'PTAA:LiTFSI:tBP', 'Mixed SAM (tBu-4PACz:MeO-2 ...
# Other (710): ['BCP', 'PEAI', 'Al2O3', 'ZrO2', 'LiF', 'PEABr', 'MgF2', 'mp-ZrO2', 'OAI', 'SAM', 'Me-4PACz', 'KCl', 'MeO-2PACz', '2D perovskite', 'PEI', 'm-ZrO2', 'PMMA', 'PFN-Br', 'PCBA', 'MeO-PEAI', '2PACz', 'MoOx', 'PbI2', 'PDAI2', 'PEACl', 'Bphen', 'PMMA:PCBM', 'OAmI', 'TEACl', 'EDAI2', 'MoS2', 'PI', 'Glass', 'BABr', 'SAMs', 'Rhodamine', 'Graphene', 'Zr(acac)4', 'WS2', 'MoOX', 'IDL2', 'IDL1', 'SiO2', 'choline chloride', 'BAI', 'N719', 'rhodamine', 'TPBi', 'FcTc2', 'MoO3', 'CsBr', '2,9-dimethyl-4,7-diphenyl-1,10-phenanthroline', 'BPhen', 'PEIE', 'BDAI2', 'OABr', 'Iodolyte AN-50', 'n-BAI', 'mp-Al2O3', 'bathocuproine', 'CEAI', 'm-FPEAI', 'MeO-4PACz', '4-MeO-PEAI', 'CHMAI', 'PCBM', 'SnO2', 'Ti(IV) bis(acetoacetate)-diisopropoxide', 'benzamidine hydrochloride', 'PANI', 'Passivation Layer', 'ZrAcac', 'WSe2', '4PADCB', 'HEC', 'PFN-P2', '2D perovskite layer', 'TiOx', 'KF', 'F4-TCNQ', 'SnOx', 'F-PEAI', 'Rhodamine 101 inner salt', 'RhB', 'PFNBr', 'KI', '3-APy', 'cyclohexylammonium iodide', 'CsPbI3 PeQDs', 'GQDs', 'SiO2-NPs', 'HUBLA', 'oFPEAI', 'DTAQTPPO', 'Rhodamine-101', 'oF-PETA', 'EAI', 'PTAI', 'MeO-PEAI-VD2', 'passivation layer', 'VNPB', 'CsPbI3 QDs', 'EDADI', 'DPPS', '4F-BHZ', 'EVA', 'PTMAI', 'Allicin', 'BHC', 'PC61BM', 'Cs3MnBr5:Ce3+ NCs', 'N719 dye', 'Zr(Acac)4', 'ZrO2 mesoporous', 'C60', 'CdS', 'DTPT', 'PTPA2PbI4', 'CsI', 'PEA2PbI4', 'TmPyPB', 'Sb2Se3', 'ZnS', 'CBP', 'Su-8', 'MnSO4', 'rhodamine-101', 'APC', 'BDA-EDAI2', 'CrOx', '2PACz/MeO-2PACz mixture', 'TOASiW12', 'MXene:H3pp', 'MePEACl', '2D perovskite capping layer', 'CeO2', 'DAB', 'D-2P', 'HADI', '4MeO-PEAI', 'MeOPEAI', 'ARPSS-Pb', 'L-Asp', 'BzMIMBr', 'porphyrin', 'KBr', 'Me-4PACz-PM', 'NiOx', 'PTABr', 'rGO', 'SCC', 'TPU', 'COFICZ+Al2O3', 'CsCl', 'PDIN-S', '4-ADPA', 'P3HT-NW', 'CBz-PAI', '4F2M-BACl', 'PFOAI', 'HQ2ZnI4', 'KCFSO', 'HTAB', 'PNAI', 'P1', 'ZIF-8', '2PACz/MeO-2PACz', 'Sn', 'HS-COFs', 'NMABr', 'ALD-SnO2', 'BP nanoflakes', 'ADAI', 'GuaBF4', 'PVBN', 'H2KNO3S', 'BP', 'Heparin sodium', 'Se', 'PEO', 'SnCl2 passivation layer', 'FTPA', 'GO', 'DA', 'BA2PbI4', 'BP-4', '4F-HBM', 'propane-1,3-diammonium iodide', '(AgCu)37 cluster', 'Y-Cl', 'i-BAI', 'HALS-770', '2FPPD', 'Ti', 'PEAI+EDAI2', 'SnPC', 'FPEAI', 'CF3PhAI', 'BTBT interlayer', 'Y-H', 'Ti3C2Tx', 'K2CO3', 'Y-F', 'amylamine passivation layer', 'IZO', 'PEA2FA2Pb3Br10', 'MeO-PEAI w/ MPA-CPA', 'CdTe', '3-MeOPEACl', 'TBAH', 'Ti3C2Tx-patched-GO', 'KPF6', 'CHCl', 'ABABr', 'Antimonene', 'PMMA + PCBM', '2PADBC', 'Fe1.84Mg0.16O3', 'TBA2B', 'T-SnOx', 'Cs4PbBr6', 'FDCA', 'C-PCBA', 'PEDOT:F', 'XA120 epoxy', 'Plasticoat Plastic Primer', 'a-Si', 'Cd-CsPbCl3:Mn2+ QDs', 'InCl3', '2DP-PDI', 'ODADI', 'PBAI', 'n-OAI', 'CPRA', 'Tedlar polyester', 'GDY', 'a-Si:H (i)', 'PFSA', 'DB21C7', 'octylammonium iodide', 'CDs', 'DT + MoS2', 'MgO', 'HPCA', 'GAI', 'MgFx', 'CsPbI2Br QDs', '(3-CBA)2PbI4', 'Al2O3-N0.12GO', 'ZR3', 'DHAI', 'L-PEAI', '4MEO-PEAI', 'TZO (O)', 'FY1', 'i-BABr', 'I-GQDs', 'CPTA', 'o-F-PEAI', 'TiO2', 'I3-/I- electrolyte', '2-BH', 'NPB', 'Me-4PACZ', 'B(CE)ACl', 'Al2O3-NPs', 'DIAC', 'FPEA2PbI4', 'Cs3Bi2I9', 'Cs4CuSb2Cl12', 'a-NbOH', 'Cs2BiAgI6', 'HTABr', 'NaYF4:Yb3+/Er3+ UCNPs mesoporous layer', 'DMAI', 'CA', 'CsPbBr3 QDs', '(VBA)2PbI4', '(BA)2PbI4', 'SiOx-NPs', 'Cr-MOF', 'AZO', 'Li2CO3', 'Me-2PACz', '345FAn', 'PMMA:F4-TCNQ', 'n-hexylammonium bromide', 'OAI passivation', 'BMDP', 'CeO2-BTC', 'PCBM:PMMA', 'CEA2PbI4', 'Al2Ox', '2D PEA2PbI4', 'LCE', 'CHAI', 'BCF', 'cis-ACHACl RPP', 'PDMS', 'Cl-PEAI', 'MBene', 'Rhodamine 101', 'RbI', 'Ti3C2Clx', 'Spiro-TTB', 'NMAI', 'TAMT', '(AMP)PbI4 2D layer', 'CsPbBr3-QDs', 'BMIMBF4', 'MAPbBr0.9I2.1 QDs', 'PhDMADBr', 'DMAcPA', '9-NRTF', 'TBAC', 'DES', 'CEACl', 'GU-CNPs', 'ZnO/Ag', 'PzTA-TPAS', 'MACl', 'EVL', 'LDC coating', 'EuAc3', 'FM5', 'S-2P', 'Cs2CO3', 'KAc CBL', 'CF3PhAI 2D perovskite', 'GuSCN', 'Cs0.05(MA0.17FA0.83)0.95PbBr3 QDs', 'P4TDPPCN', 'PABACd', '6FPPY', '2DP-Por', 'ALS', 'Pyr', 'PFN', '(OA)2PbI4', 'β-carotene', 'Bi2Te3', 'PAPz', 'ImAcCl', 'PDMS w/ leek leaf pattern', 'P3', 'PDMS antirefl ...
# Unknown (0): []
# Deposition methods (335): ['Spin-coating', 'Thermal-annealing', 'Evaporation', 'Doctor blading', 'Chemical bath deposition', 'Antisolvent-quenching', 'Screen-printing', 'Screen printing', 'Slot-die coating', 'Drop-infiltration', 'Blade coating', 'Sputtering', 'Unknown', 'Spray coating', 'Spray pyrolysis', 'Blade-coating', 'Atomic layer deposition', 'Thermal evaporation', 'Co-evaporation', 'Magnetron sputtering', 'Drop-casting', 'ALD', 'SILAR', 'Gas quenching', 'Sol-gel', 'RF magnetron sputtering', 'Inkjet printing', 'Hydrothermal', 'TiCl4 treatment', 'RF sputtering', 'Two-step sequential deposition', 'Two-step deposition', 'Sequential deposition', 'Thermal annealing', 'Immersion', 'Drop-coating', 'Chemical vapor deposition', 'Gravure printing', 'Electrospraying', 'Two-step method', 'Ligand exchange', 'Post-treatment', 'Dip-coating', 'Blading', 'Spin coating', 'Vapor-solid reaction', 'Vacuum flash', 'Electrospinning', 'Dip coating', 'DC magnetron sputtering', 'Wet transfer', 'Press transfer', 'Vacuum treatment', 'UV-ozone treatment', 'Cleaning', 'Rapid thermal sublimation', 'UV-Ozone treatment', 'Vacuum drying', 'Chemical bath', 'Electrochemical deposition', 'Laser processing', 'Thermal-assisted bar-coating', 'Hot-casting', 'Electrodeposition', 'Drop coating', 'Coating', 'Rapid thermal evaporation', 'Pyrolytic spraying', 'Printing', 'Electron beam evaporation', 'UV irradiation', 'Solution processing', 'RF sputter', 'One-step spin coating', 'Thermal-assisted blade-coating', 'Solution casting', 'UV light irradiation', 'One-step method', 'Vacuum suction', 'UV ozone treatment', 'One-step spin-coating', '2DSI treatment', 'Transfer printing', 'Dye adsorption', 'CVD', 'Glass rod coating', 'Chemical deposition', 'Pulsed laser deposition', 'Other', 'Aerosol spray pyrolysis', 'Hydrothermal deposition', 'PVD', 'Fast-drying spray deposition', 'Hydrothermal synthesis', 'Reverse-gravure coating', 'Doping', 'Reactive plasma deposition', 'Solvothermal', 'Vapor-assisted solution process', 'Deposition', 'Chemical-bath deposition', 'Space-confined method', 'Lamination', 'Slot die coating', 'Solid-vapor reaction', '2-Solution', 'Doctor blade', 'Meniscus coating', 'Drop casting', 'Solvent interlacing', 'Ozone treatment', 'Electron-beam evaporation', 'Gravure coating', 'Semi-sealed gas quenching', 'Blending', 'Oxygen plasma treatment', 'UV/ozone treatment', 'AACVD', 'Rapid thermal processing', 'DC sputtering', 'Two-step sequential method', 'Vacuum backfilling', 'Vapor-assisted solution technique', 'Vacuum-flash', 'Intense pulsed light', 'Bar coating', 'BHSP meniscus coating', 'one-step anti-solvent method', 'Direct placement', 'Two-step approach', 'Electropolishing', 'Rinsing', 'V2SLC', 'In situ crystal transfer', 'Soaking', 'Doctor-blading', 'Sputter deposition', 'Ultrasonic spray-coating', 'Spray-pyrolysis', 'Ultrasonic cleaning', 'Pressing transfer', 'Layer-by-layer processing', 'In-situ polymerization', 'Double-sided sandwich evaporation technique', 'Anisole liquid soaking', 'Spray-coating', 'Seed-assisted growth', 'HCVD', 'Vacuum-quenching', 'Vacuum pumping', 'Laser crystallization', 'Ligand-induced self-assembly', 'Successive ionic layer adsorption and reaction', 'Meniscus-coating', 'Vacuum flash evaporation', 'CBD', 'Intermittent spin-coating', 'Attachment', 'Pressure-assisted thermal annealing', 'Vacuum-flash crystallization', 'Laser patterning', 'Close-space annealing', 'Aging treatment', 'Space-confined inverse temperature crystallization', 'Spraying coating', 'Chemical bath co-deposition', 'Ar plasma treatment', 'Acid treatment', 'Reactive electron-beam evaporation', 'Vacuum deposition', 'Thermal spraying', 'Spray pyrolysis deposition', 'Combustion synthesis', 'Thermal co-evaporation', 'DC-PMS', 'Hot pure oxygen treatment', 'Physical vapor deposition', 'Two-step sequential', 'Heat-press transfer', 'Air-knife-assisted drying', 'Plasma treatment', 'UV-ozone cleaning', 'Plasma oxidation', 'RCA-2 cleaning', 'Vacuum-assisted solvent quenching' ...

# %%
print('\nSummary of unique names per functionality:')
for func, names in layer_names.items():
    unique_names = set(names)
    print(f'{func} ({len(unique_names)})')
# Out:
# Summary of unique names per functionality:
# Substrate (71)
# Absorber (2128)
# Contact (178)
# Electron-transport (598)
# Hole-transport (789)
# Other (492)
# Unknown (0)

# %%
with open('unique_names_and_methods.json', 'w') as f:
    json.dump(unique_names, f, indent=2)

# %%
with open('unique_names_and_methods.json') as f:
    unique_names = json.load(f)

# %%
synthesis_methods = [m for m, _ in unique_names.get('Deposition methods', [])]
print(f'Synthesis methods: {synthesis_methods}')

manual_synthesis_method_synonyms = {
    'Spin-coating': [
        'Spin-coating',
        'Spin coating',
        'One-step spin coating',
        'One-step spin-coating',
        'Intermittent spin-coating',
    ],
    'Thermal-annealing': ['Thermal-annealing', 'Thermal annealing'],
    'Doctor blading': [
        'Blade coating',
        'Blade-coating',
        'Doctor blading',
        'Doctor blade',
        'Doctor-blading',
        'Meniscus coating',
        'Meniscus-coating',
        'Meniscus-modulated blade coating',
    ],
    'CBD': [
        'Chemical bath deposition',
        'Chemical Bath Deposition',
        'Chemical-bath deposition',
        'Chemical bath',
        'Chemical bath co-deposition',
        'CBD',
    ],
    'Antisolvent-quenching': [
        'Antisolvent-quenching',
        'Antisolvent technique',
        'one-step anti-solvent method',
        'Antisolvent-fumigated',
    ],
    'Screen printing': ['Screen-printing', 'Screen printing'],
    'Slot-die coating': ['Slot-die coating', 'Slot die coating', 'Slot-die printing'],
    'Drop-infiltration': [
        'Drop-infiltration',
    ],
    'Sputtering': [
        'Sputtering',
    ],
    'Unknown': [
        'Unknown',
    ],
    'Spray coating': [
        'Spray coating',
    ],
    'Spray pyrolysis': [
        'Spray pyrolysis',
    ],
    'Atomic layer deposition': [
        'Atomic layer deposition',
        'ALD',
        'Atom layer deposition',
        'Atomic Layer Deposition',
    ],
    'Thermal evaporation': ['Thermal evaporation'],
    'Co-evaporation': ['Co-evaporation'],
    'Magnetron sputtering': ['Magnetron sputtering'],
    'Drop-casting': [
        'Drop-casting',
        'Drop casting',
        'Drop-coating',
        'Drop coating',
        'Dropcasting',
    ],
    'SILAR': ['SILAR'],
    'Gas quenching': ['Gas quenching'],
    'Sol-gel': ['Sol-gel'],
    'RF magnetron sputtering': ['RF magnetron sputtering'],
    'Inkjet printing': ['Inkjet printing'],
    'Hydrothermal': ['Hydrothermal'],
    'TiCl4 treatment': ['TiCl4 treatment'],
    'RF sputtering': ['RF sputtering'],
}

synthesis_method_map = {}
for standard_method, synonyms in manual_synthesis_method_synonyms.items():
    if len(synonyms) < 2:
        continue
    for synonym in synonyms:
        synthesis_method_map[synonym] = standard_method

unique_synthesis_methods = []
for method in synthesis_methods:
    unique_method = synthesis_method_map.get(method, method)
    if unique_method not in unique_synthesis_methods:
        unique_synthesis_methods.append(unique_method)

print(
    f'Unique synthesis methods after mapping: {json.dumps(unique_synthesis_methods, indent=2)}'
)
# Out:
# Synthesis methods: ['Spin-coating', 'Thermal-annealing', 'Evaporation', 'Doctor blading', 'Chemical bath deposition', 'Antisolvent-quenching', 'Screen-printing', 'Screen printing', 'Slot-die coating', 'Drop-infiltration', 'Blade coating', 'Sputtering', 'Unknown', 'Spray coating', 'Spray pyrolysis', 'Blade-coating', 'Atomic layer deposition', 'Thermal evaporation', 'Co-evaporation', 'Magnetron sputtering', 'Drop-casting', 'ALD', 'SILAR', 'Gas quenching', 'Sol-gel', 'RF magnetron sputtering', 'Inkjet printing', 'Hydrothermal', 'TiCl4 treatment', 'RF sputtering', 'Two-step sequential deposition', 'Two-step deposition', 'Sequential deposition', 'Thermal annealing', 'Immersion', 'Drop-coating', 'Chemical vapor deposition', 'Gravure printing', 'Electrospraying', 'Two-step method', 'Ligand exchange', 'Post-treatment', 'Dip-coating', 'Blading', 'Spin coating', 'Vapor-solid reaction', 'Vacuum flash', 'Electrospinning', 'Dip coating', 'DC magnetron sputtering', 'Wet transfer', 'Press transfer', 'Vacuum treatment', 'UV-ozone treatment', 'Cleaning', 'Rapid thermal sublimation', 'UV-Ozone treatment', 'Vacuum drying', 'Chemical bath', 'Electrochemical deposition', 'Laser processing', 'Thermal-assisted bar-coating', 'Hot-casting', 'Electrodeposition', 'Drop coating', 'Coating', 'Rapid thermal evaporation', 'Pyrolytic spraying', 'Printing', 'Electron beam evaporation', 'UV irradiation', 'Solution processing', 'RF sputter', 'One-step spin coating', 'Thermal-assisted blade-coating', 'Solution casting', 'UV light irradiation', 'One-step method', 'Vacuum suction', 'UV ozone treatment', 'One-step spin-coating', '2DSI treatment', 'Transfer printing', 'Dye adsorption', 'CVD', 'Glass rod coating', 'Chemical deposition', 'Pulsed laser deposition', 'Other', 'Aerosol spray pyrolysis', 'Hydrothermal deposition', 'PVD', 'Fast-drying spray deposition', 'Hydrothermal synthesis', 'Reverse-gravure coating', 'Doping', 'Reactive plasma deposition', 'Solvothermal', 'Vapor-assisted solution process', 'Deposition', 'Chemical-bath deposition', 'Space-confined method', 'Lamination', 'Slot die coating', 'Solid-vapor reaction', '2-Solution', 'Doctor blade', 'Meniscus coating', 'Drop casting', 'Solvent interlacing', 'Ozone treatment', 'Electron-beam evaporation', 'Gravure coating', 'Semi-sealed gas quenching', 'Blending', 'Oxygen plasma treatment', 'UV/ozone treatment', 'AACVD', 'Rapid thermal processing', 'DC sputtering', 'Two-step sequential method', 'Vacuum backfilling', 'Vapor-assisted solution technique', 'Vacuum-flash', 'Intense pulsed light', 'Bar coating', 'BHSP meniscus coating', 'one-step anti-solvent method', 'Direct placement', 'Two-step approach', 'Electropolishing', 'Rinsing', 'V2SLC', 'In situ crystal transfer', 'Soaking', 'Doctor-blading', 'Sputter deposition', 'Ultrasonic spray-coating', 'Spray-pyrolysis', 'Ultrasonic cleaning', 'Pressing transfer', 'Layer-by-layer processing', 'In-situ polymerization', 'Double-sided sandwich evaporation technique', 'Anisole liquid soaking', 'Spray-coating', 'Seed-assisted growth', 'HCVD', 'Vacuum-quenching', 'Vacuum pumping', 'Laser crystallization', 'Ligand-induced self-assembly', 'Successive ionic layer adsorption and reaction', 'Meniscus-coating', 'Vacuum flash evaporation', 'CBD', 'Intermittent spin-coating', 'Attachment', 'Pressure-assisted thermal annealing', 'Vacuum-flash crystallization', 'Laser patterning', 'Close-space annealing', 'Aging treatment', 'Space-confined inverse temperature crystallization', 'Spraying coating', 'Chemical bath co-deposition', 'Ar plasma treatment', 'Acid treatment', 'Reactive electron-beam evaporation', 'Vacuum deposition', 'Thermal spraying', 'Spray pyrolysis deposition', 'Combustion synthesis', 'Thermal co-evaporation', 'DC-PMS', 'Hot pure oxygen treatment', 'Physical vapor deposition', 'Two-step sequential', 'Heat-press transfer', 'Air-knife-assisted drying', 'Plasma treatment', 'UV-ozone cleaning', 'Plasma oxidation', 'RCA-2 cleaning', 'Vacuum-assisted solvent quenching', 'Vacu ...
# Unique synthesis methods after mapping: [
#   "Spin-coating",
#   "Thermal-annealing",
#   "Evaporation",
#   "Doctor blading",
#   "CBD",
#   "Antisolvent-quenching",
#   "Screen printing",
#   "Slot-die coating",
#   "Drop-infiltration",
#   "Sputtering",
#   "Unknown",
#   "Spray coating",
#   "Spray pyrolysis",
#   "Atomic layer deposition",
#   "Thermal evaporation",
#   "Co-evaporation",
#   "Magnetron sputtering",
#   "Drop-casting",
#   "SILAR",
#   "Gas quenching",
#   "Sol-gel",
#   "RF magnetron sputtering",
#   "Inkjet printing",
#   "Hydrothermal",
#   "TiCl4 treatment",
#   "RF sputtering",
#   "Two-step sequential deposition",
#   "Two-step deposition",
#   "Sequential deposition",
#   "Immersion",
#   "Chemical vapor deposition",
#   "Gravure printing",
#   "Electrospraying",
#   "Two-step method",
#   "Ligand exchange",
#   "Post-treatment",
#   "Dip-coating",
#   "Blading",
#   "Vapor-solid reaction",
#   "Vacuum flash",
#   "Electrospinning",
#   "Dip coating",
#   "DC magnetron sputtering",
#   "Wet transfer",
#   "Press transfer",
#   "Vacuum treatment",
#   "UV-ozone treatment",
#   "Cleaning",
#   "Rapid thermal sublimation",
#   "UV-Ozone treatment",
#   "Vacuum drying",
#   "Electrochemical deposition",
#   "Laser processing",
#   "Thermal-assisted bar-coating",
#   "Hot-casting",
#   "Electrodeposition",
#   "Coating",
#   "Rapid thermal evaporation",
#   "Pyrolytic spraying",
#   "Printing",
#   "Electron beam evaporation",
#   "UV irradiation",
#   "Solution processing",
#   "RF sputter",
#   "Thermal-assisted blade-coating",
#   "Solution casting",
#   "UV light irradiation",
#   "One-step method",
#   "Vacuum suction",
#   "UV ozone treatment",
#   "2DSI treatment",
#   "Transfer printing",
#   "Dye adsorption",
#   "CVD",
#   "Glass rod coating",
#   "Chemical deposition",
#   "Pulsed laser deposition",
#   "Other",
#   "Aerosol spray pyrolysis",
#   "Hydrothermal deposition",
#   "PVD",
#   "Fast-drying spray deposition",
#   "Hydrothermal synthesis",
#   "Reverse-gravure coating",
#   "Doping",
#   "Reactive plasma deposition",
#   "Solvothermal",
#   "Vapor-assisted solution process",
#   "Deposition",
#   "Space-confined method",
#   "Lamination",
#   "Solid-vapor reaction",
#   "2-Solution",
#   "Solvent interlacing",
#   "Ozone treatment",
#   "Electron-beam evaporation",
#   "Gravure coating",
#   "Semi-sealed gas quenching",
#   "Blending",
#   "Oxygen plasma treatment",
#   "UV/ozone treatment",
#   "AACVD",
#   "Rapid thermal processing",
#   "DC sputtering",
#   "Two-step sequential method",
#   "Vacuum backfilling",
#   "Vapor-assisted solution technique",
#   "Vacuum-flash",
#   "Intense pulsed light",
#   "Bar coating",
#   "BHSP meniscus coating",
#   "Direct placement",
#   "Two-step approach",
#   "Electropolishing",
#   "Rinsing",
#   "V2SLC",
#   "In situ crystal transfer",
#   "Soaking",
#   "Sputter deposition",
#   "Ultrasonic spray-coating",
#   "Spray-pyrolysis",
#   "Ultrasonic cleaning",
#   "Pressing transfer",
#   "Layer-by-layer processing",
#   "In-situ polymerization",
#   "Double-sided sandwich evaporation technique",
#   "Anisole liquid soaking",
#   "Spray-coating",
#   "Seed-assisted growth",
#   "HCVD",
#   "Vacuum-quenching",
#   "Vacuum pumping",
#   "Laser crystallization",
#   "Ligand-induced self-assembly",
#   "Successive ionic layer adsorption and reaction",
#   "Vacuum flash evaporation",
#   "Attachment",
#   "Pressure-assisted thermal annealing",
#   "Vacuum-flash crystallization",
#   "Laser patterning",
#   "Close-space annealing",
#   "Aging treatment",
#   "Space-confined inverse temperature crystallization",
#   "Spraying coating",
#   "Ar plasma treatment",
#   "Acid treatment",
#   "Reactive electron-beam evaporation",
#   "Vacuum deposition",
#   "Thermal spraying",
#   "Spray pyrolysis deposition",
#   "Combustion synthesis",
#   "Thermal co-evaporation",
#   "DC-PMS",
#   "Hot pure oxygen treatment",
#   "Physical vapor deposition",
#   "Two-step sequential",
#   "Heat-press transfer",
#   "Air-knife-assisted drying",
#   "Plasma treatment",
#   "UV-ozone cleaning",
#   "Plasma oxidation",
#   "RCA-2 cleaning",
#   "Vacuum-assisted solvent quenching",
#   "Vacuum processing",
#   "UV-O3 plasma treatment",
#   "Non-thermal plasma",
#   "Ion-beam sputtering",
#   "Electrostatic adsorption self-assembly",
#   "Cold-casting",
#   "Solution conversion",
#   "Flash infrared annealing",
#   "Low-pressure assisted method",
#   "Hot-pressing transfer",
#   "Ion beam sputtering",
#   "One-step spin coating with antisolvent",
#   "Vacuum flashing",
#   "RF-magnetron sputtering",
#   "Vacuum-assisted growth",
#   "Dry press deposition",
#   "Ar/O2 DC sputtering",
#   "Vacuum evaporation",
#   "Vapor fumigation",
#   "Close-space vapor transport",
#   "Artist spray gun assisted pyrolysis",
#   "Nitrogen quenching",
#   "E-beam evaporation",
#   "Bifacial-stamping",
#   "Ultrasonic spray",
#   "Pressing",
#   "Two-step solvent deposition",
#   "Dry air treatment",
#   "Air-flow treatment",
#   "Hot pressing",
#   "Hybrid chemical vapor deposition",
#   "Powder pressing",
#   "Roll-to-roll gravure printing",
#   "IPSD",
#   "Alternating vacuum deposition",
#   "Combustion",
#   "oCVD",
#   "Vapour deposition",
#   "Vapor treatment",
#   "Vacuum vapour deposition",
#   "Grinding synthesis",
#   "Atmospheric-pressure chemical vapor deposition",
#   "Roll-to-roll coating",
#   "UV/plasma activation",
#   "Vacuum dry",
#   "Solvent engineering",
#   "Chemical etching",
#   "Sequential-vapor",
#   "Microgravure coating",
#   "Soft lithography",
#   "Electron-beam lithography",
#   "Negative pressure evaporation",
#   "Vapor-annealing",
#   "Merged annealing",
#   "DC pulsed magnetron sputtering",
#   "Vacuum flash processing",
#   "Vapor iodination",
#   "RF-sputtering",
#   "Ion exchange",
#   "One-step spin coating and low-pressure-assisted method",
#   "Hot-press transfer",
#   "Vertical deposition",
#   "Hot air flow",
#   "Vacuum-assisted thermal annealing",
#   "Ball milling",
#   "Electrical and mechanical field-assisted sintering",
#   "Thermal vacuum evaporation",
#   "Thermal decomposition",
#   "UV-Ozone cleaning",
#   "UV sintering",
#   "Sequential vapor deposition",
#   "Gas treatment",
#   "vapor-assisted solution process",
#   "Layering",
#   "Periodic acid post-treatment",
#   "Robotic Mesh (RbM)",
#   "NIR heating",
#   "Reactive vapor deposition",
#   "IPA post-treatment",
#   "GAI surface passivation",
#   "Chemical bathing",
#   "In situ growth",
#   "Reverse gravure coating",
#   "Ultrasonic spray coating",
#   "Aerosol-assisted solvent treatment",
#   "Mesh-assisted deposition",
#   "Oxygen plasma assisted reaction",
#   "Space-limited ITC",
#   "Co-precipitation",
#   "UV laser ablation",
#   "Pre-patterned",
#   "Convective deposition",
#   "Low-temperature processing",
#   "Solution process",
#   "Linear facing target sputtering",
#   "Halide exchange",
#   "Solid-phase in-plane growth",
#   "SC-CBD",
#   "Self-woven deposition",
#   "Laser pulse deposition",
#   "Two-step sequential solution-phase process",
#   "Commercial substrate",
#   "Sulfurization",
#   "Thermal sintering",
#   "Etching",
#   "Inverse temperature crystallization",
#   "Dual-source thermal evaporation",
#   "Plasma-assisted spin-coating",
#   "Press-transfer",
#   "hydrothermal process",
#   "PA-MBE",
#   "Pulse laser deposition",
#   "Scratch-coating",
#   "Dual source evaporation",
#   "UV/O3 treatment",
#   "Crystal growth",
#   "Vacuum quenching",
#   "Reactive polyiodide melt",
#   "High-pressure cooking",
#   "VUV irradiation",
#   "ITC",
#   "Sequential vacuum deposition",
#   "H2O-rich solvent washing",
#   "Mold-assisted decal-coating",
#   "Thermal-assisted blade coating",
#   "Robotic deposition",
#   "Stacking",
#   "Hot-pressing",
#   "Water treatment",
#   "LPCVD",
#   "One-step deposition",
#   "Hydrothermal reaction",
#   "Sequential deposition via anion-exchange",
#   "Single-source vacuum deposition",
#   "Chemical precipitation",
#   "Nitrogen knife-assisted blade-coating",
#   "Gas-solid phase reaction",
#   "VLS growth",
#   "dissolution-recrystallization",
#   "UV treatment",
#   "Thermal sublimation",
#   "Close-space sublimation"
# ]

# %%
substrates = [m for m, _ in unique_names.get('Substrate', [])]
print(f'Substrates: {substrates}')

manual_substrate_synonyms = {
    'FTO': [
        'FTO',
        'FTO glass',
        'FTO/glass',
        'Glass/FTO',
        'FTO-30',
        'FTO-70',
        'FTO-50',
        'FTO-glass',
    ],
    'ITO': ['ITO', 'ITO glass', 'ITO/glass', 'Glass/ITO', 'ITO-glass'],
    'SLG': ['Glass', 'glass', 'SLG'],
    'Silicon': ['Silicon', 'Si', 'Si substrate', 'Silicon wafer', 'c-Si'],
    'p-type silicon': ['p-type silicon', 'p-type Cz silicon', 'p-Si', 'PSi'],
    'n-type silicon': ['n-type silicon', 'n-Si', 'n+Si'],
    'PEN/ITO': ['PEN/ITO', 'PEN-ITO', 'ITO-PEN', 'PEN/ITO strip'],
    'PET/ITO': ['PET/ITO', 'PET-ITO', 'ITO-PET'],
}

substrate_map = {}
for standard_substrate, synonyms in manual_substrate_synonyms.items():
    if len(synonyms) < 2:
        continue
    for synonym in synonyms:
        substrate_map[synonym] = standard_substrate

unique_substrates = []
for substrate in substrates:
    unique_substrate = substrate_map.get(substrate, substrate)
    if unique_substrate not in unique_substrates:
        unique_substrates.append(unique_substrate)

print(f'Unique substrates after mapping: {json.dumps(unique_substrates, indent=2)}')
# Out:
# Substrates: ['FTO', 'ITO', 'Glass', 'PET', 'PEN', 'PEN/ITO', 'PET/ITO', 'FTO glass', 'Glass/ITO', 'ITO/PET', 'ITO/PEN', 'Quartz', 'FTO/glass', 'IZO', 'PEN-ITO', 'ITO-glass', 'Glass/FTO', 'ITO-PET', 'PDMS', 'TCO', 'p-type silicon', 'ITO glass', 'MgF2/Glass', 'c-Si', 'Ti', 'FTO-30', 'FTO-70', 'Flexible substrate', 'glass', 'HPMC', 'Silicon', 'Kapton', 'FTO-50', 'FTO-glass', 'ITO-PEN', 'Parylene', 'Silicon heterojunction', 'PSi', 'Ni', 'PET-IZO', 'n-type silicon', 'TCO/glass', 'Al-foil', 'Sapphire', 'Stainless steel', 'ITO/glass', 'Cellophane paper', 'PI-SWNT', 'FTO-A', 'SiO2', 'SWNT-PI', 'NOA 63', 'PET:ITO', 'CFRP', 'ITP-coated Glass', 'FTO-HA', 'FTO-N', 'PI', 'PET/IMI', 'MgF2/PET/ITO', 'Cu foil', 'Polymer', 'Si', 'SiO2/Si', 'FTO Glass', 'SLG', 'Ti metal-coated glass', 'LiF/FTO', 'FTO substrate with Sm3+-Ce3+ co-doped glass-ceramic waveguides', 'Textured silicon', 'Graphene', 'n-Si', 'OPV8', 'sm-ITO', 'Willow glass', 'ITO-coated PEN', 'Silk-Ag nanowires', 'Carbon cloth', 'TLHA-coated glass', 'SiO2/PET/SiO2', 'MgF2/FTO', 'GaN', 'Transparent wood', 'PEN/Cu', 'uFTE with iSPM', 'Elastic fiber', 'FTO substrate with 4,7-diphenyl-1,10-phenanthroline coordinated Eu3+ complex', 'Silicon wafer', 'uFTE', 'FTO substrate with Eu(TTA)2(Phen)MAA DC layer', 'Ti foil', 'Steel yarn', 'PEN/ITO strip', 'p-type Cz silicon', 'p-Si', 'PET with nanograting', 'DS-TOPCon silicon subcell', 'PC', 'High-transparency FTO', 'n+Si', 'Si substrate']
# Unique substrates after mapping: [
#   "FTO",
#   "ITO",
#   "SLG",
#   "PET",
#   "PEN",
#   "PEN/ITO",
#   "PET/ITO",
#   "ITO/PET",
#   "ITO/PEN",
#   "Quartz",
#   "IZO",
#   "PDMS",
#   "TCO",
#   "p-type silicon",
#   "MgF2/Glass",
#   "Silicon",
#   "Ti",
#   "Flexible substrate",
#   "HPMC",
#   "Kapton",
#   "Parylene",
#   "Silicon heterojunction",
#   "Ni",
#   "PET-IZO",
#   "n-type silicon",
#   "TCO/glass",
#   "Al-foil",
#   "Sapphire",
#   "Stainless steel",
#   "Cellophane paper",
#   "PI-SWNT",
#   "FTO-A",
#   "SiO2",
#   "SWNT-PI",
#   "NOA 63",
#   "PET:ITO",
#   "CFRP",
#   "ITP-coated Glass",
#   "FTO-HA",
#   "FTO-N",
#   "PI",
#   "PET/IMI",
#   "MgF2/PET/ITO",
#   "Cu foil",
#   "Polymer",
#   "SiO2/Si",
#   "FTO Glass",
#   "Ti metal-coated glass",
#   "LiF/FTO",
#   "FTO substrate with Sm3+-Ce3+ co-doped glass-ceramic waveguides",
#   "Textured silicon",
#   "Graphene",
#   "OPV8",
#   "sm-ITO",
#   "Willow glass",
#   "ITO-coated PEN",
#   "Silk-Ag nanowires",
#   "Carbon cloth",
#   "TLHA-coated glass",
#   "SiO2/PET/SiO2",
#   "MgF2/FTO",
#   "GaN",
#   "Transparent wood",
#   "PEN/Cu",
#   "uFTE with iSPM",
#   "Elastic fiber",
#   "FTO substrate with 4,7-diphenyl-1,10-phenanthroline coordinated Eu3+ complex",
#   "uFTE",
#   "FTO substrate with Eu(TTA)2(Phen)MAA DC layer",
#   "Ti foil",
#   "Steel yarn",
#   "PET with nanograting",
#   "DS-TOPCon silicon subcell",
#   "PC",
#   "High-transparency FTO"
# ]

# %%
contacts = [m for m, _ in unique_names.get('Contact', [])]
print(f'Contacts: {contacts}')

manual_contact_synonyms = {
    'Au': [
        'Au',
        'Gold',
    ],
    'Ag': [
        'Ag',
        'Silver',
    ],
    'ITO': [
        'ITO',
    ],
    'Carbon': [
        'Carbon',
        'C',
        'carbon',
        'Carbon paste',
        'Carbon electrode',
        'Carbon black electrode',
    ],
    'Carbon-mp': [
        'Carbon-mp',
        'mp-Carbon',
        'Carbon mesoporous',
        'm-Carbon',
        'm-carbon electrode',
        'porous carbon',
    ],
    'Cu': [
        'Cu',
        'Copper',
    ],
}

contact_map = {}
for standard_contact, synonyms in manual_contact_synonyms.items():
    if len(synonyms) < 2:
        continue
    for synonym in synonyms:
        contact_map[synonym] = standard_contact

unique_contacts = []
for contact in contacts:
    unique_contact = contact_map.get(contact, contact)
    if unique_contact not in unique_contacts:
        unique_contacts.append(unique_contact)

print(f'Unique contacts after mapping: {json.dumps(unique_contacts, indent=2)}')
# Out:
# Contacts: ['Au', 'Ag', 'ITO', 'Carbon', 'Cu', 'MoO3', 'Al', 'FTO', 'Ni', 'MoOx', 'IZO', 'LiF', 'C', 'Pt', 'Cr', 'carbon', 'Carbon paste', 'Ta-WOx', 'Silver', 'TCO', 'IO:H', 'AgNWs', 'Carbon electrode', 'Ti wire', 'Back contact', 'Graphite', 'AZO', 'C-rCP', 'Mo', 'Gold', 'Cathode', 'Anode', 'Au/Ag', 'Ag-grid', 'Silver paste', 'Cu2S', 'rGO', 'Metal', 'Se', 'SWCNT@85%', 'Pd', 'TCE', 'Graphene', 'H2PtCl6', 'TETA-Gr', 'ZrAcac', 'Au:Pd', 'Ag grid', 'WO3', 'Ta4C3F2', 'Ti4N3', 'mp-Carbon', 'VOx', 'BCP', 'RGO', 'ITO/Au gold finger', 'Platinum', 'nanocarbon', 'NiO/Ag/NiO', 'Carbon mesoporous', 'C-G', 'AgAl', 'Carbon black electrode', 'ALD ITO', 'Ag/Au', 'SWCNT', 'Pt coated FTO', 'CNT sheet', 'LIG@NiOX', 'AgNW', 'DMD', 'Back electrode', 'Copper', 'Metal electrode', 'DWNT', 'ICO:H', 'W', 'MoOx/Au/MoOx', 'Ca', 'Carbon/conductive cloth', 'm-Carbon', 'F-CE', 'm-carbon electrode', 'WO3/Ag/WO3', 'Gr/CB', 'PEDOT:F', 'Carbon w/ 30 wt% Mn3O4', 'TiO2/ultrathin Ag/TiO2', 'Ag paste', 'CNTs', 'CNT', 'Cu2S/brass', 'silver', 'PEDOT', 'Front electrode', 'Cu wire', 'Au-mesh/PEDOT:PSS', 'graphene', 'Ag/MoO3', 'ITO-r', 'porous carbon', 'IZTO', 'Ag NWs', 'MoOx/Al', 'IZVO', 'PEI', 'Carbon w/ o-xylene', 'Ag-mesh/PH1000', 'In:SnO2', 'HAT-CN', 'Mg/Ag', 'Ti1-rGO', 'Boron-doped graphite-based carbon', 'Cu-Ni/graphene composite', 'PH1000:Ag NWs', 'Co1/CN', 'CNF', 'm-SWCNTs', 'carbon framework', 'Rhodamine-Ag-MoO3', 'PDMS/Ag grids', 'AgNWs/TiO2', 'Silver grid', 'Carbon w/ OAI', 'BCP:Ag', 'AgNWs/graphene', 'Graphite-based carbon', 'orthogonal AgNWs', 'a-ITO', 'PH1000', 'PEDOT:PSS', 'Bathocuproine', 'CN', 'Carbon + CNTs + Ti3C2-MXene', 'CB', 'Carbon electrode w/ BAI', 'IOH', 'Ag/MgF2/Ag micro-cavity cathode', 'Pt-FTO', 'AZO/Cu/Ag/AZO', 'Carbon w/ 5 wt% waste toner carbon', 'Carbon with SWCNTs', 'Ca/Al', 'Ti', 'MOM (20/75/30)', 'ffBT-F3N', 'HC-PEDOT', 'TWCNT w/ L-PTAA', 'SnOX/ZTO', 'Cr2O3/Cr', 'MoO3/Au/Ag/MoO3', 'Carbon electrode w/ DDAI', 'MOM (25/75/25)', 'Ni foil', 'DPP-PhN', 'MoO3/Ag/Cu/MoO3', 'CNW', 'Au grids/PH1000', 'ZnO-Al', 'Ti1/CB', 'm-CNF', 'Graphite/CB', 'Carbon with CuPc', 'In:ZnO', 'B0.5%-CP', 'CB+Graphite', 'GO', 'IAI', 'TiN+Graphite', 'Bi', 'TWCNT', 'M0.1%-CP', 'graphene aerogel/Au', 'MC/Ti', 'Carbon w/ NiO', 'MoOx/ITO/Ag/ITO', 'AuCl3-doped monolayer graphene', 'Carbon w/ 17 wt% waste toner carbon', 'MOM (30/75/20)', 'GS', 'Ti/Au', 'LIG', 'ITO bilayer', 'PbZrO3', 'CP', 'PoA-PbZrO3', 'VO@CNF', 'Gold contact', 'VS4@CNF', 'Commercial Carbon', 'PNMPy-PoA-PbZrO3', 'NC', 'B0.1%-CP', 'Carbon w/ 23 wt% waste toner carbon', 'Liq', 'Textured front contact with nanoholes', 'Au buffer layer', 'GCEP', 'Pt-Ti foil', 'SA:c-ITO', 'CQDs', 'MoO3/Au/Cu/MoO3', 'Carbon w/ IPA', 'Au electrode with embedded NaYF4:Yb3+,Er3+ UCNPs', 'MoOx/ITO', 'Carbon Control', 'n++/p++ tunnel junction', 'Ag nanowires', 'N-Ti3C2@carbon', 'Sb', 'FTO-Glass', 'M0.5%-CP', 'Pearl carbon', 'Carbon electrode w/ OAI', 'AgNW:Ti3C2Tx', 'Carbon electrode w/ HDAI', 'NiO/Ag/NiO transparent electrode with UC layer', 'rGO/AgNWs/rGO', 'Carbon w/ 10 wt% waste toner carbon', 'MoOX', 'Ag yarn', 'DPP-F3N', 'MXene-V3C2F2', 'PNMPy-PbZrO3', 'Fe', 'Expanded graphite', 'Cr/Au', 'm-BCNF', 'Commercial Carbon w/ NiO', 'Ti3C2Tx', 'Ag fingers', 'Carbon w/ CB', 'BMG ITO', 'Carbon electrode w/ DAI', 'Pearl carbon w/ CAISSe NPs', 'TWCNT w/ H-PTAA', 'Ag front contact', 'Ti/Ag back contact', 'ITO/Au fingers']
# Unique contacts after mapping: [
#   "Au",
#   "Ag",
#   "ITO",
#   "Carbon",
#   "Cu",
#   "MoO3",
#   "Al",
#   "FTO",
#   "Ni",
#   "MoOx",
#   "IZO",
#   "LiF",
#   "Pt",
#   "Cr",
#   "Ta-WOx",
#   "TCO",
#   "IO:H",
#   "AgNWs",
#   "Ti wire",
#   "Back contact",
#   "Graphite",
#   "AZO",
#   "C-rCP",
#   "Mo",
#   "Cathode",
#   "Anode",
#   "Au/Ag",
#   "Ag-grid",
#   "Silver paste",
#   "Cu2S",
#   "rGO",
#   "Metal",
#   "Se",
#   "SWCNT@85%",
#   "Pd",
#   "TCE",
#   "Graphene",
#   "H2PtCl6",
#   "TETA-Gr",
#   "ZrAcac",
#   "Au:Pd",
#   "Ag grid",
#   "WO3",
#   "Ta4C3F2",
#   "Ti4N3",
#   "Carbon-mp",
#   "VOx",
#   "BCP",
#   "RGO",
#   "ITO/Au gold finger",
#   "Platinum",
#   "nanocarbon",
#   "NiO/Ag/NiO",
#   "C-G",
#   "AgAl",
#   "ALD ITO",
#   "Ag/Au",
#   "SWCNT",
#   "Pt coated FTO",
#   "CNT sheet",
#   "LIG@NiOX",
#   "AgNW",
#   "DMD",
#   "Back electrode",
#   "Metal electrode",
#   "DWNT",
#   "ICO:H",
#   "W",
#   "MoOx/Au/MoOx",
#   "Ca",
#   "Carbon/conductive cloth",
#   "F-CE",
#   "WO3/Ag/WO3",
#   "Gr/CB",
#   "PEDOT:F",
#   "Carbon w/ 30 wt% Mn3O4",
#   "TiO2/ultrathin Ag/TiO2",
#   "Ag paste",
#   "CNTs",
#   "CNT",
#   "Cu2S/brass",
#   "silver",
#   "PEDOT",
#   "Front electrode",
#   "Cu wire",
#   "Au-mesh/PEDOT:PSS",
#   "graphene",
#   "Ag/MoO3",
#   "ITO-r",
#   "IZTO",
#   "Ag NWs",
#   "MoOx/Al",
#   "IZVO",
#   "PEI",
#   "Carbon w/ o-xylene",
#   "Ag-mesh/PH1000",
#   "In:SnO2",
#   "HAT-CN",
#   "Mg/Ag",
#   "Ti1-rGO",
#   "Boron-doped graphite-based carbon",
#   "Cu-Ni/graphene composite",
#   "PH1000:Ag NWs",
#   "Co1/CN",
#   "CNF",
#   "m-SWCNTs",
#   "carbon framework",
#   "Rhodamine-Ag-MoO3",
#   "PDMS/Ag grids",
#   "AgNWs/TiO2",
#   "Silver grid",
#   "Carbon w/ OAI",
#   "BCP:Ag",
#   "AgNWs/graphene",
#   "Graphite-based carbon",
#   "orthogonal AgNWs",
#   "a-ITO",
#   "PH1000",
#   "PEDOT:PSS",
#   "Bathocuproine",
#   "CN",
#   "Carbon + CNTs + Ti3C2-MXene",
#   "CB",
#   "Carbon electrode w/ BAI",
#   "IOH",
#   "Ag/MgF2/Ag micro-cavity cathode",
#   "Pt-FTO",
#   "AZO/Cu/Ag/AZO",
#   "Carbon w/ 5 wt% waste toner carbon",
#   "Carbon with SWCNTs",
#   "Ca/Al",
#   "Ti",
#   "MOM (20/75/30)",
#   "ffBT-F3N",
#   "HC-PEDOT",
#   "TWCNT w/ L-PTAA",
#   "SnOX/ZTO",
#   "Cr2O3/Cr",
#   "MoO3/Au/Ag/MoO3",
#   "Carbon electrode w/ DDAI",
#   "MOM (25/75/25)",
#   "Ni foil",
#   "DPP-PhN",
#   "MoO3/Ag/Cu/MoO3",
#   "CNW",
#   "Au grids/PH1000",
#   "ZnO-Al",
#   "Ti1/CB",
#   "m-CNF",
#   "Graphite/CB",
#   "Carbon with CuPc",
#   "In:ZnO",
#   "B0.5%-CP",
#   "CB+Graphite",
#   "GO",
#   "IAI",
#   "TiN+Graphite",
#   "Bi",
#   "TWCNT",
#   "M0.1%-CP",
#   "graphene aerogel/Au",
#   "MC/Ti",
#   "Carbon w/ NiO",
#   "MoOx/ITO/Ag/ITO",
#   "AuCl3-doped monolayer graphene",
#   "Carbon w/ 17 wt% waste toner carbon",
#   "MOM (30/75/20)",
#   "GS",
#   "Ti/Au",
#   "LIG",
#   "ITO bilayer",
#   "PbZrO3",
#   "CP",
#   "PoA-PbZrO3",
#   "VO@CNF",
#   "Gold contact",
#   "VS4@CNF",
#   "Commercial Carbon",
#   "PNMPy-PoA-PbZrO3",
#   "NC",
#   "B0.1%-CP",
#   "Carbon w/ 23 wt% waste toner carbon",
#   "Liq",
#   "Textured front contact with nanoholes",
#   "Au buffer layer",
#   "GCEP",
#   "Pt-Ti foil",
#   "SA:c-ITO",
#   "CQDs",
#   "MoO3/Au/Cu/MoO3",
#   "Carbon w/ IPA",
#   "Au electrode with embedded NaYF4:Yb3+,Er3+ UCNPs",
#   "MoOx/ITO",
#   "Carbon Control",
#   "n++/p++ tunnel junction",
#   "Ag nanowires",
#   "N-Ti3C2@carbon",
#   "Sb",
#   "FTO-Glass",
#   "M0.5%-CP",
#   "Pearl carbon",
#   "Carbon electrode w/ OAI",
#   "AgNW:Ti3C2Tx",
#   "Carbon electrode w/ HDAI",
#   "NiO/Ag/NiO transparent electrode with UC layer",
#   "rGO/AgNWs/rGO",
#   "Carbon w/ 10 wt% waste toner carbon",
#   "MoOX",
#   "Ag yarn",
#   "DPP-F3N",
#   "MXene-V3C2F2",
#   "PNMPy-PbZrO3",
#   "Fe",
#   "Expanded graphite",
#   "Cr/Au",
#   "m-BCNF",
#   "Commercial Carbon w/ NiO",
#   "Ti3C2Tx",
#   "Ag fingers",
#   "Carbon w/ CB",
#   "BMG ITO",
#   "Carbon electrode w/ DAI",
#   "Pearl carbon w/ CAISSe NPs",
#   "TWCNT w/ H-PTAA",
#   "Ag front contact",
#   "Ti/Ag back contact",
#   "ITO/Au fingers"
# ]

# %%
etls = [m for m, _ in unique_names.get('Electron-transport', [])]
print(f'Electron transport layers ({len(etls)}): {etls}')

etl_synonyms = {
    'SnO2-c': [
        'SnO2',
        'SnO2-c',
        'SnOx',
        'c-SnO2',
        'ALD-SnO2',
        'SnO2-SnOx',
        'SnO2-x',
        'ALD-SnOx',
        'CBD-SnO2',
        'ALD SnOx',
        'Crystalline SnO2',
    ],
    'TiO2-c': [
        'TiO2-c',
        'TiO2',
        'c-TiO2',
        'Compact TiO2',
        'compact-TiO2',
        'cp-TiO2',
        'C-TiO2',
        'compact TiO2',
        'compacted TiO2',
        'TiO2 compact',
        'cTiO2',
        'TiO2 compact layer',
        'TiO2 CL',
        'Compact-TiO2',
    ],
    'C60': ['C60'],
    'PCBM-60': ['PCBM', 'PC60BM', 'PCBM-60'],
    'BCP': ['BCP'],
    'PC61BM': ['PC61BM'],
    'TiO2-mp': [
        'TiO2-mp',
        'mp-TiO2',
        'm-TiO2',
        'mesoporous TiO2',
        'TiO2 mesoporous',
        'Mesoporous TiO2',
        'mesoporous-TiO2',
        'meso-TiO2',
        'Mesoscopic TiO2',
        'mp TiO2',
        'ms-TiO2',
        'Meso.TiO2',
        'mpTiO2',
        'TiO2 scaffold',
        'M-TiO2',
        'Thin mp-TiO2',
    ],
    'TiO2-np': ['TiO2-np', 'TiO2-NPs'],
    'SnO2-np': [
        'SnO2-np',
        'SnO2 QD',
        'SnO2 QDs',
        'SnO2 NP',
        'SnO2 NPs',
        'np-SnO2',
        'QD-SnO2',
        'NP-SnO2',
        'SnO2 QDs-TQDs',
    ],
    'TiO2-bl': ['TiO2-bl', 'bl-TiO2', 'b-TiO2'],
}

etl_map = {}
for standard_etl, synonyms in etl_synonyms.items():
    if len(synonyms) < 2:
        continue
    for synonym in synonyms:
        etl_map[synonym] = standard_etl

unique_etls = []
for etl in etls:
    unique_etl = etl_map.get(etl, etl)
    if unique_etl not in unique_etls:
        unique_etls.append(unique_etl)

print(
    f'Unique electron transport layers after mapping ({len(unique_etls)}): {json.dumps(unique_etls, indent=2)}'
)
# Out:
# Electron transport layers (811): ['SnO2', 'TiO2', 'C60', 'PCBM', 'c-TiO2', 'BCP', 'PC61BM', 'm-TiO2', 'mp-TiO2', 'ZnO', 'ICBA', 'CdS', 'TiO2 mesoporous', 'SnOx', 'PC60BM', 'bl-TiO2', 'mesoporous TiO2', 'WS2', 'SnS2', 'ZnSe', 'Compact TiO2', 'TPBi', 'compact-TiO2', 'SnO2 QD', 'AZO', 'IGZO', 'ZnO NPs', 'Mesoporous TiO2', 'mesoporous-TiO2', 'TiO2-NPs', 'In2S3', 'ZnOS', 'C60-ETPA', 'cp-TiO2', 'C-TiO2', 'ZnO nanorods', 'Bphen', 'meso-TiO2', 'PC71BM', 'PFN-Br', 'ALD-SnO2', 'ETL', 'c-SnO2', 'compact TiO2', 'TiO2 nanorods', 'WO3', 'LiF', 'SnO2-KBr', 'PEI', 'PC61BM + C60', 'SnO2 QDs', 'TiOx', 'GO', 'SnO2-SnOx', 'b-TiO2', 'bathocuproine', 'CeO2', 'Mesoscopic TiO2', 'C60-SAM', 'ZnS', 'F8', 'PC61BM-C60', 'CdZnS', 'compacted TiO2', 'ZnMgO', 'SnO2-Cl', 'SnO2 NP', 'mp TiO2', 'LBSO', 'ZnO NP', 'SnO2 w/ urea', 'RbF-SnO2', 'NDP', 'TiO2/ZnO', 'Fe2O3', 'SnO2 NPs', 'TiO2 compact', 'CPTA', 'Li-TiO2', 'n-CsGeI3', 'Cd0.5Zn0.5S', 'i-ZnO', 'Bathocuproine', 'Meo-2PACz', 'ZnO@TiO2 NAs', 'PC61BM + TBABF4', 'AT-TiO2 NPs', 'Au/SnO2', 'TiO2 w/ AlCl3', 'SnO2-PbO', 'ZnO@ZnSe NAs', 'PCBM@DCBP', 'PDI', 'TiO2 paste', 'PC70BM w/ N-DMBI', 'SnO2-TiOxCl4-2x', 'BF4-SnO2', 'Li-treated c-TiO2', 'AH-SnO2', '2,9-dimethyl-4,7-diphenyl-1,10 phenanthroline', 'PbTiO3/TiO2', 'cTiO2', 'PCBM:EVA', 'TiO2 NRs', 'PY-DFT', 'PAA-EA-SnO2', 'SrSnO3', 'IZGO', 'PCBM:C60', 'SnO2-MXene', 'PC61BM:C60', 'C60MC12', 'Zn0.75Mg0.25O', 'SnO2 w/ GLDA and βA', 'OC', 'S,N-CQDs-SnO2', 'SnO2 w/ RbF', 'PCBM w/ TMDS', 'SnO2 w/ IGQDs', 'PCBM@TPP', 'PDIN', 'NDI-C4F', 'SnO2:PEIE', 'PCBM:PMMA', 'fullerene', 'TiO2 nanowires', 'ms-TiO2', 'SnO2-NiCl2', 'PCBM w/ DMAPF and N-DMBI', 'TAc-SnO2', 'TiO2:Al2O3', 'SnO2 w/ AC', 'M13-SnO2', 'Al-SnO2', 'SnO2-FACl', 'doped C60', 'SnCl2', 'SnO2/TMPU', '2PACz', 'ITO', 'Cl-SubPcF6', 'SnO2/PCBM', 'm-TiO2 w/ PCBM', 'CeOX', 'Ti2O3:Nb', 'SnO2-TiO2', 'SnO2/EGT', 'SnO2 w/ 3-AS', 'PM6:Y6:PC61BM', 'TiO2 w/ CDA', 'Y-doped TiO2', 'TiO2 compact layer', 'SnO2 w/ BEPBF4', 'Ti_Oxd', 'Li-doped mesoporous-TiO2', 'G-SnO2', 'α-Fe2O3', 'SnO2/NdCl3', 'PCBM+PMMA', 'SrTiO3', 'np-SnO2', 'PDADI', 'ITO/SnO2', 'MoS2', 'SnO2-DAC-AA', 'TiS2', 'SnO2/m-TiO2', 'Sb2O5@SnO2', 'SnO2:BPQDs', 'SnO2-STRS', 'SnO2 w/ GADET', 'SnO2 w/ LiF', 'PCBM:DTPTCY', 'TiO2 NRs w/ TCA', 'HATIC', 'AA-TiO2', 'SnO2:C-EDTA', 'BK TiO2 NPs', 'SAM', 'ZnO NPs w/ PVA', 'Bis-PC', 'Nb:TiO2', 'SnO2-x', 'ChCl-SnO2', 'Zn(O0.3,S0.7)', 'Sb-ZnO', 'S-PASP:SnO2', 'PANDI', 'SnO2 w/ MDACl2', 'FI-SnO2', 'Ti0.936O2@TiO2', 'FR-TiO2', 'SnO2-LHHM', 'TiO2:MXene', 'r-SnOx', 'PNDIT-F3N', 'BK TiO2 NPs w/ CsI', 'ZnTiO3-ZnS', 'PC70BM', 'a-Si:H (i/n)', 'hTiO2', 'mTiO2', 'SnO2-Li2CO3', 'SnO2@ZnO', 'V-doped ZnO', 'CeOx', 'ho-TiO2', 'SnO2+Gd', 'SnO2 w/ PAAm', 'SnO2-BCA', 'SnO2 w/ KMsO', 'QD-SnO2', 'Y6', 'C-SnO2', 'TiO2 nanowire arrays', 'ZTO', 'NP-SnO2', 'ALD-SnOx', 'PCBM:N2200', 'SnO2-Nb2C', 'PC61BM:BCP', 'SnS2/SnS', 'SnO2-KCl', 'Ti3C2Tx', 'CBD-SnO2', 'SnO2 w/ HCOONH4', 'TiO2-Li2CO3', 'BaTiO3', 'TiO2/Mg-SnO2', 'SnO2-PEIE', 'PCBM/MnSO4', 'CPTA-passivated SnO2', 'SnO2 w/ PASP', 'PFN-Br2', 'SnO2 w/ LiOTf', 'SnO2 w/ NHS', 'CN-TPACl', 'Sb2Ox', 'SnO2 w/ NCS', 'SnO2-poly(DAC-AA)', 'CPAN', 'PC-SnO2', 'SnO2-MH', 'SnO2 w/ CsPbBr3 nanocrystals', 'ZTO-ICN', 'MZO', 'SnO2/KF', 'SnO2 w/ BA', 'SnO2-NRs/Cl-BSM', 'Y-CE', 'TiON', 'Acac-TiO2 NPs', 'STO', 'TiO2-Cl', 'CSCO', 'c-TiO2/m-TiO2', 'Cr2O3/SnO2', 'MXene/CoS-SnO2', 'SnO2-GL', 'TiO2-SDBA-SnO2', 'FADD:ZnO', 'TiO2 NPs', 'SnO2 w/ PCC', 'Al2O3-graphene', 'SnO2 w/ KSCN-PEO', 'SnO2-TBHCl', 'TiO2/SnO2', 'H-SnO2', 'PCBM + C60', 'ZnO-ZnS', 'PDA: SnO2', 'F-TiOx-SnO2', 'Graded-TiO2:N', 'SnO2@ZnO.PANI 4%', 'BPQDs', 'ZnONPs', 'ZnO@ZnS core-shell nanorods', 'SnO2 w/ g-C3N5', 'CuO@PANI (1:1)', 'ALD SnOx', 'graphene-incorporating m-TiO2', 'SnO2 w/ ELAA', 'SnO2-HCl', 'SnO2/KBr', 'TiO2 NFs', 'SnO2 w/ KF', 'Er-TiO2', 'SnO2 w/ GQDs', 'TiO2-Cou', 'TiO2:5%Er3+, 5%Yb3+ + TiO2 + TiO2:1%Er3+, 3%Yb3+', 'Sn(S0.92Se0.08)2', 'SnO2 QDs-TQDs', 'TiO2 CL', 'AT TiO2 NPs', 'SnO2-PA', 'c&m-TiO2', 'SnO2-SA', 'TiOX', 'SnO2-BD', 'NDI-B:SnO2', 'PCBM+C60', 'SnO2-RbC ...
# Unique electron transport layers after mapping (767): [
#   "SnO2-c",
#   "TiO2-c",
#   "C60",
#   "PCBM-60",
#   "BCP",
#   "PC61BM",
#   "TiO2-mp",
#   "ZnO",
#   "ICBA",
#   "CdS",
#   "TiO2-bl",
#   "WS2",
#   "SnS2",
#   "ZnSe",
#   "TPBi",
#   "SnO2-np",
#   "AZO",
#   "IGZO",
#   "ZnO NPs",
#   "TiO2-np",
#   "In2S3",
#   "ZnOS",
#   "C60-ETPA",
#   "ZnO nanorods",
#   "Bphen",
#   "PC71BM",
#   "PFN-Br",
#   "ETL",
#   "TiO2 nanorods",
#   "WO3",
#   "LiF",
#   "SnO2-KBr",
#   "PEI",
#   "PC61BM + C60",
#   "TiOx",
#   "GO",
#   "bathocuproine",
#   "CeO2",
#   "C60-SAM",
#   "ZnS",
#   "F8",
#   "PC61BM-C60",
#   "CdZnS",
#   "ZnMgO",
#   "SnO2-Cl",
#   "LBSO",
#   "ZnO NP",
#   "SnO2 w/ urea",
#   "RbF-SnO2",
#   "NDP",
#   "TiO2/ZnO",
#   "Fe2O3",
#   "CPTA",
#   "Li-TiO2",
#   "n-CsGeI3",
#   "Cd0.5Zn0.5S",
#   "i-ZnO",
#   "Bathocuproine",
#   "Meo-2PACz",
#   "ZnO@TiO2 NAs",
#   "PC61BM + TBABF4",
#   "AT-TiO2 NPs",
#   "Au/SnO2",
#   "TiO2 w/ AlCl3",
#   "SnO2-PbO",
#   "ZnO@ZnSe NAs",
#   "PCBM@DCBP",
#   "PDI",
#   "TiO2 paste",
#   "PC70BM w/ N-DMBI",
#   "SnO2-TiOxCl4-2x",
#   "BF4-SnO2",
#   "Li-treated c-TiO2",
#   "AH-SnO2",
#   "2,9-dimethyl-4,7-diphenyl-1,10 phenanthroline",
#   "PbTiO3/TiO2",
#   "PCBM:EVA",
#   "TiO2 NRs",
#   "PY-DFT",
#   "PAA-EA-SnO2",
#   "SrSnO3",
#   "IZGO",
#   "PCBM:C60",
#   "SnO2-MXene",
#   "PC61BM:C60",
#   "C60MC12",
#   "Zn0.75Mg0.25O",
#   "SnO2 w/ GLDA and \u03b2A",
#   "OC",
#   "S,N-CQDs-SnO2",
#   "SnO2 w/ RbF",
#   "PCBM w/ TMDS",
#   "SnO2 w/ IGQDs",
#   "PCBM@TPP",
#   "PDIN",
#   "NDI-C4F",
#   "SnO2:PEIE",
#   "PCBM:PMMA",
#   "fullerene",
#   "TiO2 nanowires",
#   "SnO2-NiCl2",
#   "PCBM w/ DMAPF and N-DMBI",
#   "TAc-SnO2",
#   "TiO2:Al2O3",
#   "SnO2 w/ AC",
#   "M13-SnO2",
#   "Al-SnO2",
#   "SnO2-FACl",
#   "doped C60",
#   "SnCl2",
#   "SnO2/TMPU",
#   "2PACz",
#   "ITO",
#   "Cl-SubPcF6",
#   "SnO2/PCBM",
#   "m-TiO2 w/ PCBM",
#   "CeOX",
#   "Ti2O3:Nb",
#   "SnO2-TiO2",
#   "SnO2/EGT",
#   "SnO2 w/ 3-AS",
#   "PM6:Y6:PC61BM",
#   "TiO2 w/ CDA",
#   "Y-doped TiO2",
#   "SnO2 w/ BEPBF4",
#   "Ti_Oxd",
#   "Li-doped mesoporous-TiO2",
#   "G-SnO2",
#   "\u03b1-Fe2O3",
#   "SnO2/NdCl3",
#   "PCBM+PMMA",
#   "SrTiO3",
#   "PDADI",
#   "ITO/SnO2",
#   "MoS2",
#   "SnO2-DAC-AA",
#   "TiS2",
#   "SnO2/m-TiO2",
#   "Sb2O5@SnO2",
#   "SnO2:BPQDs",
#   "SnO2-STRS",
#   "SnO2 w/ GADET",
#   "SnO2 w/ LiF",
#   "PCBM:DTPTCY",
#   "TiO2 NRs w/ TCA",
#   "HATIC",
#   "AA-TiO2",
#   "SnO2:C-EDTA",
#   "BK TiO2 NPs",
#   "SAM",
#   "ZnO NPs w/ PVA",
#   "Bis-PC",
#   "Nb:TiO2",
#   "ChCl-SnO2",
#   "Zn(O0.3,S0.7)",
#   "Sb-ZnO",
#   "S-PASP:SnO2",
#   "PANDI",
#   "SnO2 w/ MDACl2",
#   "FI-SnO2",
#   "Ti0.936O2@TiO2",
#   "FR-TiO2",
#   "SnO2-LHHM",
#   "TiO2:MXene",
#   "r-SnOx",
#   "PNDIT-F3N",
#   "BK TiO2 NPs w/ CsI",
#   "ZnTiO3-ZnS",
#   "PC70BM",
#   "a-Si:H (i/n)",
#   "hTiO2",
#   "mTiO2",
#   "SnO2-Li2CO3",
#   "SnO2@ZnO",
#   "V-doped ZnO",
#   "CeOx",
#   "ho-TiO2",
#   "SnO2+Gd",
#   "SnO2 w/ PAAm",
#   "SnO2-BCA",
#   "SnO2 w/ KMsO",
#   "Y6",
#   "C-SnO2",
#   "TiO2 nanowire arrays",
#   "ZTO",
#   "PCBM:N2200",
#   "SnO2-Nb2C",
#   "PC61BM:BCP",
#   "SnS2/SnS",
#   "SnO2-KCl",
#   "Ti3C2Tx",
#   "SnO2 w/ HCOONH4",
#   "TiO2-Li2CO3",
#   "BaTiO3",
#   "TiO2/Mg-SnO2",
#   "SnO2-PEIE",
#   "PCBM/MnSO4",
#   "CPTA-passivated SnO2",
#   "SnO2 w/ PASP",
#   "PFN-Br2",
#   "SnO2 w/ LiOTf",
#   "SnO2 w/ NHS",
#   "CN-TPACl",
#   "Sb2Ox",
#   "SnO2 w/ NCS",
#   "SnO2-poly(DAC-AA)",
#   "CPAN",
#   "PC-SnO2",
#   "SnO2-MH",
#   "SnO2 w/ CsPbBr3 nanocrystals",
#   "ZTO-ICN",
#   "MZO",
#   "SnO2/KF",
#   "SnO2 w/ BA",
#   "SnO2-NRs/Cl-BSM",
#   "Y-CE",
#   "TiON",
#   "Acac-TiO2 NPs",
#   "STO",
#   "TiO2-Cl",
#   "CSCO",
#   "c-TiO2/m-TiO2",
#   "Cr2O3/SnO2",
#   "MXene/CoS-SnO2",
#   "SnO2-GL",
#   "TiO2-SDBA-SnO2",
#   "FADD:ZnO",
#   "TiO2 NPs",
#   "SnO2 w/ PCC",
#   "Al2O3-graphene",
#   "SnO2 w/ KSCN-PEO",
#   "SnO2-TBHCl",
#   "TiO2/SnO2",
#   "H-SnO2",
#   "PCBM + C60",
#   "ZnO-ZnS",
#   "PDA: SnO2",
#   "F-TiOx-SnO2",
#   "Graded-TiO2:N",
#   "SnO2@ZnO.PANI 4%",
#   "BPQDs",
#   "ZnONPs",
#   "ZnO@ZnS core-shell nanorods",
#   "SnO2 w/ g-C3N5",
#   "CuO@PANI (1:1)",
#   "graphene-incorporating m-TiO2",
#   "SnO2 w/ ELAA",
#   "SnO2-HCl",
#   "SnO2/KBr",
#   "TiO2 NFs",
#   "SnO2 w/ KF",
#   "Er-TiO2",
#   "SnO2 w/ GQDs",
#   "TiO2-Cou",
#   "TiO2:5%Er3+, 5%Yb3+ + TiO2 + TiO2:1%Er3+, 3%Yb3+",
#   "Sn(S0.92Se0.08)2",
#   "AT TiO2 NPs",
#   "SnO2-PA",
#   "c&m-TiO2",
#   "SnO2-SA",
#   "TiOX",
#   "SnO2-BD",
#   "NDI-B:SnO2",
#   "PCBM+C60",
#   "SnO2-RbCl",
#   "OA-TiO2",
#   "10%-LBSO-TiO2",
#   "SnO2/GP",
#   "s-SnO2",
#   "SnO2 w/ N-CQDs",
#   "SnO2 w/ NaF",
#   "SnO2/Y6",
#   "SnO2-Ti3C2",
#   "TiO2-CSBA",
#   "PCBA",
#   "mp-TiO2 w/ 3.75% m-rGO",
#   "meso-Sn:TiO2",
#   "SnO2 w/ NaPF6 + NH2-PEG-NH2",
#   "SnO2-PT",
#   "T-SnO2",
#   "DTMQ",
#   "ND-B-TiO2",
#   "2%Er-TiO2",
#   "SnO2 w/ HAL",
#   "SnO2@ZnO.PANI 6%",
#   "PCBM or C60 or TPBI",
#   "ZTO-S",
#   "WO3@SnO2",
#   "RGO:QDs",
#   "TiO2 modified with Pb(NO3)2",
#   "aligned TiO2 nanotube",
#   "ZTO-SnO2",
#   "m-TiO2 + G",
#   "AZO0",
#   "CH3NH3PbCl3",
#   "SnO2/urea",
#   "Ni:SnO2",
#   "Ppy",
#   "SnO2 w/ PhDMADBr",
#   "1% Cu-ZnO",
#   "PCBM w/ V2O5",
#   "SnO2-SDBS",
#   "SnO2 w/ KFSI",
#   "SnO2 w/ GQDs and Au QDs",
#   "gradient Sn-doped TiO2",
#   "meso-TiO2 w/ 2 wt% EC",
#   "Mesoporous TiO2 with 50% Ho3+-Yb3+-Li+ doped TiO2",
#   "SnO2 w/ PCBM",
#   "Blocking TiO2",
#   "SnO2 NRA-6h",
#   "PCBCB",
#   "Ppy@CuMoSe2",
#   "Spiro-OMeTAD",
#   "PPCBM",
#   "PM-SnO2",
#   "F4",
#   "MIL-125(Ti) derived TiO2",
#   "ZnO/Au",
#   "Cl-bonded SnO2",
#   "trans-4 DCBA",
#   "N-PDI",
#   "SnO2@ZnO.PANI 2%",
#   "DTQ",
#   "Cl-SubPcCl12",
#   "Li2CO3@C-SnO2",
#   "TiO2-PCBM",
#   "RGO:PCBM",
#   "ZnO w/ EDTA-K",
#   "SnO2 w/ BGCl",
#   "Alq3",
#   "Betaine-capped ZnO QDs w/ NH4Br",
#   "SnO2 w/ NH4+",
#   "SnO2 w/ AEP",
#   "SnO2-x w/ F-ISS",
#   "TiO2:YVO4:Eu3+,Bi3+",
#   "SnO2 w/ GAAc",
#   "TiO2 nanorod arrays",
#   "Ag-AZO",
#   "NPE-SnO2",
#   "CN-TPAI",
#   "m-TiO2/c-TiO2",
#   "ZnO w/ MgO",
#   "SnO2 w/ TiCl4",
#   "SnO2 w/ PVEM",
#   "Compact TiO2-ETL with CsPbBr3 layer",
#   "TiO2 NRs doped with Yb3+ and Er3+",
#   "SnO2 w/ Nb2CTOH",
#   "3%Er-TiO2",
#   "SnO2 double-layer",
#   "ms-TiO2 w/ TMAOH",
#   "PCBM/FPP",
#   "PbCl2-ZnO",
#   "ZAS",
#   "SnO2-PPA",
#   "CF3-FIDO",
#   "SnO2 w/ SnCl4",
#   "SnO2-BCA-2H",
#   "PCBM with MoSe2@CNT (30%)",
#   "Yb-doped SnO2",
#   "N-SnO2",
#   "modified ZnO",
#   "Ru:SnO2",
#   "Nb2CTx",
#   "PL-SnO2",
#   "TiO2-CdS",
#   "Nb-doped TiO2",
#   "CN-TPAMe",
#   "Cl@SnO2",
#   "SnO2 w/ PL-Glu",
#   "d-TiO2",
#   "KF-SnO2",
#   "PCBM w/ MgO",
#   "PCBM:AQF",
#   "SnO2-Ti3C2Tx QDs",
#   "RGO/mp-TiO2",
#   "Ag-doped ZnO 1wt%",
#   "CN-TPABr",
#   "IDL1",
#   "m-TiO2/RGO + Li",
#   "Sb-SnO2/SnO2",
#   "Li-SnO2",
#   "BaSnO3",
#   "SnO2:MAPbI3",
#   "ZnSnO3-HD",
#   "SnO2 w/ sodium trifluoroacetate",
#   "SnO2 w/ i-BACl",
#   "TiO2-Cin",
#   "a-WOx/SnO2",
#   "SnSe2-SnO2",
#   "C-C1-P",
#   "SnO2-Li2SO4",
#   "BCP/PVP",
#   "Au@TiO2 NRs",
#   "DTMQCl",
#   "mp-TiO2@ZrO2",
#   "e DCBA",
#   "TiO2-Caf",
#   "mp-TiO2:2D-MoS2 (1 wt.%)",
#   "TiO2 NRs doped with Er3+ and Yb3+",
#   "TiO2-RGO",
#   "SnO2/PA",
#   "B-TiO2-NAF",
#   "ZnO w/ PFPA",
#   "ZnO@C60",
#   "c(Li)-NP-SnO2",
#   "SnO2 w/ TMACl",
#   "nc-Si (n)",
#   "SnO2/TiO2 gradient heterojunction",
#   "Ti3C2Tx@TiO2",
#   "W-doped SnO2",
#   "PCBM@ND-B-TiO2",
#   "Ga-doped SnO2",
#   "paa-QD-SnO2",
#   "SnO2-PGA",
#   "ALN-SnO2",
#   "SnO2 bilayer",
#   "Cl-SubPcF12",
#   "CH3NH3PbCl3 w/ PVP",
#   "SPOS",
#   "SnO2 w/ GASCN",
#   "Betaine-capped ZnO QDs w/ NH4F",
#   "AZO5",
#   "PCBM with MoSe2@CNT (20%)",
#   "SnO2 w/ Zr-MOF",
#   "1D anatase TiO2 NRs",
#   "TiO2 w/ Ag NPs",
#   "BaZrS3",
#   "SnO2 w/ PAPT",
#   "AZO1",
#   "Mac-SnO2",
#   "SnO2 w/ EDTA",
#   "mp-SnO2",
#   "KiPX-SnO2",
#   "SnO2 w/ GA2SO4",
#   "SnO2-BiFeO3",
#   "SnO2 w/ CL-NH",
#   "DMEC70",
#   "Y-Sn3O4",
#   "SnO2 w/ PAA",
#   "5%-LBSO-TiO2",
#   "DCMA-SnO2",
#   "TiO2:GQDs",
#   "m-TiO2:CDs",
#   "F-B,N-C60-A2",
#   "R-SnO2",
#   "HCOONH4-SnO2",
#   "SnO2 w/ 2% GQD",
#   "Betaine-capped ZnO QDs",
#   "ZnSnN2",
#   "SnO2@SiW9Ni3",
#   "PAMAM G3",
#   "SC-TiO2",
#   "SnSe QDs w/ STRS",
#   "STF5",
#   "LiCl@PPy NCPs-TiO2",
#   "NiFe",
#   "6 mg/mL-Sm@m-SnO2",
#   "PCBM with MoSe2",
#   "Mesoporous TiO2 with 5% Eu doping",
#   "ZTO-ZnO",
#   "p-Al2O3",
#   "CBD-SnO2 w/ IAM",
#   "SnO2 w/ DCMA",
#   "SnO2 w/ DSDA",
#   "PEIE",
#   "D18-Cl:Y6:PC61BM",
#   "SnO2 w/ C60-SAM",
#   "SnO2:RCQs",
#   "SnO2-TiO2 hybrid",
#   "AZO2",
#   "H2O2-SnO2",
#   "3D G-CuInS2",
#   "CMC:ICBA",
#   "AZO-1",
#   "B,N-C60",
#   "CN-TPA",
#   "ZnO NW array",
#   "SnO2-BCA-2Na",
#   "ZnO w/ EDTA-Na",
#   "CdS-SnO2",
#   "C60/SnOX",
#   "SnO2-BCA-2K",
#   "SnO2-EDTA",
#   "trans-2 DCBA",
#   "SnO2 w/ BTDOH",
#   "F-B,N-C60-T1",
#   "p-SnO2",
#   "TiO2/WO3 bilayer",
#   "mp-TiO2 w/ CDCl",
#   "Y-Phen",
#   "CN-TPAOMe",
#   "DMEC60",
#   "TiO2:Sm31,Eu31",
#   "SnO2 w/ NaPF6",
#   "Li-doped m-TiO2",
#   "ZnO-NP",
#   "SnO2:SnS2",
#   "Electron transport layer",
#   "DTBTI",
#   "CBD-SSO",
#   "LiF/C60",
#   "PDI-3",
#   "SnO2 w/ GACl",
#   "AZO10",
#   "SnO2-NH3\u00b7H2O",
#   "PDI derivative 1",
#   "MOF-derived ZnO",
#   "C60-TAME",
#   "In2O3/SnO2",
#   "SP-SnO2",
#   "TiO2 w/ Na2S",
#   "SnO2-Ti3C2Tx",
#   "TiO2 bilayer",
#   "TiO2-ETL with Sr2CeO4:Sm3+ layer",
#   "TiO2 w/ \u03b2-NaYF4:Yb31/Er31/Sc31@NaYF4 UCNPs",
#   "ZnO@ZnS NRs",
#   "(anti,S)16,17-bis[60]PCBM",
#   "CSTO",
#   "AI-HAc-SnO2",
#   "CQDs:TiO2",
#   "SnO2 w/ 4% GQD",
#   "SnO2 w/ -C3-Cl SAM",
#   "SnO2-CMD",
#   "SnO2 w/ PS",
#   "TiOx-Au-TiOx",
#   "SnO2 with SnO2:PAN NWs",
#   "F-TiO2",
#   "F-B,N-C60-G1",
#   "IDIC",
#   "STF7",
#   "SnO2 quantum dots",
#   "Ws2",
#   "mp-TiO2:2D-MoS2 (0.25 wt.%)",
#   "mp-TiO2:perovskite composite layer",
#   "gradient F-doped SnO2",
#   "a-BaTiO3",
#   "SnO2/SbCl3",
#   "10a",
#   "bis(formato)dimethyltin(IV)",
#   "wts-TiO2",
#   "F-B,N-C60-G2",
#   "SnO2 w/ -C3\u2261N SAM",
#   "SnO2 w/ PA",
#   "2 mg/mL-Sm@m-SnO2",
#   "3TPYMB",
#   "ETL with Cu2-xS@SiO2@Er2O3 hybrid",
#   "CuInS2",
#   "TOAN",
#   "SnO2 w/ DLCH",
#   "Cl-SnO2",
#   "doped ZnO/SnO2",
#   "C60 w/ Al2O3",
#   "La-doped BaSnO3",
#   "SnO2 w/ BAC",
#   "PS600-SnO2",
#   "SnO2:SnF2",
#   "c-TiO2/mp-TiO2",
#   "PCBM w/ additives",
#   "AZO-2",
#   "meso-TiO2 w/ 1 wt% EC",
#   "CeO2-CuO",
#   "Acac-TiO2",
#   "TiO2 w/ Au@Ag nanorods",
#   "SnO2:CH3NH3PbI3",
#   "TiO2/60-PCBM",
#   "ZnO-Mg-EA(NH3+)",
#   "SnO2 w/ NaCl",
#   "TiO2/rGO NFs",
#   "TiO2 w/ Au@SiO2",
#   "m-SnO2",
#   "SnO2 w/ CsF",
#   "C60-BAME",
#   "PDI derivative 4",
#   "PCBH",
#   "TiO2/Cs2CO3",
#   "Mg-doped TiO2/Cs2CO3",
#   "PS480-SnO2",
#   "F-B,N-C60-C1",
#   "F-B,N-C60-T2",
#   "CsF-SnO2",
#   "PCBM with CNT",
#   "TmPyPB",
#   "ER-SnO2",
#   "ZnO NRAs",
#   "SnO2/TiS2",
#   "TiO2 w/ DACl",
#   "NH2-ZnO@SnO2",
#   "TiO2/Al2O3",
#   "TiO2-CdS-RGO",
#   "IO-SnO2",
#   "3% Cu-ZnO",
#   "mp-TiO2:2D-MoS2 (0.5 wt.%)",
#   "TiO2 w/ HFSTA",
#   "SnO2-NaCl",
#   "SnO2 w/ MB",
#   "CSCO-KCl",
#   "SnO2 w/ AMO",
#   "Zn(OAc)2-TiO2",
#   "SnO2-RbAc",
#   "SnO2/U-PA",
#   "ZnSnO3-MW",
#   "Cs:SnO2",
#   "SnO2 w/ RbDP",
#   "SnO2-BTF",
#   "4 mg/mL-Sm@m-SnO2",
#   "MOACl-SnO2",
#   "PCBM with MoSe2@CNT (10%)",
#   "Zr(acac)",
#   "NX-F",
#   "meso-TiO2 w/ 0.50 wt% EC",
#   "SnO2 w/ CB[5]",
#   "SnO2/ZnO",
#   "PCBM/FDPP",
#   "TiO2 w/ PMMA:PCBM",
#   "C60/SnO2",
#   "meso-TiO2 w/ 0.25 wt% EC",
#   "SnO2 w/ CsCl",
#   "SnO2-GUP",
#   "TiO2 nanosheet arrays",
#   "SnO2/Ti3C2Tx:m-SWCNT",
#   "C60-PMME",
#   "SnO2 w/ 4-DB",
#   "TiO2:1%Er3+, 3%Yb3+",
#   "LD-TiO2",
#   "SnO2 w/ NH4Cl",
#   "EDTA-doped SnO2",
#   "Au-decorated TiO2 nanorods",
#   "PCBM w/ MnO2",
#   "In2O3",
#   "PDI derivative 2",
#   "c(Li)-SnO2",
#   "Ag@ZnO NPs",
#   "F-B,N-C60-A1",
#   "A-SnO2",
#   "Mg-SnO2",
#   "SnO2 array (300 nm)",
#   "SnO2-AA",
#   "MoSe2",
#   "ZnO w/ EDTA",
#   "Betaine-capped ZnO QDs w/ NH4Cl",
#   "SnO2 w/ DABCO",
#   "15%-LBSO-TiO2",
#   "HO-Ti3C2Tx@Ti3C2Tx",
#   "SnO2-SBP",
#   "nano-ZnO",
#   "SnO2 w/ BTDTH",
#   "TiO2/PCBM",
#   "PCBM/C60",
#   "ZnO/PCBM",
#   "MQDs-SnO2",
#   "m-TiO2:ZnGa2O4:Eu3+",
#   "PS350-SnO2",
#   "C60 w/ Corannulene",
#   "PVP-SnO2",
#   "n-GaN NWs",
#   "Fullerene",
#   "ETL with NaYF4@NaYF4:Yb,Er UCNPs-NaCsWO3 hybrids",
#   "MPA-SnO2",
#   "p-TiO2",
#   "SnO2 w/ MSAK",
#   "(anti)16,17-bis[60]PCBM racemate",
#   "Nd-TiO2",
#   "SnO2 w/ 4-FAnHI",
#   "DPP",
#   "DCBA mixture",
#   "PAAQ",
#   "PCBM:CQF",
#   "SnO2-APS",
#   "GBG-Zn(S,O)",
#   "trans-3 DCBA",
#   "SnO2-MACl",
#   "MWCNT/Zn(COO)2",
#   "SnO2-BHCl",
#   "SnO2/TiO2/SnO2",
#   "c-NP-SnO2",
#   "KAc ETL",
#   "TiO2 nano-forests",
#   "SnO2 w/ Cl-bonded",
#   "Sn3O4",
#   "SnO2@RbCl",
#   "PC61BM w/ C60TPY",
#   "S-SnO2 NRA-6h",
#   "ZnO nanofibers",
#   "Fe2O3@SnO2",
#   "R-SnO2/O-SnO2",
#   "SnO2 w/ KCl",
#   "WS-C60",
#   "Nb2O5",
#   "HRhMOP:PCBM",
#   "STF1",
#   "ZnO/Ag",
#   "SnO2 array (400 nm)",
#   "Li-m-TiO2",
#   "FMG",
#   "Zn-doped TiO2",
#   "Zn2SnO4",
#   "Mono-PC",
#   "ZrS2",
#   "c-ZTO",
#   "Cr-ZTO nanoparticles",
#   "0.5%Er-TiO2",
#   "SG-SnO2",
#   "AZO NRAs",
#   "Buffer",
#   "TiO2 nanofibers",
#   "Al2O3",
#   "Ce-doped SnOx",
#   "SnO2 w/ NH2-PEG-NH2",
#   "SnO2 w/ RbCl",
#   "PCBM/FTPP",
#   "SnO2 w/ Tz-GDY",
#   "TiO2 dense",
#   "PDI derivative 3",
#   "TiO2 mesoporous layer with NaYF4:Yb3+ nanoprisms",
#   "APTES-linked C60",
#   "SnO2 w/ CL-BPh",
#   "SnO2-BPS",
#   "Zn(O0.3S0.7)",
#   "Cl-bSO",
#   "SnO2 w/ NH4PF6",
#   "SnO2 w/ SSB",
#   "Sm-doped SnO2",
#   "WO3/CPTA",
#   "Y:SnO2",
#   "AuNSs-TiO2/SnO2",
#   "SnO2-PVA",
#   "HAc-SnO2",
#   "NX-Cl",
#   "TiO2:5%Er3+, 5%Yb3+",
#   "Sn-doped TiO2",
#   "SnO2-Ti3C2Clx",
#   "SnO2 w/ 6% GQD",
#   "n+ POLO",
#   "m-TiO2 w/ TAA",
#   "4/10a",
#   "KFBS-SnO2",
#   "b-PEI",
#   "SnO2 w/ PS-Li",
#   "mp-TiO2 w/ 8-Oxychinoline",
#   "PNDI-BT/ICBA",
#   "In2O3/ZnO",
#   "STF3",
#   "SnO2-SDCDPS",
#   "SnO2 w/ DACl SAM",
#   "F-B,N-C60-C2",
#   "PCBM or C60 or BCP",
#   "SnO2-NRs",
#   "Cl-capped TiO2",
#   "2% Cu-ZnO",
#   "ZnO NWLs",
#   "TiO2 w/ Au@MgO",
#   "KAFA-SnO2",
#   "C\u2013Chl m-TiO2",
#   "Y-TiO2",
#   "PAMAM G1",
#   "NDC",
#   "GNRs",
#   "Mesoporous TiO2 with \u03b2-NaYF4:Yb3+/Tm3+@TiO2 core-shell UCNPs",
#   "ZnS-SnO2",
#   "n+-Si BSF",
#   "GQDs:SnO2",
#   "PF6-SnO2",
#   "GBG-ZnMgO",
#   "PCBM-PMMA",
#   "F-B,N-C60",
#   "T-Nb2CTx",
#   "SnO2:OH"
# ]

# %%
htls = [m for m, _ in unique_names.get('Hole-transport', [])]
print(f'Hole transport layers ({len(htls)}): {htls}')

htl_synonyms = {
    'Spiro-OMeTAD': [
        'Spiro-OMeTAD',
        'spiro-OMeTAD',
        'Spiro-MeOTAD',
        'spiro-MeOTAD',
        'SpiroOMeTAD',
        'spiroOMeTAD',
        'spiroMeOTAD',
        'SpiroMeOTAD',
        'spiro-OMETAD',
        'spiro-OSMeTAD',
        'spiro-MEOTAD',
        'spiro-OMeTAD (doped)',
        'Commercial spiro-OMeTAD',
        'spiro-SMeTAD',
        'Spiro',
    ],
    'NiOx': ['NiOx', 'NiO', 'NiOX'],
    'PTAA': ['PTAA'],
    'PEDOT:PSS': ['PEDOT:PSS', 'PEDOT', 'PEDOT/PSS', 'PEDOT-PSS'],
    'MeO-2PACz': ['MeO-2PACz', 'MeO-2PACZ', 'MeO-2PACz SAM', 'Meo-2PACz'],
    '2PACz': ['2PACz', '2PACZ'],
    'P3HT': ['P3HT'],
    'Me-4PACz': ['Me-4PACz', '4PACz', 'Me-4PACZ'],
    'CuSCN': ['CuSCN'],
    'Cu2O': ['Cu2O'],
    'CuI': ['CuI'],
    'SAM': ['SAM'],
    'MeO-4PACz': ['MeO-4PACz'],
}

htl_map = {}
for standard_htl, synonyms in htl_synonyms.items():
    if len(synonyms) < 2:
        continue
    for synonym in synonyms:
        htl_map[synonym] = standard_htl

unique_htls = []
for htl in htls:
    unique_htl = htl_map.get(htl, htl)
    if unique_htl not in unique_htls:
        unique_htls.append(unique_htl)

print(
    f'Unique hole transport layers after mapping ({len(unique_htls)}): {json.dumps(unique_htls, indent=2)}'
)
# Out:
# Hole transport layers (1080): ['Spiro-OMeTAD', 'spiro-OMeTAD', 'NiOx', 'PTAA', 'PEDOT:PSS', 'Spiro-MeOTAD', 'MeO-2PACz', 'P3HT', 'NiO', 'Me-4PACz', 'CuSCN', 'Cu2O', '2PACz', 'CuI', 'spiro-MeOTAD', 'SAM', 'MeO-4PACz', 'NiOX', 'MoO3', 'P3CT-N', 'CBTS', 'HTL', '4PADCB', 'CuInS2', 'TaTm', 'PDCBT', 'SpiroOMeTAD', 'CuPc', 'CFTS', 'CuO', 'PEDOT', 'CdTe', 'PTAA:F4-TCNQ', 'Cu:NiOx', 'V2O5', 'Carbon', 'CZTS', 'Spiro-TTB', 'CuSbS2', 'PTB7', 'PBDB-T', 'GO', 'CuOx', 'poly-TPD', 'CuAlO2', 'PolyTPD', 'SAMs', 'CbzNaph', 'Me-4PAcz', 'Spiro-OMETAD', 'Spiro-OmeTAD', 'MoOx', 'Me4PACz', 'Spiro', 'MASnBr3', 'PTAA:F4TCNQ', 'TFB', 'Spiro-OMeOTAD', 'VNPB', 'cp-NiOx', 'LaNiO3', 'CZTSe', 'PANI-PAMPSA', 'MoS2', 'MPA-CPA', 'MoTe2', '4PACz', 'MeO-2PACz:Me-4PACz', 'Ph-4PACz', 'Cu:NiOX', 'TAPC', 'PTA', 'PM6', 'BDT-C8-3O', 'rGO', 'PVA + F-127 + KI + I2', 'A-PEDOT:PSS', 'poly(triarylamine)', 'NiOx:Sr', 'CuCrO2', 'NiO NPs', 'SAM (2PACz and Me-4PACz)', '2PACZ', 'spiroOMeTAD', 'D18-Cl', 'Spiro-OMeTAD w/ TCPO', 'p-CsGeI3', 'VB-FNPD', 'EMIC-PEDOT:PSS', 'PTB7-Th', 'NiOx@VNPB', 'SAB', 'Cu2ZnSnS4', 'PTAA:Ce3+', 'PTPD', 'MeO-2PACZ', 'PEDOT:PSS w/ PM6', 'FTPE-OSMe', 'PbS-EDT', 'ZnTe', 'Spiro-OMeTAD w/ Co(III)TFSI', 'PCBM', 'Eu:NiOx', 'I-/I3- electrolyte', 'P3CT-Cs', 'D-PBTTT-14', 'spiro-OMeTAD w/ Mn complex', 'Mg-CuCrO2', 'Spiro-OMeTAD w/ C@NiO', 'Bz-PhpPACz', 'PTAA-P1', 'TTPA-mF', 'Cl-2PACz', 'TTPA-iF', 'CuSeCN', 'CuScO2', 'P1', 'Spiro-OMeTAD w/ C8A', 'TPA-NiOx', 'polyTPD', 'Spiro-OMeTAD:PTAA', 'Poly-TPD', 'Ph-2PACz', 'MeO-2PACz SAM', 'MeO-2PACz:2PACz', 'PFI', 'CbzNaphPPA', '2PACz-3-UA', 'DC-TMPS', 'I-2PACz', 'CPDA 1', 'H101', 'SMe-TPA-CuPc', 'NiO@SAM', 'spiro-OMeTAD w/ SnSO', 'BTP1', 'MB-NiO', '2FMPA-BT-BA', 'BCzSPA', 'DFBT-PMTP', 'NiOx w/ CsI', 'Cs2SnI6', 'spiroMeOTAD', 'PEDOT/PSS', 'SpiroMeOTAD', 'PEDOT:PSS-N0.12GO', 'HTM', 'Carbon electrode from waste tires', 'PCPDTBT', 'Me-4PACz/AG', 'NiOx w/ KBr', 'PEDOT:PSS w/ CEPA', 'PTAA-BCF', 'NiOx w/ [EMIM]PF6', 'hc-PEDOT:PSS', 'PEDOT:PSS w/ CG', '4PACDF', 'CuS', 'Spiro-OMeTAD w/ Li-TFSI', 'Li-P3HT', 'MAP-CPA', 'CbzBT', 'P3HT-COOH', 'compact NiO', 'PTPY', 'MeO-2PACz w/ MXene', 'c-NiOx', 'PEDOT:PSS PH 1000 w/ OPC', '79', 'Ni/NiOx', 'Spiro-OMeTAD w/ TA', 'Mx-SAM', 'SBF-FC with TBPHTFSI', 'PEDOT:PSS w/ D-glucamine', 'Sb2S3', 'PFNBr', 'Mixed SAM (MeO-2PACz:Me-4PACz 3:1)', 'FTPE-ST', 'NiCo2O4', 'Spin-NiOx', 'NP-NiOx', 'B-20', 'Cu2GeS3', 'MeO-BTBT', 'Spiro-OMeTAD w/ GADET', 'LaFeO3@C/C', 'MeO-PhPACz', 'PVK', 'Meo-2PACz', 'SWPC-PEDOT:PSS', 'spiro-TTB', 'Mixed SAM', 'X60', 'NY-04', 'CuInS2 QDs', 'NiOx@Me-2PACz', 'PTZ-CPA', 'FeS2', 'P3HT w/ 4-ABA', 'P3HT:5CB', 'spiro-OMeTAD w/ O2- doping', 'PEDN', 'BTDC', 'optNiOx', 'spiro-OMeTAD w/ TA', 'CI-TTIN-2F', 'PH1000', 'NiO:Cu', 'Mg:CoOx', 'P3HT/c-MWCNT', 'Al2CdSe4', 'DMAcPA', 'NiOBu-MeAMD', 'Al:NiOBu-MeAMD', 'PTAA w/ PFN-Br', 'spiro-OMeTAD/BQX-2', 'PF', 'PFBTI', 'MD', 'DTTP-ThSO', 'spiro-OMETAD', 'CMTS', 'p-DM', 'P3HT 338 kDa/76%', 'MPA-Ph-CA', 'spiro-OMeTAD/BQX-1', 'IDIDF2', 'SF71', 'Spiro-OMeTAD w/ Tp-Azo-COF', 'APTES/TFSA-doped graphene', 'Spiro-OMeTAD w/ LiTFSI and t-BP', 'CuGaO2', 'T2', 'CuInSe2', 'Zn-BL54', 'NiPc', 'NCz-DM', 'DC-PA', 'phthalocyanine derivative', 'NY-03', 'HL38', 'P3HT-PTAA', 'p-BM', 'P3BT', 'IDIDF', 'TEA-NiOx', '2-layered graphene', 'CZTSSe', 'YJS003', 'BD', 'Mg:CuCrO2', 'PPTZ', 'PTAA w/ Al2O3', 'graphene/MoO3', 'spiro-OSMeTAD', 'WBH-P3HT', 'LiTSO', 'CzAn', 'MnS', 'CIS', 'NiOx/Trp', 'DM', 'WH01', 'FTPE-OMe', 'Br-2EPSe', 'CuxO', 'PEDOT:Cx', 'P2', 'Nap-SiBTA', 'SWCNTs', 'CB', 'CbzPPA', 'CNTS', 'SFX-MeOTAD', 'MeO-2PACz/Me-4PACz', 'PPE2', '82', 'Water-free PEDOT', 'MePA-CPA', 'NiOx:Cu', 'PE10', 'Organic electrolyte', 'M:CCO', 'TaTm/PEDOT', 'NiO w/ Ala', 'HTL with 0.1 wt% Li(Gd/Y)F4:Yb/Er UCNPs', 'spiro-mCl', 'n-NiOx', 'JY6', 'WO3', 'spiro-OMeTAD w/ LiTFSI', 'XF3', '83', 'p-O5H-E-POZ-E', 'a-BTC', 'NY-02', 'a-BTBC', 'PEDOT-PSS', 'PDBD-T', 'Br-2EPT', 'HYC-oF', 'YJS001', 'NiOx NPs', 'SL22', 'SpiroPT', 'ISC-HTL', 'Py-DB', 'CzCOPXZ:PTAA', 'PTAA:LiTFSI:tBP', 'Mixed SAM (tBu-4PAC ...
# Unique hole transport layers after mapping (1055): [
#   "Spiro-OMeTAD",
#   "NiOx",
#   "PTAA",
#   "PEDOT:PSS",
#   "MeO-2PACz",
#   "P3HT",
#   "Me-4PACz",
#   "CuSCN",
#   "Cu2O",
#   "2PACz",
#   "CuI",
#   "SAM",
#   "MeO-4PACz",
#   "MoO3",
#   "P3CT-N",
#   "CBTS",
#   "HTL",
#   "4PADCB",
#   "CuInS2",
#   "TaTm",
#   "PDCBT",
#   "CuPc",
#   "CFTS",
#   "CuO",
#   "CdTe",
#   "PTAA:F4-TCNQ",
#   "Cu:NiOx",
#   "V2O5",
#   "Carbon",
#   "CZTS",
#   "Spiro-TTB",
#   "CuSbS2",
#   "PTB7",
#   "PBDB-T",
#   "GO",
#   "CuOx",
#   "poly-TPD",
#   "CuAlO2",
#   "PolyTPD",
#   "SAMs",
#   "CbzNaph",
#   "Me-4PAcz",
#   "Spiro-OMETAD",
#   "Spiro-OmeTAD",
#   "MoOx",
#   "Me4PACz",
#   "MASnBr3",
#   "PTAA:F4TCNQ",
#   "TFB",
#   "Spiro-OMeOTAD",
#   "VNPB",
#   "cp-NiOx",
#   "LaNiO3",
#   "CZTSe",
#   "PANI-PAMPSA",
#   "MoS2",
#   "MPA-CPA",
#   "MoTe2",
#   "MeO-2PACz:Me-4PACz",
#   "Ph-4PACz",
#   "Cu:NiOX",
#   "TAPC",
#   "PTA",
#   "PM6",
#   "BDT-C8-3O",
#   "rGO",
#   "PVA + F-127 + KI + I2",
#   "A-PEDOT:PSS",
#   "poly(triarylamine)",
#   "NiOx:Sr",
#   "CuCrO2",
#   "NiO NPs",
#   "SAM (2PACz and Me-4PACz)",
#   "D18-Cl",
#   "Spiro-OMeTAD w/ TCPO",
#   "p-CsGeI3",
#   "VB-FNPD",
#   "EMIC-PEDOT:PSS",
#   "PTB7-Th",
#   "NiOx@VNPB",
#   "SAB",
#   "Cu2ZnSnS4",
#   "PTAA:Ce3+",
#   "PTPD",
#   "PEDOT:PSS w/ PM6",
#   "FTPE-OSMe",
#   "PbS-EDT",
#   "ZnTe",
#   "Spiro-OMeTAD w/ Co(III)TFSI",
#   "PCBM",
#   "Eu:NiOx",
#   "I-/I3- electrolyte",
#   "P3CT-Cs",
#   "D-PBTTT-14",
#   "spiro-OMeTAD w/ Mn complex",
#   "Mg-CuCrO2",
#   "Spiro-OMeTAD w/ C@NiO",
#   "Bz-PhpPACz",
#   "PTAA-P1",
#   "TTPA-mF",
#   "Cl-2PACz",
#   "TTPA-iF",
#   "CuSeCN",
#   "CuScO2",
#   "P1",
#   "Spiro-OMeTAD w/ C8A",
#   "TPA-NiOx",
#   "polyTPD",
#   "Spiro-OMeTAD:PTAA",
#   "Poly-TPD",
#   "Ph-2PACz",
#   "MeO-2PACz:2PACz",
#   "PFI",
#   "CbzNaphPPA",
#   "2PACz-3-UA",
#   "DC-TMPS",
#   "I-2PACz",
#   "CPDA 1",
#   "H101",
#   "SMe-TPA-CuPc",
#   "NiO@SAM",
#   "spiro-OMeTAD w/ SnSO",
#   "BTP1",
#   "MB-NiO",
#   "2FMPA-BT-BA",
#   "BCzSPA",
#   "DFBT-PMTP",
#   "NiOx w/ CsI",
#   "Cs2SnI6",
#   "PEDOT:PSS-N0.12GO",
#   "HTM",
#   "Carbon electrode from waste tires",
#   "PCPDTBT",
#   "Me-4PACz/AG",
#   "NiOx w/ KBr",
#   "PEDOT:PSS w/ CEPA",
#   "PTAA-BCF",
#   "NiOx w/ [EMIM]PF6",
#   "hc-PEDOT:PSS",
#   "PEDOT:PSS w/ CG",
#   "4PACDF",
#   "CuS",
#   "Spiro-OMeTAD w/ Li-TFSI",
#   "Li-P3HT",
#   "MAP-CPA",
#   "CbzBT",
#   "P3HT-COOH",
#   "compact NiO",
#   "PTPY",
#   "MeO-2PACz w/ MXene",
#   "c-NiOx",
#   "PEDOT:PSS PH 1000 w/ OPC",
#   "79",
#   "Ni/NiOx",
#   "Spiro-OMeTAD w/ TA",
#   "Mx-SAM",
#   "SBF-FC with TBPHTFSI",
#   "PEDOT:PSS w/ D-glucamine",
#   "Sb2S3",
#   "PFNBr",
#   "Mixed SAM (MeO-2PACz:Me-4PACz 3:1)",
#   "FTPE-ST",
#   "NiCo2O4",
#   "Spin-NiOx",
#   "NP-NiOx",
#   "B-20",
#   "Cu2GeS3",
#   "MeO-BTBT",
#   "Spiro-OMeTAD w/ GADET",
#   "LaFeO3@C/C",
#   "MeO-PhPACz",
#   "PVK",
#   "SWPC-PEDOT:PSS",
#   "spiro-TTB",
#   "Mixed SAM",
#   "X60",
#   "NY-04",
#   "CuInS2 QDs",
#   "NiOx@Me-2PACz",
#   "PTZ-CPA",
#   "FeS2",
#   "P3HT w/ 4-ABA",
#   "P3HT:5CB",
#   "spiro-OMeTAD w/ O2- doping",
#   "PEDN",
#   "BTDC",
#   "optNiOx",
#   "spiro-OMeTAD w/ TA",
#   "CI-TTIN-2F",
#   "PH1000",
#   "NiO:Cu",
#   "Mg:CoOx",
#   "P3HT/c-MWCNT",
#   "Al2CdSe4",
#   "DMAcPA",
#   "NiOBu-MeAMD",
#   "Al:NiOBu-MeAMD",
#   "PTAA w/ PFN-Br",
#   "spiro-OMeTAD/BQX-2",
#   "PF",
#   "PFBTI",
#   "MD",
#   "DTTP-ThSO",
#   "CMTS",
#   "p-DM",
#   "P3HT 338 kDa/76%",
#   "MPA-Ph-CA",
#   "spiro-OMeTAD/BQX-1",
#   "IDIDF2",
#   "SF71",
#   "Spiro-OMeTAD w/ Tp-Azo-COF",
#   "APTES/TFSA-doped graphene",
#   "Spiro-OMeTAD w/ LiTFSI and t-BP",
#   "CuGaO2",
#   "T2",
#   "CuInSe2",
#   "Zn-BL54",
#   "NiPc",
#   "NCz-DM",
#   "DC-PA",
#   "phthalocyanine derivative",
#   "NY-03",
#   "HL38",
#   "P3HT-PTAA",
#   "p-BM",
#   "P3BT",
#   "IDIDF",
#   "TEA-NiOx",
#   "2-layered graphene",
#   "CZTSSe",
#   "YJS003",
#   "BD",
#   "Mg:CuCrO2",
#   "PPTZ",
#   "PTAA w/ Al2O3",
#   "graphene/MoO3",
#   "WBH-P3HT",
#   "LiTSO",
#   "CzAn",
#   "MnS",
#   "CIS",
#   "NiOx/Trp",
#   "DM",
#   "WH01",
#   "FTPE-OMe",
#   "Br-2EPSe",
#   "CuxO",
#   "PEDOT:Cx",
#   "P2",
#   "Nap-SiBTA",
#   "SWCNTs",
#   "CB",
#   "CbzPPA",
#   "CNTS",
#   "SFX-MeOTAD",
#   "MeO-2PACz/Me-4PACz",
#   "PPE2",
#   "82",
#   "Water-free PEDOT",
#   "MePA-CPA",
#   "NiOx:Cu",
#   "PE10",
#   "Organic electrolyte",
#   "M:CCO",
#   "TaTm/PEDOT",
#   "NiO w/ Ala",
#   "HTL with 0.1 wt% Li(Gd/Y)F4:Yb/Er UCNPs",
#   "spiro-mCl",
#   "n-NiOx",
#   "JY6",
#   "WO3",
#   "spiro-OMeTAD w/ LiTFSI",
#   "XF3",
#   "83",
#   "p-O5H-E-POZ-E",
#   "a-BTC",
#   "NY-02",
#   "a-BTBC",
#   "PDBD-T",
#   "Br-2EPT",
#   "HYC-oF",
#   "YJS001",
#   "NiOx NPs",
#   "SL22",
#   "SpiroPT",
#   "ISC-HTL",
#   "Py-DB",
#   "CzCOPXZ:PTAA",
#   "PTAA:LiTFSI:tBP",
#   "Mixed SAM (tBu-4PACz:MeO-2PACz)",
#   "Syl-SC",
#   "DF-3 w/ LiTFSI and t-BP",
#   "2PACz:3-MPA",
#   "Me-4PACz/FBA",
#   "SAM/POM",
#   "CuPC",
#   "D12",
#   "Se/Te:Cu2O",
#   "BDT-DC8",
#   "Poly-DBPP",
#   "YSH-oF",
#   "M130",
#   "SL21",
#   "Spiro-OMeTAD w/ PEAI",
#   "NiOx/SaC-100",
#   "SF67",
#   "Spiro-OMeTAD w/ FG",
#   "NBD-Pyz",
#   "WH02",
#   "WSe2",
#   "Cu:Ni1-xO",
#   "DMeTPA",
#   "PEDOT-PSSA",
#   "MDMO-PPV",
#   "Spiro-OMeTAD w/ 5D doping",
#   "NiOx w/ 2DPP",
#   "BiO-BDC-NH2",
#   "Spiro-OMeTAD w/ MWCNT-1",
#   "DTP-1",
#   "XS7",
#   "Spiro-OMeTAD+PC",
#   "BFM-C1",
#   "0.5 mol% Mn-doped NiOx",
#   "ALD-NiOx",
#   "NiOx w/ 2-IBA",
#   "asy-PBTBDT",
#   "SP-NiOx",
#   "Mixed SAM (2PACz/MeO-2PACz)",
#   "UV-NiOx",
#   "Phen-TPA",
#   "PPr-BT-14",
#   "Spiro-OMeTAD w/ MPT",
#   "oCVD PEDOT-Cl",
#   "PBPyT-in",
#   "In-PEDOT:PSS",
#   "Spiro-OMeTAD w/ FePP",
#   "PEDOT:PSS dedoped with 20% NaOH",
#   "Redox electrolyte",
#   "PyBDP-2",
#   "36ICzC4PA",
#   "PE64",
#   "PMO-MeSO4",
#   "PyAA-MeO",
#   "XJ3",
#   "hm-HTL",
#   "DF-3",
#   "Spiro-OMeTAD w/ CNH",
#   "P3OT",
#   "4PADCB + NNN-BO",
#   "Ti3C2Tx-PEDOT:PSS",
#   "NiO w/ C132-8COOH",
#   "PEDOT-t-PASA",
#   "spiro-mF",
#   "S-BA-SAM",
#   "DTC",
#   "HY5",
#   "NiOx w/ PAM-0.10",
#   "81",
#   "H-BFM-C1",
#   "spiroOMeTAD w/ m-CPBA",
#   "PT-H",
#   "FF-OMeTPA",
#   "TPTI-TPA2F",
#   "P3HT w/ IP-TFSI",
#   "DTB-FL",
#   "PTAA w/ PVN",
#   "TADM3",
#   "PEDOT:PSS w/ HIS",
#   "TTC-Cl",
#   "CuIn0.5Ga0.5S2",
#   "Electrolyte solution",
#   "MeO-2PACz+TBA",
#   "NiOx w/ ABA",
#   "spiro-OMe2Im",
#   "4PADCB/MPA Co-SAMs",
#   "Mixed SAM (MeO-2PACz and Me-4PACz)",
#   "PEDOT-PAMPSNa",
#   "Spiro-OMeTAD w/ MWCNT-3",
#   "HTAB-NiOx",
#   "BTZ30",
#   "G-P3HT",
#   "G-NiOx",
#   "P3CT-CH3NH2",
#   "Co-SAM (2PACz:glycine)",
#   "HY6",
#   "PTAA w/ T35FP",
#   "PTAA-ID",
#   "B-TPA",
#   "PTPD w/ DPI-UV",
#   "CH3NH3SnI3",
#   "G-EDA",
#   "DTTP-TPA",
#   "Spiro-OMeTAD w/ MIL-88B-NH2",
#   "np6-NiOx",
#   "PolyZnPor",
#   "TADM5",
#   "DF-1",
#   "PE52",
#   "5b",
#   "Spiro-MeOTAD w/ 2-ThMAB",
#   "10-NiCo2O4",
#   "TPA-9O",
#   "Azu-2F6T",
#   "TPA-ADP 2",
#   "4-aminobenzoic acid",
#   "Li0.05Mg0.15NiOx",
#   "TPADPP-Boc",
#   "PEDOT:PSS w/ P3",
#   "ICZ-R",
#   "CX1",
#   "EBT",
#   "PEDOT:PSS w/ PANI",
#   "SC-PEDOT",
#   "Cu:NiOx/PTAA",
#   "PyPTPDAn",
#   "PEDOT:PSS w/ KBF4",
#   "SBF-FC with TBPHHFSI",
#   "RGO",
#   "PEDOT:PSS w/ KSt",
#   "2Cz-OMeDPA",
#   "BT-T",
#   "NC-PEDOT:PSS",
#   "PE2",
#   "B-DPT",
#   "PBTA-8",
#   "JY5",
#   "He-CZ-PTZ",
#   "NiOx1",
#   "MPTCZ-FNP",
#   "SAM/POM(PPD)",
#   "HTM-F-CL",
#   "PCP-a",
#   "HTM-FX'",
#   "gradient PEDOT:PSS-PEDOT:PSS(VOx)",
#   "Me-4PACz/MeO-2PACz",
#   "CP1",
#   "np9-NiOx",
#   "alkoxy-PTEG",
#   "PEDOT:PSS w/ NiO@W2C",
#   "EH44",
#   "P3HT-ID",
#   "Spiro-OMeTAD w/ CuSCN",
#   "SP-Naph",
#   "PT-Cz30",
#   "SiGe",
#   "Spiro-OMeTAD w/ COF@TCNQ",
#   "PEDOT:PSS w/ PANI-CdO (1%)",
#   "5-NiCo2O4",
#   "PEDOT:PSS-(2-Py)",
#   "Spiro-MeOTAD w/ LiPFSI",
#   "PTZT",
#   "DIM",
#   "P-SnOx",
#   "MC-1",
#   "CoOx",
#   "NiOx/BAEE",
#   "Spiro-MeOTAD:P3HT (88:12)",
#   "np15-NiOx",
#   "NiOx w/ 2-IBSA",
#   "NiOx + 6FPPY",
#   "Spiro-OMeTAD w/ BT-400",
#   "NiOx/CoPcevap",
#   "R-P3HT",
#   "CBZ-BDMTPA",
#   "XL7",
#   "cor-OMePTPA",
#   "CH3NH3SnBr3",
#   "S01",
#   "HTL w/ Au nanobipyramids",
#   "IDL2",
#   "Spiro-OMeTAD w/ Zn(TFSI)2",
#   "P65",
#   "PTOAA",
#   "Br-2EPO",
#   "LiCoO2",
#   "Aza-BODIPY 3",
#   "TC-36",
#   "SP-SMe",
#   "MC-4",
#   "PE53",
#   "Cor-SMePTPA",
#   "NiO w/ ABA",
#   "2-PACz",
#   "Mo2C-CNT@PEDOT:PSS",
#   "PEDOT:PSS w/ K2SnO3",
#   "CI-GO",
#   "PTTA",
#   "2 mol% Mn-doped NiOx",
#   "WO3-x/P3HT",
#   "PEDOT:PTP",
#   "NiOx-SAM",
#   "PEDOT:PSS w/ NaSt",
#   "TEG-CZ-POZ",
#   "nano-GDY:Spiro-OMeTAD",
#   "PPE1",
#   "P-Nano SnOx",
#   "BEpo-SAM",
#   "TM-01",
#   "NiOx w/ 2-IPBA",
#   "WH-2",
#   "TCTA-BVP",
#   "MeO5PECz",
#   "CX2",
#   "TPA-T-PE (2E)",
#   "TP-CA",
#   "PBCz-BTz",
#   "CQ8",
#   "S-4PADCB",
#   "2Cz-OMeDPA-OH",
#   "Cu2O nanoparticles",
#   "Z26",
#   "MC-5",
#   "a-Si:H (p)",
#   "PBTA-26",
#   "Spiro-OMeTAD w/ MOF-545",
#   "DBT5-COMe",
#   "H-CuO",
#   "Spiro-NADF",
#   "Spiro-OMeTAD w/ nanopattern",
#   "Spiro-OMeTAD + P(NDI2OD-T2)",
#   "Nap-SiBTz",
#   "PolyNiPor",
#   "PEDOT-i-PASA",
#   "PE51",
#   "NiOx-Pc",
#   "0-NiCo2O4",
#   "4Cz-OMeDPA-OH",
#   "HTM-F",
#   "BDT-POZ",
#   "TPA-AA",
#   "4dp3PACz",
#   "4Cz-OMeDPA",
#   "Spiro-OMeTAD w/ IP-PF6",
#   "NiOx w/ 2% Al",
#   "SWCNT",
#   "TM-14",
#   "IDCz-3",
#   "H-BSe",
#   "XJ2",
#   "M-CuO",
#   "XC2-H",
#   "YKP05",
#   "Co3O4-SrCO3",
#   "3Cz-OMeDPA-OH",
#   "spiro-OMeTAD w/ [Er@C82]",
#   "XS8",
#   "Cz-OMeDPA",
#   "Spiro-OMeTAD w/ TBP complex",
#   "DBT5-SH",
#   "P3HT:CuPc",
#   "PTQ10",
#   "TM-02",
#   "glycine",
#   "PyAA-Br",
#   "3Cz-OMeDPA",
#   "DC-1",
#   "PTAA-P2",
#   "B-00",
#   "XF1",
#   "PE65",
#   "PBCz-FBTz",
#   "gradient Spiro-OMeTAD",
#   "compound 2",
#   "V1431",
#   "Spiro-OMeTAD w/ IP-TFSI",
#   "HYC-H",
#   "ZnCo2O4",
#   "HTM-H-CL",
#   "HTM1",
#   "PyTPA-2OH",
#   "YSH-mF",
#   "BT-TT",
#   "Asy-PSeDTS",
#   "PTZT-MPF",
#   "GQD",
#   "spiro-OMeTAD w/ BATFSI",
#   "CuOx QDs",
#   "NiO w/ Gly",
#   "TADM2",
#   "X60+PC",
#   "Spiro-OMeTAD w/ spiro-T",
#   "DMeOTPA-O",
#   "PolyNiChl",
#   "YN1",
#   "Spiro-OMeTAD w/ BMPIP-TFSI",
#   "4-(2-aminoethyl)benzoic acid",
#   "Spiro-OMeTAD w/ TBP",
#   "WH-3",
#   "m-CP",
#   "MeO-4Pacz",
#   "NiOx-IL",
#   "B1",
#   "NiOx w/ TFOA",
#   "PyAA",
#   "Spiro-OMeTAD w/ PCN-224 QDs",
#   "NiOx5A",
#   "compound 3",
#   "MPA-BTTI",
#   "fluorene-terminated HTL",
#   "H-NiO",
#   "Spiro-OMeTAD w/ IP-OTs",
#   "Spiro-OMeTAD+PTAA",
#   "PyBDP-1",
#   "4-PhCz",
#   "PBDB-Cz",
#   "p-POZ-E",
#   "NiOx2A",
#   "PTPD w/ DPI",
#   "PEDOT:PSS-TBP",
#   "Spiro-OMeTAD w/ pristine MWCNT",
#   "Cu@RGO",
#   "H123",
#   "WO2",
#   "Spiro-OMeTAD w/ Tb-FTZB",
#   "MPA-BT-CA",
#   "Spiro-MeOTAD w/ LiPF6",
#   "V1306",
#   "YT-PTPA",
#   "Eu-TCPP MOF",
#   "Spiro-OMeTAD w/ COF",
#   "ThPCyAc",
#   "PEDOT:PSS w/ NiO",
#   "Cu3SbS4",
#   "CuO@NiO",
#   "PyDAn",
#   "B2",
#   "YKP02",
#   "NiOx w/ PMD25-0.15",
#   "CuFeO2",
#   "FN-O",
#   "Li-NiPc:P3HT",
#   "NiChl",
#   "A1DR",
#   "TPA-DN",
#   "2PACz-4PADCB",
#   "NiOx w/ NixN",
#   "H-Cu:NiOx",
#   "TPE-ETPA",
#   "p-O5H-E",
#   "BDT-p-IDN",
#   "JY9",
#   "A-4PADCB",
#   "Cu2Te",
#   "Cs:NiOx",
#   "H580",
#   "Spiro-OMeTAD w/ In2",
#   "HTM-2",
#   "PPr-SBT-14",
#   "Spiro-OMeTAD w/ LiTFSI",
#   "Spiro-OMeTAD w/ Li-TFSI@NH2-MIL-101",
#   "BCB-C4PA",
#   "FNE29",
#   "Aza-BODIPY 2",
#   "Zn\u2013Chl",
#   "PMO-SCN",
#   "Zn-doped PEDOT:PSS",
#   "PEDOT:PSS w/ NiO@Mo2C",
#   "DBT5-CF3",
#   "NiOX w/ PATFBA",
#   "PEDOT:PSS/PANI",
#   "PTAA(TPFB)",
#   "DTTP-ThTPA",
#   "Th-2EPT",
#   "PEDOT:PSS w/ P1",
#   "P1-2",
#   "PEDOT:PSS-DMSO",
#   "4PADCB w/ HOBT",
#   "BFM-C1 (doped)",
#   "DBT5",
#   "Hole transport layer",
#   "PEDOT-PSSNa",
#   "PyTPA-OH",
#   "TPB-2F",
#   "PTAA:\u03b1-6T",
#   "M1",
#   "Spiro-OMeTAD w/ PS",
#   "B-15",
#   "PTAA/PFN",
#   "HYC-mF",
#   "B-25",
#   "BT28",
#   "V1308",
#   "NiOx1A",
#   "DTmBDT-OMeTPA",
#   "P-CuO",
#   "r-GO/PTAA",
#   "m-MTDATA",
#   "V1435",
#   "Pyra-TPA",
#   "Me-4PACz/MBA",
#   "H-S",
#   "2-PACz w/ PAG",
#   "BFM-C6",
#   "H-BO",
#   "P3CT-K",
#   "G-EA",
#   "DC-2",
#   "PE8",
#   "MWCNTs",
#   "JY7",
#   "PEDOT:PSS PH 1000",
#   "PCPDTBT:PCBM",
#   "Spiro-OMeTAD w/ Ca(TFSI)2",
#   "NiO w/ C222-12COOH",
#   "np12-NiOx",
#   "Cu2O/CuSCN",
#   "ALD Cu:NiOx",
#   "DCT",
#   "Spiro-OMeTAD w/ LiTFSI and tBP",
#   "NiOx w/ PMD25-0.05",
#   "BTPA-3C",
#   "O5H-OMeDPA",
#   "MCz-VPOZ",
#   "D6-PEDOT:PSS",
#   "IDIDF2 w/ Li-TFSI and 4-tBP",
#   "PTAA(TPFB):Spiro(LiTFSI)",
#   "H-BS",
#   "PTAA w/ MAI",
#   "ACR-CZ",
#   "PVCz-SMeTPA",
#   "36MeOCzC4PA",
#   "SA/Me-4PACz",
#   "O2",
#   "M-PEDOT:PSS",
#   "MeO-2PACz+SBA",
#   "ADT-TPA",
#   "H-O",
#   "NiOx w/ BPCSA",
#   "TADM1",
#   "ZnPor/rGO/CuO bio nanocomposite",
#   "CQ7",
#   "DBC-ETPA",
#   "Zn2P3",
#   "MoO3-x/P3HT",
#   "spiro-OMeTAD w/ MMPyTFSI",
#   "X-F6-TAPC",
#   "NiOxIn-1.0%",
#   "PEDOT:PSS w/ PANI-CdO (5%)",
#   "BDT-DPA-F",
#   "Single SAM",
#   "Spiro-OMeTAD w/ Co(III)-CN",
#   "Spiro-OMeTAD w/ P@M-4",
#   "PEH-16",
#   "NiOx2",
#   "PEDOT-i-PASNa",
#   "PE9",
#   "S02",
#   "NiOx/LS2@PTAA-0.2P",
#   "Spiro-ID",
#   "DF-2",
#   "Cu_Oxd",
#   "3C-H SAM",
#   "NiOx w/ 4-IPBA",
#   "Cu1.8S",
#   "CO2 doping Spiro-OMeTAD",
#   "NiO w/ TPPO",
#   "DBT5-H",
#   "TPB(2-MeOTAD)",
#   "Spiro-OMeTAD w/ H3PMo12O40",
#   "WZ40",
#   "PTAA/PFN-Br",
#   "PT-Cz50",
#   "CDT",
#   "DOP-OMeDPA",
#   "MoO",
#   "P3",
#   "1 mol% Mn-doped NiOx",
#   "Cu2-xS",
#   "3C-OMe SAM",
#   "NiOMeCp",
#   "Spiro-OMeTAD w/ Tb-TZB",
#   "Li0.05Mg0.05NiOx",
#   "TPA-Sp-PA (1)",
#   "Mg-doped NiCo2O4",
#   "4PACZ",
#   "PBPyT-ex",
#   "Spiro-OMeTAD w/ Co(III)-CNS",
#   "YT-KTPA",
#   "X22",
#   "WZ102",
#   "PTAA(TPFB):C8BTBT(TPFB)",
#   "TPABT",
#   "NiMgLiO",
#   "NiOx:Cu+SAM",
#   "TPA-P-PE (3E)",
#   "Spiro-OMeTAD w/ CIGSe QDs and Au NRs",
#   "HZ2",
#   "Spiro-OMeTAD w/ Sc(TFSI)3",
#   "V1307",
#   "PTAA:PASQ-IDT",
#   "ITO NCs",
#   "PTAC-DEG",
#   "DMeTPA-O",
#   "PTZT-FF",
#   "spiro-OMeTAD w/ PVK",
#   "TPA-BBT",
#   "PolyPor",
#   "Ca",
#   "TAPC:MoO3",
#   "sp-NiOx",
#   "NiOx5",
#   "IDIDF3",
#   "WS2",
#   "La:NiOx",
#   "PPr",
#   "NDT-Pyz",
#   "IQTPAFlu",
#   "FDT",
#   "X25",
#   "S04",
#   "GO/PANI",
#   "X60 w/ COF@TCNQ",
#   "PEDOT:PSS w/ PC",
#   "8TPAEPC",
#   "PyDAnCBZ",
#   "PEDOT:PSS w/ Ti3C2Tx MXene",
#   "PTAA w/ PBDB-T-SF",
#   "F23",
#   "Spiro-MeOTAD w/ LiTFSI",
#   "69",
#   "TPA-ADP 1",
#   "4PADCB + NSN-C4",
#   "XC2-M",
#   "SY1",
#   "TPADPP",
#   "Spiro-OMeTAD w/ TBPEH",
#   "PolyCuChl",
#   "AgSCN",
#   "TOP-3",
#   "T5H-BMCA",
#   "4PADCB + NSN-IB",
#   "Spiro-OMeTAD w/ In10",
#   "Nb2CTx",
#   "NiO w/ TPPSe",
#   "M-P3HT",
#   "P3HT 194 kDa/100%",
#   "TPA-CAA",
#   "NiOx w/ PMD25-0.10",
#   "MBT",
#   "CISe",
#   "Li0.05NiOx",
#   "NiOx/CQ37",
#   "TPA-Sp-PE (1E)",
#   "O1",
#   "CS-9",
#   "Tatm",
#   "IDIDF4",
#   "poly-v-spiro",
#   "D-CZ",
#   "YSH-H",
#   "TP-MN",
#   "XF2",
#   "MeO-2PACZ and Me-4PACZ",
#   "4-(2-aminomethyl)benzoic acid",
#   "WO2.72",
#   "V1434",
#   "spiro-OMeIm",
#   "D-ACR",
#   "PE7",
#   "YN2",
#   "PTAA:P3HT",
#   "BT",
#   "TPT-T (MB/C6) w/ Li-TFSI and tBP",
#   "PyAA-Me",
#   "Spiro-OMeTAD w/ Cu(TFSI)2",
#   "TPA-P-PA (3)",
#   "ALD NiOx",
#   "P-PY",
#   "pDPA-SFX",
#   "SIM",
#   "Ag@RGO",
#   "FN-S",
#   "4-nitrobenzoic acid",
#   "NiOx w/ PMD50-0.03",
#   "P3CT-Na",
#   "K5-13",
#   "TPT-T (MB/C6)",
#   "CuSCN/rGO",
#   "PTOAA w/ C222-12COOH",
#   "DBFMT",
#   "Liquid electrolyte",
#   "PPr-SBT-6",
#   "PTAA:PNRs",
#   "Spiro-OMeTAD w/ MWCNT-2",
#   "3,6-SFY",
#   "PT-HP",
#   "Ga(acac)3-P3HT",
#   "3,6-SFY:2,7-SFY (1:1)",
#   "PMO",
#   "BEDN",
#   "PEDOT-PAMPSA",
#   "GM-4PACz",
#   "Spiro-OMeTAD w/ IBX",
#   "Spiro-OMeTAD w/ Li-TFSI:Co-TFSI",
#   "NiOx w/ p-F-PEAI",
#   "CbzBF",
#   "PTOAA w/ C132-8COOH",
#   "PEDOT:PSS:CNDs",
#   "p-TAA",
#   "mp-CuGaO2",
#   "PEDOT:PSS/SrGO",
#   "PEDOT:PSS w/ PANI-CdO (10%)",
#   "PTAA w/ PNRs",
#   "PEDOT:PSS w/ NaBH4",
#   "Cu:NiO",
#   "PyTPA",
#   "IDCz-1",
#   "TPA-DBT-DTPA",
#   "DTmBDT-TPA",
#   "PEDOT:PSS + WO3",
#   "Cu\u2013NiO",
#   "MC-3",
#   "PT-Cz70",
#   "Spiro-OMeTAD w/ Li-TFSI/12-crown-4",
#   "BTP2",
#   "XL6",
#   "Spiro-OMeTAD w/ Li-TFSI/tBP",
#   "TPA-BPFN-TPA",
#   "H-Se",
#   "V1305",
#   "Spiro-OMeTAD w/ MIL-88B-1,4-SO3H",
#   "PTAA w/ PMI",
#   "PMO-I",
#   "Py-C",
#   "XS10",
#   "Azu-diT",
#   "CZGS",
#   "Spiro-OMeTAD w/ LQ",
#   "G-NH2",
#   "PyBDP-3",
#   "T5H-OMeDPA",
#   "HTL with NaYF4:Yb/Er/Li-Ag@SiO2",
#   "PE3",
#   "PyPDAn",
#   "p-TNI2",
#   "P3HT/SWNT/PMMA",
#   "DC-3",
#   "C3-S",
#   "CL-TPDA",
#   "FT-OMeTPA",
#   "Spiro-OMeTAD w/ MIL-88B-1,3-SO3H",
#   "DBT5-COOH",
#   "X23",
#   "PEDOT:PSS-(4-Py)",
#   "Azu-diF",
#   "MF-2",
#   "PEDOT-t-PASNa",
#   "spiro-OMeTAD w/ [Sc3N@C80]",
#   "CDT-CN",
#   "P3CT-K/IL",
#   "ADT-DPA",
#   "PDO2",
#   "XS13",
#   "PT-H w/ tBP",
#   "PTAA w/ IP-TFSI",
#   "2%Cu@ZnCo2O4",
#   "mDPA-SFX",
#   "GO/PEDOT:PSS/PANI",
#   "Spiro-OMeTAD w/ CPDT",
#   "XL8",
#   "DTTTP-TPA",
#   "TBTAT-B-C1-e3",
#   "Li:NiOx",
#   "CP2",
#   "HTM-1",
#   "DP",
#   "IDIDF1",
#   "Zn0.1Ni0.9Co2O4",
#   "PEDOT:PSS w/ P2",
#   "CSAC",
#   "PBTI",
#   "TPASF",
#   "NiOxIn-0.5%",
#   "SFX-3",
#   "BiOCOOH",
#   "IDCz-2",
#   "PEDOT:PSS(SC)",
#   "PyBDP-4",
#   "TM-13",
#   "4-PACz",
#   "NiOx w/ IL",
#   "Ti3C2Tx-SCA",
#   "TaTm:F6-TCNNQ",
#   "Z30",
#   "AI4083",
#   "CuCrO2/Spiro-OMeTAD",
#   "NiOx NaPAs",
#   "4PADCB + NSN-BO",
#   "PTAA w/ F-PEAI",
#   "Spiro-OMeTAD w/ Li(Gd,Y)F4:Yb,Er UCNCs",
#   "PTAA w/ FPEAI",
#   "Aza-BODIPY 1",
#   "3C-Ph SAM",
#   "DTTP-ThC6",
#   "CoN",
#   "CX3",
#   "Ti3C2-MXene",
#   "JY4",
#   "CuI/PEDOT:PSS",
#   "NiO w/ TPPS",
#   "PEDOT-WO3",
#   "mHSL",
#   "VB-MeO-FDPA",
#   "TEG-CZ-PTZ",
#   "DT-1",
#   "THP-1",
#   "Cu-corrole",
#   "M3",
#   "MEBT",
#   "Graphene:PM6",
#   "PEDOT:PSS-Py",
#   "PVCz-SMeDAD",
#   "DTP-2",
#   "YT-KMPF",
#   "DTTTP-DPA",
#   "DPA-DBT-DTPA",
#   "Sm:NiOx",
#   "Spiro-OMeTAD w/ TPP",
#   "C3-D",
#   "BFM-C6 (doped)",
#   "Spiro-OMeTAD w/ POM-IL",
#   "compound 1",
#   "MeO-2PACz/4PADCP bilayer SAM",
#   "TPT-MN",
#   "TBTA[6]H",
#   "D-3PACz",
#   "c-NiO",
#   "PyBDP-5",
#   "CuChl",
#   "Spiro-OMeTAD w/ MWCNT-4",
#   "MoSe2/Spiro grating w/ PbS-TBAI",
#   "NiOx w/ KSiF6",
#   "AZO-II",
#   "DBPP",
#   "1T-rich WS2",
#   "PTAA/CuI",
#   "JY8",
#   "p+-Si shell",
#   "Spiro-OMeTAD w/ MWCNT-5",
#   "V1036",
#   "PA",
#   "PA-Cz50",
#   "P3HT w/ 5CB",
#   "Spiro-OMeTAD w/ P(VDF-TRFE)",
#   "NiOx w/ PEAI",
#   "PTAA w/ PEAI",
#   "K5-36",
#   "SMeTAD",
#   "Azu-2T6F",
#   "TADM4",
#   "MC-2",
#   "He-CZ-POZ",
#   "VOx",
#   "TaTm:F6TCNNQ",
#   "TPA-T-PA (2)"
# ]

# %%
combined_map = synthesis_method_map | substrate_map | contact_map | etl_map | htl_map
with open('../src/perovskite_solar_cell_database/synonym_map.json', 'w') as f:
    json.dump(combined_map, f, indent=2)
