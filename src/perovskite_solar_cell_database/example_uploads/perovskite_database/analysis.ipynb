# %% [markdown]
# # Statistical analysis of perovskite data

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from scipy import stats
from collections import Counter
import networkx as nx
import warnings
import re
from plotly_theme import register_template, scatter_plot, set_defaults, SINGLE_COLUMN_PX, DOUBLE_COLUMN_PX
import plotly.express as px
import plotly.graph_objects as go
register_template()
set_defaults()

# %%
df = pd.read_parquet('pvdb.parquet')

# %%
list(df.columns)
# Out:
# ['data.add.lay_back',
#  'data.add.lay_back_deposition_aggregation_state_of_reactants',
#  'data.add.lay_back_deposition_procedure',
#  'data.add.lay_back_deposition_reaction_solutions_age',
#  'data.add.lay_back_deposition_reaction_solutions_compounds_purity',
#  'data.add.lay_back_deposition_reaction_solutions_compounds_supplier',
#  'data.add.lay_back_deposition_reaction_solutions_temperature',
#  'data.add.lay_back_deposition_reaction_solutions_volumes',
#  'data.add.lay_back_deposition_solvents',
#  'data.add.lay_back_deposition_solvents_purity',
#  'data.add.lay_back_deposition_solvents_supplier',
#  'data.add.lay_back_deposition_substrate_temperature',
#  'data.add.lay_back_deposition_synthesis_atmosphere',
#  'data.add.lay_back_deposition_thermal_annealing_atmosphere',
#  'data.add.lay_back_deposition_thermal_annealing_temperature',
#  'data.add.lay_back_deposition_thermal_annealing_time',
#  'data.add.lay_back_function',
#  'data.add.lay_back_stack_sequence',
#  'data.add.lay_back_storage_atmosphere',
#  'data.add.lay_back_storage_time_until_next_deposition_step',
#  'data.add.lay_back_thickness_list',
#  'data.add.lay_front',
#  'data.add.lay_front_deposition_aggregation_state_of_reactants',
#  'data.add.lay_front_deposition_procedure',
#  'data.add.lay_front_deposition_reaction_solutions_age',
#  'data.add.lay_front_deposition_reaction_solutions_compounds_purity',
#  'data.add.lay_front_deposition_reaction_solutions_compounds_supplier',
#  'data.add.lay_front_deposition_reaction_solutions_temperature',
#  'data.add.lay_front_deposition_reaction_solutions_volumes',
#  'data.add.lay_front_deposition_solvents',
#  'data.add.lay_front_deposition_solvents_purity',
#  'data.add.lay_front_deposition_solvents_supplier',
#  'data.add.lay_front_deposition_substrate_temperature',
#  'data.add.lay_front_deposition_synthesis_atmosphere',
#  'data.add.lay_front_deposition_thermal_annealing_atmosphere',
#  'data.add.lay_front_deposition_thermal_annealing_temperature',
#  'data.add.lay_front_deposition_thermal_annealing_time',
#  'data.add.lay_front_function',
#  'data.add.lay_front_stack_sequence',
#  'data.add.lay_front_storage_atmosphere',
#  'data.add.lay_front_storage_time_until_next_deposition_step',
#  'data.add.lay_front_thickness_list',
#  'data.backcontact.additives_compounds',
#  'data.backcontact.additives_concentrations',
#  'data.backcontact.deposition_aggregation_state_of_reactants',
#  'data.backcontact.deposition_procedure',
#  'data.backcontact.deposition_reaction_solutions_age',
#  'data.backcontact.deposition_reaction_solutions_compounds',
#  'data.backcontact.deposition_reaction_solutions_compounds_purity',
#  'data.backcontact.deposition_reaction_solutions_compounds_supplier',
#  'data.backcontact.deposition_reaction_solutions_concentrations',
#  'data.backcontact.deposition_reaction_solutions_temperature',
#  'data.backcontact.deposition_reaction_solutions_volumes',
#  'data.backcontact.deposition_solvents',
#  'data.backcontact.deposition_solvents_mixing_ratios',
#  'data.backcontact.deposition_solvents_purity',
#  'data.backcontact.deposition_solvents_supplier',
#  'data.backcontact.deposition_substrate_temperature',
#  'data.backcontact.deposition_synthesis_atmosphere',
#  'data.backcontact.deposition_synthesis_atmosphere_pressure_partial',
#  'data.backcontact.deposition_synthesis_atmosphere_pressure_total',
#  'data.backcontact.deposition_synthesis_atmosphere_relative_humidity',
#  'data.backcontact.deposition_thermal_annealing_atmosphere',
#  'data.backcontact.deposition_thermal_annealing_temperature',
#  'data.backcontact.deposition_thermal_annealing_time',
#  'data.backcontact.stack_sequence',
#  'data.backcontact.storage_atmosphere',
#  'data.backcontact.storage_relative_humidity',
#  'data.backcontact.storage_time_until_next_deposition_step',
#  'data.backcontact.surface_treatment_before_next_deposition_step',
#  'data.backcontact.thickness_list',
#  'data.cell.architecture',
#  'data.cell.area_measured',
#  'data.cell.area_total',
#  'data.cell.flexible',
#  'data.cell.number_of_cells_per_substrate',
#  'data.cell.semitransparent',
#  'data.cell.semitransparent_AVT',
#  'data.cell.semitransparent_raw_data',
#  'data.cell.semitransparent_wavelength_range',
#  'data.cell.stack_sequence',
#  'data.encapsulation.Encapsulation',
#  'data.encapsulation.atmosphere_for_encapsulation',
#  'data.encapsulation.edge_sealing_materials',
#  'data.encapsulation.oxygen_transmission_rate',
#  'data.encapsulation.stack_sequence',
#  'data.encapsulation.water_vapour_transmission_rate',
#  'data.eqe.integrated_Jsc',
#  'data.eqe.light_bias',
#  'data.eqe.link_raw_data',
#  'data.eqe.measured',
#  'data.etl.additives_compounds',
#  'data.etl.additives_concentrations',
#  'data.etl.deposition_aggregation_state_of_reactants',
#  'data.etl.deposition_procedure',
#  'data.etl.deposition_reaction_solutions_age',
#  'data.etl.deposition_reaction_solutions_compounds',
#  'data.etl.deposition_reaction_solutions_compounds_purity',
#  'data.etl.deposition_reaction_solutions_compounds_supplier',
#  'data.etl.deposition_reaction_solutions_concentrations',
#  'data.etl.deposition_reaction_solutions_temperature',
#  'data.etl.deposition_reaction_solutions_volumes',
#  'data.etl.deposition_solvents',
#  'data.etl.deposition_solvents_mixing_ratios',
#  'data.etl.deposition_solvents_purity',
#  'data.etl.deposition_solvents_supplier',
#  'data.etl.deposition_substrate_temperature',
#  'data.etl.deposition_synthesis_atmosphere',
#  'data.etl.deposition_synthesis_atmosphere_pressure_partial',
#  'data.etl.deposition_synthesis_atmosphere_pressure_total',
#  'data.etl.deposition_synthesis_atmosphere_relative_humidity',
#  'data.etl.deposition_thermal_annealing_atmosphere',
#  'data.etl.deposition_thermal_annealing_temperature',
#  'data.etl.deposition_thermal_annealing_time',
#  'data.etl.stack_sequence',
#  'data.etl.storage_atmosphere',
#  'data.etl.storage_relative_humidity',
#  'data.etl.storage_time_until_next_deposition_step',
#  'data.etl.surface_treatment_before_next_deposition_step',
#  'data.etl.thickness',
#  'data.figures.0.figure.data.0.alphahull',
#  'data.figures.0.figure.data.0.color',
#  'data.figures.0.figure.data.0.hoverinfo',
#  'data.figures.0.figure.data.0.name',
#  'data.figures.0.figure.data.0.opacity',
#  'data.figures.0.figure.data.0.showlegend',
#  'data.figures.0.figure.data.0.type',
#  'data.figures.0.figure.data.0.x',
#  'data.figures.0.figure.data.0.y',
#  'data.figures.0.figure.data.0.z',
#  'data.figures.0.figure.data.1.hoverinfo',
#  'data.figures.0.figure.data.1.line.color',
#  'data.figures.0.figure.data.1.line.width',
#  'data.figures.0.figure.data.1.mode',
#  'data.figures.0.figure.data.1.showlegend',
#  'data.figures.0.figure.data.1.type',
#  'data.figures.0.figure.data.1.x',
#  'data.figures.0.figure.data.1.y',
#  'data.figures.0.figure.data.1.z',
#  'data.figures.0.figure.data.10.alphahull',
#  'data.figures.0.figure.data.10.color',
#  'data.figures.0.figure.data.10.hoverinfo',
#  'data.figures.0.figure.data.10.name',
#  'data.figures.0.figure.data.10.opacity',
#  'data.figures.0.figure.data.10.showlegend',
#  'data.figures.0.figure.data.10.type',
#  'data.figures.0.figure.data.10.x',
#  'data.figures.0.figure.data.10.y',
#  'data.figures.0.figure.data.10.z',
#  'data.figures.0.figure.data.11.hoverinfo',
#  'data.figures.0.figure.data.11.line.color',
#  'data.figures.0.figure.data.11.line.width',
#  'data.figures.0.figure.data.11.mode',
#  'data.figures.0.figure.data.11.showlegend',
#  'data.figures.0.figure.data.11.type',
#  'data.figures.0.figure.data.11.x',
#  'data.figures.0.figure.data.11.y',
#  'data.figures.0.figure.data.11.z',
#  'data.figures.0.figure.data.12.alphahull',
#  'data.figures.0.figure.data.12.color',
#  'data.figures.0.figure.data.12.hoverinfo',
#  'data.figures.0.figure.data.12.name',
#  'data.figures.0.figure.data.12.opacity',
#  'data.figures.0.figure.data.12.showlegend',
#  'data.figures.0.figure.data.12.type',
#  'data.figures.0.figure.data.12.x',
#  'data.figures.0.figure.data.12.y',
#  'data.figures.0.figure.data.12.z',
#  'data.figures.0.figure.data.13.hoverinfo',
#  'data.figures.0.figure.data.13.line.color',
#  'data.figures.0.figure.data.13.line.width',
#  'data.figures.0.figure.data.13.mode',
#  'data.figures.0.figure.data.13.showlegend',
#  'data.figures.0.figure.data.13.type',
#  'data.figures.0.figure.data.13.x',
#  'data.figures.0.figure.data.13.y',
#  'data.figures.0.figure.data.13.z',
#  'data.figures.0.figure.data.14.alphahull',
#  'data.figures.0.figure.data.14.color',
#  'data.figures.0.figure.data.14.hoverinfo',
#  'data.figures.0.figure.data.14.name',
#  'data.figures.0.figure.data.14.opacity',
#  'data.figures.0.figure.data.14.showlegend',
#  'data.figures.0.figure.data.14.type',
#  'data.figures.0.figure.data.14.x',
#  'data.figures.0.figure.data.14.y',
#  'data.figures.0.figure.data.14.z',
#  'data.figures.0.figure.data.15.hoverinfo',
#  'data.figures.0.figure.data.15.line.color',
#  'data.figures.0.figure.data.15.line.width',
#  'data.figures.0.figure.data.15.mode',
#  'data.figures.0.figure.data.15.showlegend',
#  'data.figures.0.figure.data.15.type',
#  'data.figures.0.figure.data.15.x',
#  'data.figures.0.figure.data.15.y',
#  'data.figures.0.figure.data.15.z',
#  'data.figures.0.figure.data.16.alphahull',
#  'data.figures.0.figure.data.16.color',
#  'data.figures.0.figure.data.16.hoverinfo',
#  'data.figures.0.figure.data.16.name',
#  'data.figures.0.figure.data.16.opacity',
#  'data.figures.0.figure.data.16.showlegend',
#  'data.figures.0.figure.data.16.type',
#  'data.figures.0.figure.data.16.x',
#  'data.figures.0.figure.data.16.y',
#  'data.figures.0.figure.data.16.z',
#  'data.figures.0.figure.data.17.hoverinfo',
#  'data.figures.0.figure.data.17.line.color',
#  'data.figures.0.figure.data.17.line.width',
#  'data.figures.0.figure.data.17.mode',
#  'data.figures.0.figure.data.17.showlegend',
#  'data.figures.0.figure.data.17.type',
#  'data.figures.0.figure.data.17.x',
#  'data.figures.0.figure.data.17.y',
#  'data.figures.0.figure.data.17.z',
#  'data.figures.0.figure.data.18.alphahull',
#  'data.figures.0.figure.data.18.color',
#  'data.figures.0.figure.data.18.hoverinfo',
#  'data.figures.0.figure.data.18.name',
#  'data.figures.0.figure.data.18.opacity',
#  'data.figures.0.figure.data.18.showlegend',
#  'data.figures.0.figure.data.18.type',
#  'data.figures.0.figure.data.18.x',
#  'data.figures.0.figure.data.18.y',
#  'data.figures.0.figure.data.18.z',
#  'data.figures.0.figure.data.19.hoverinfo',
#  'data.figures.0.figure.data.19.line.color',
#  'data.figures.0.figure.data.19.line.width',
#  'data.figures.0.figure.data.19.mode',
#  'data.figures.0.figure.data.19.showlegend',
#  'data.figures.0.figure.data.19.type',
#  'data.figures.0.figure.data.19.x',
#  'data.figures.0.figure.data.19.y',
#  'data.figures.0.figure.data.19.z',
#  'data.figures.0.figure.data.2.alphahull',
#  'data.figures.0.figure.data.2.color',
#  'data.figures.0.figure.data.2.hoverinfo',
#  'data.figures.0.figure.data.2.name',
#  'data.figures.0.figure.data.2.opacity',
#  'data.figures.0.figure.data.2.showlegend',
#  'data.figures.0.figure.data.2.type',
#  'data.figures.0.figure.data.2.x',
#  'data.figures.0.figure.data.2.y',
#  'data.figures.0.figure.data.2.z',
#  'data.figures.0.figure.data.20.alphahull',
#  'data.figures.0.figure.data.20.color',
#  'data.figures.0.figure.data.20.hoverinfo',
#  'data.figures.0.figure.data.20.name',
#  'data.figures.0.figure.data.20.opacity',
#  'data.figures.0.figure.data.20.showlegend',
#  'data.figures.0.figure.data.20.type',
#  'data.figures.0.figure.data.20.x',
#  'data.figures.0.figure.data.20.y',
#  'data.figures.0.figure.data.20.z',
#  'data.figures.0.figure.data.21.hoverinfo',
#  'data.figures.0.figure.data.21.line.color',
#  'data.figures.0.figure.data.21.line.width',
#  'data.figures.0.figure.data.21.mode',
#  'data.figures.0.figure.data.21.showlegend',
#  'data.figures.0.figure.data.21.type',
#  'data.figures.0.figure.data.21.x',
#  'data.figures.0.figure.data.21.y',
#  'data.figures.0.figure.data.21.z',
#  'data.figures.0.figure.data.22.alphahull',
#  'data.figures.0.figure.data.22.color',
#  'data.figures.0.figure.data.22.hoverinfo',
#  'data.figures.0.figure.data.22.name',
#  'data.figures.0.figure.data.22.opacity',
#  'data.figures.0.figure.data.22.showlegend',
#  'data.figures.0.figure.data.22.type',
#  'data.figures.0.figure.data.22.x',
#  'data.figures.0.figure.data.22.y',
#  'data.figures.0.figure.data.22.z',
#  'data.figures.0.figure.data.23.hoverinfo',
#  'data.figures.0.figure.data.23.line.color',
#  'data.figures.0.figure.data.23.line.width',
#  'data.figures.0.figure.data.23.mode',
#  'data.figures.0.figure.data.23.showlegend',
#  'data.figures.0.figure.data.23.type',
#  'data.figures.0.figure.data.23.x',
#  'data.figures.0.figure.data.23.y',
#  'data.figures.0.figure.data.23.z',
#  'data.figures.0.figure.data.24.alphahull',
#  'data.figures.0.figure.data.24.color',
#  'data.figures.0.figure.data.24.hoverinfo',
#  'data.figures.0.figure.data.24.name',
#  'data.figures.0.figure.data.24.opacity',
#  'data.figures.0.figure.data.24.showlegend',
#  'data.figures.0.figure.data.24.type',
#  'data.figures.0.figure.data.24.x',
#  'data.figures.0.figure.data.24.y',
#  'data.figures.0.figure.data.24.z',
#  'data.figures.0.figure.data.25.hoverinfo',
#  'data.figures.0.figure.data.25.line.color',
#  'data.figures.0.figure.data.25.line.width',
#  'data.figures.0.figure.data.25.mode',
#  'data.figures.0.figure.data.25.showlegend',
#  'data.figures.0.figure.data.25.type',
#  'data.figures.0.figure.data.25.x',
#  'data.figures.0.figure.data.25.y',
#  'data.figures.0.figure.data.25.z',
#  'data.figures.0.figure.data.26.alphahull',
#  'data.figures.0.figure.data.26.color',
#  'data.figures.0.figure.data.26.hoverinfo',
#  'data.figures.0.figure.data.26.name',
#  'data.figures.0.figure.data.26.opacity',
#  'data.figures.0.figure.data.26.showlegend',
#  'data.figures.0.figure.data.26.type',
#  'data.figures.0.figure.data.26.x',
#  'data.figures.0.figure.data.26.y',
#  'data.figures.0.figure.data.26.z',
#  'data.figures.0.figure.data.27.hoverinfo',
#  'data.figures.0.figure.data.27.line.color',
#  'data.figures.0.figure.data.27.line.width',
#  'data.figures.0.figure.data.27.mode',
#  'data.figures.0.figure.data.27.showlegend',
#  'data.figures.0.figure.data.27.type',
#  'data.figures.0.figure.data.27.x',
#  'data.figures.0.figure.data.27.y',
#  'data.figures.0.figure.data.27.z',
#  'data.figures.0.figure.data.28.alphahull',
#  'data.figures.0.figure.data.28.color',
#  'data.figures.0.figure.data.28.hoverinfo',
#  'data.figures.0.figure.data.28.name',
#  'data.figures.0.figure.data.28.opacity',
#  'data.figures.0.figure.data.28.showlegend',
#  'data.figures.0.figure.data.28.type',
#  'data.figures.0.figure.data.28.x',
#  'data.figures.0.figure.data.28.y',
#  'data.figures.0.figure.data.28.z',
#  'data.figures.0.figure.data.29.hoverinfo',
#  'data.figures.0.figure.data.29.line.color',
#  'data.figures.0.figure.data.29.line.width',
#  'data.figures.0.figure.data.29.mode',
#  'data.figures.0.figure.data.29.showlegend',
#  'data.figures.0.figure.data.29.type',
#  'data.figures.0.figure.data.29.x',
#  'data.figures.0.figure.data.29.y',
#  'data.figures.0.figure.data.29.z',
#  'data.figures.0.figure.data.3.hoverinfo',
#  'data.figures.0.figure.data.3.line.color',
#  'data.figures.0.figure.data.3.line.width',
#  'data.figures.0.figure.data.3.mode',
#  'data.figures.0.figure.data.3.showlegend',
#  'data.figures.0.figure.data.3.type',
#  'data.figures.0.figure.data.3.x',
#  'data.figures.0.figure.data.3.y',
#  'data.figures.0.figure.data.3.z',
#  'data.figures.0.figure.data.30.alphahull',
#  'data.figures.0.figure.data.30.color',
#  'data.figures.0.figure.data.30.hoverinfo',
#  'data.figures.0.figure.data.30.name',
#  'data.figures.0.figure.data.30.opacity',
#  'data.figures.0.figure.data.30.showlegend',
#  'data.figures.0.figure.data.30.type',
#  'data.figures.0.figure.data.30.x',
#  'data.figures.0.figure.data.30.y',
#  'data.figures.0.figure.data.30.z',
#  'data.figures.0.figure.data.31.hoverinfo',
#  'data.figures.0.figure.data.31.line.color',
#  'data.figures.0.figure.data.31.line.width',
#  'data.figures.0.figure.data.31.mode',
#  'data.figures.0.figure.data.31.showlegend',
#  'data.figures.0.figure.data.31.type',
#  'data.figures.0.figure.data.31.x',
#  'data.figures.0.figure.data.31.y',
#  'data.figures.0.figure.data.31.z',
#  'data.figures.0.figure.data.32.alphahull',
#  'data.figures.0.figure.data.32.color',
#  'data.figures.0.figure.data.32.hoverinfo',
#  'data.figures.0.figure.data.32.name',
#  'data.figures.0.figure.data.32.opacity',
#  'data.figures.0.figure.data.32.showlegend',
#  'data.figures.0.figure.data.32.type',
#  'data.figures.0.figure.data.32.x',
#  'data.figures.0.figure.data.32.y',
#  'data.figures.0.figure.data.32.z',
#  'data.figures.0.figure.data.33.hoverinfo',
#  'data.figures.0.figure.data.33.line.color',
#  'data.figures.0.figure.data.33.line.width',
#  'data.figures.0.figure.data.33.mode',
#  'data.figures.0.figure.data.33.showlegend',
#  'data.figures.0.figure.data.33.type',
#  'data.figures.0.figure.data.33.x',
#  'data.figures.0.figure.data.33.y',
#  'data.figures.0.figure.data.33.z',
#  'data.figures.0.figure.data.4.alphahull',
#  'data.figures.0.figure.data.4.color',
#  'data.figures.0.figure.data.4.hoverinfo',
#  'data.figures.0.figure.data.4.name',
#  'data.figures.0.figure.data.4.opacity',
#  'data.figures.0.figure.data.4.showlegend',
#  'data.figures.0.figure.data.4.type',
#  'data.figures.0.figure.data.4.x',
#  'data.figures.0.figure.data.4.y',
#  'data.figures.0.figure.data.4.z',
#  'data.figures.0.figure.data.5.hoverinfo',
#  'data.figures.0.figure.data.5.line.color',
#  'data.figures.0.figure.data.5.line.width',
#  'data.figures.0.figure.data.5.mode',
#  'data.figures.0.figure.data.5.showlegend',
#  'data.figures.0.figure.data.5.type',
#  'data.figures.0.figure.data.5.x',
#  'data.figures.0.figure.data.5.y',
#  'data.figures.0.figure.data.5.z',
#  'data.figures.0.figure.data.6.alphahull',
#  'data.figures.0.figure.data.6.color',
#  'data.figures.0.figure.data.6.hoverinfo',
#  'data.figures.0.figure.data.6.name',
#  'data.figures.0.figure.data.6.opacity',
#  'data.figures.0.figure.data.6.showlegend',
#  'data.figures.0.figure.data.6.type',
#  'data.figures.0.figure.data.6.x',
#  'data.figures.0.figure.data.6.y',
#  'data.figures.0.figure.data.6.z',
#  'data.figures.0.figure.data.7.hoverinfo',
#  'data.figures.0.figure.data.7.line.color',
#  'data.figures.0.figure.data.7.line.width',
#  'data.figures.0.figure.data.7.mode',
#  'data.figures.0.figure.data.7.showlegend',
#  'data.figures.0.figure.data.7.type',
#  'data.figures.0.figure.data.7.x',
#  'data.figures.0.figure.data.7.y',
#  'data.figures.0.figure.data.7.z',
#  'data.figures.0.figure.data.8.alphahull',
#  'data.figures.0.figure.data.8.color',
#  'data.figures.0.figure.data.8.hoverinfo',
#  'data.figures.0.figure.data.8.name',
#  'data.figures.0.figure.data.8.opacity',
#  'data.figures.0.figure.data.8.showlegend',
#  'data.figures.0.figure.data.8.type',
#  'data.figures.0.figure.data.8.x',
#  'data.figures.0.figure.data.8.y',
#  'data.figures.0.figure.data.8.z',
#  'data.figures.0.figure.data.9.hoverinfo',
#  'data.figures.0.figure.data.9.line.color',
#  'data.figures.0.figure.data.9.line.width',
#  'data.figures.0.figure.data.9.mode',
#  'data.figures.0.figure.data.9.showlegend',
#  'data.figures.0.figure.data.9.type',
#  'data.figures.0.figure.data.9.x',
#  'data.figures.0.figure.data.9.y',
#  'data.figures.0.figure.data.9.z',
#  'data.figures.0.figure.layout.annotations.0.align',
#  'data.figures.0.figure.layout.annotations.0.borderwidth',
#  'data.figures.0.figure.layout.annotations.0.showarrow',
#  'data.figures.0.figure.layout.annotations.0.text',
#  'data.figures.0.figure.layout.annotations.0.x',
#  'data.figures.0.figure.layout.annotations.0.xanchor',
#  'data.figures.0.figure.layout.annotations.0.xref',
#  'data.figures.0.figure.layout.annotations.0.y',
#  'data.figures.0.figure.layout.annotations.0.yanchor',
#  'data.figures.0.figure.layout.annotations.0.yref',
#  'data.figures.0.figure.layout.height',
#  'data.figures.0.figure.layout.hovermode',
#  'data.figures.0.figure.layout.legend.traceorder',
#  'data.figures.0.figure.layout.legend.x',
#  'data.figures.0.figure.layout.legend.xanchor',
#  'data.figures.0.figure.layout.legend.y',
#  'data.figures.0.figure.layout.legend.yanchor',
#  'data.figures.0.figure.layout.margin.b',
#  'data.figures.0.figure.layout.margin.l',
#  'data.figures.0.figure.layout.margin.r',
#  'data.figures.0.figure.layout.margin.t',
#  'data.figures.0.figure.layout.scene.camera.eye.x',
#  'data.figures.0.figure.layout.scene.camera.eye.y',
#  'data.figures.0.figure.layout.scene.camera.eye.z',
#  'data.figures.0.figure.layout.scene.dragmode',
#  'data.figures.0.figure.layout.scene.xaxis.showgrid',
#  'data.figures.0.figure.layout.scene.xaxis.visible',
#  'data.figures.0.figure.layout.scene.xaxis.zeroline',
#  'data.figures.0.figure.layout.scene.yaxis.showgrid',
#  'data.figures.0.figure.layout.scene.yaxis.visible',
#  'data.figures.0.figure.layout.scene.yaxis.zeroline',
#  'data.figures.0.figure.layout.scene.zaxis.showgrid',
#  'data.figures.0.figure.layout.scene.zaxis.visible',
#  'data.figures.0.figure.layout.scene.zaxis.zeroline',
#  'data.figures.0.figure.layout.showlegend',
#  'data.figures.0.figure.layout.width',
#  'data.htl.additives_compounds',
#  'data.htl.additives_concentrations',
#  'data.htl.deposition_aggregation_state_of_reactants',
#  'data.htl.deposition_procedure',
#  'data.htl.deposition_reaction_solutions_age',
#  'data.htl.deposition_reaction_solutions_compounds',
#  'data.htl.deposition_reaction_solutions_compounds_purity',
#  'data.htl.deposition_reaction_solutions_compounds_supplier',
#  'data.htl.deposition_reaction_solutions_concentrations',
#  'data.htl.deposition_reaction_solutions_temperature',
#  'data.htl.deposition_reaction_solutions_volumes',
#  'data.htl.deposition_solvents',
#  'data.htl.deposition_solvents_mixing_ratios',
#  'data.htl.deposition_solvents_purity',
#  'data.htl.deposition_solvents_supplier',
#  'data.htl.deposition_substrate_temperature',
#  'data.htl.deposition_synthesis_atmosphere',
#  'data.htl.deposition_synthesis_atmosphere_pressure_partial',
#  'data.htl.deposition_synthesis_atmosphere_pressure_total',
#  'data.htl.deposition_synthesis_atmosphere_relative_humidity',
#  'data.htl.deposition_thermal_annealing_atmosphere',
#  'data.htl.deposition_thermal_annealing_temperature',
#  'data.htl.deposition_thermal_annealing_time',
#  'data.htl.stack_sequence',
#  'data.htl.storage_atmosphere',
#  'data.htl.storage_relative_humidity',
#  'data.htl.storage_time_until_next_deposition_step',
#  'data.htl.surface_treatment_before_next_deposition_step',
#  'data.htl.thickness_list',
#  'data.jv.average_over_n_number_of_cells',
#  'data.jv.certification_institute',
#  'data.jv.certified_values',
#  'data.jv.default_FF',
#  'data.jv.default_FF_scan_direction',
#  'data.jv.default_Jsc',
#  'data.jv.default_Jsc_scan_direction',
#  'data.jv.default_PCE',
#  'data.jv.default_PCE_scan_direction',
#  'data.jv.default_Voc',
#  'data.jv.default_Voc_scan_direction',
#  'data.jv.forward_scan_FF',
#  'data.jv.forward_scan_Jmp',
#  'data.jv.forward_scan_Jsc',
#  'data.jv.forward_scan_PCE',
#  'data.jv.forward_scan_Vmp',
#  'data.jv.forward_scan_Voc',
#  'data.jv.forward_scan_series_resistance',
#  'data.jv.forward_scan_shunt_resistance',
#  'data.jv.hysteresis_index',
#  'data.jv.light_illumination_direction',
#  'data.jv.light_intensity',
#  'data.jv.light_mask_area',
#  'data.jv.light_masked_cell',
#  'data.jv.light_source_brand_name',
#  'data.jv.light_source_simulator_class',
#  'data.jv.light_source_type',
#  'data.jv.light_spectra',
#  'data.jv.light_wavelength_range',
#  'data.jv.link_raw_data',
#  'data.jv.measured',
#  'data.jv.preconditioning_light_intensity',
#  'data.jv.preconditioning_potential',
#  'data.jv.preconditioning_protocol',
#  'data.jv.preconditioning_time',
#  'data.jv.reverse_scan_FF',
#  'data.jv.reverse_scan_Jmp',
#  'data.jv.reverse_scan_Jsc',
#  'data.jv.reverse_scan_PCE',
#  'data.jv.reverse_scan_Vmp',
#  'data.jv.reverse_scan_Voc',
#  'data.jv.reverse_scan_series_resistance',
#  'data.jv.reverse_scan_shunt_resistance',
#  'data.jv.scan_delay_time',
#  'data.jv.scan_integration_time',
#  'data.jv.scan_speed',
#  'data.jv.scan_voltage_step',
#  'data.jv.storage_age_of_cell',
#  'data.jv.storage_atmosphere',
#  'data.jv.storage_relative_humidity',
#  'data.jv.test_atmosphere',
#  'data.jv.test_relative_humidity',
#  'data.jv.test_temperature',
#  'data.m_def',
#  'data.module.JV_data_recalculated_per_cell',
#  'data.module.Module',
#  'data.module.area_effective',
#  'data.module.area_total',
#  'data.module.number_of_cells_in_module',
#  'data.outdoor.PCE_T80',
#  'data.outdoor.PCE_T95',
#  'data.outdoor.PCE_Ts80',
#  'data.outdoor.PCE_Ts95',
#  'data.outdoor.PCE_after_1000_h',
#  'data.outdoor.PCE_burn_in_observed',
#  'data.outdoor.PCE_end_of_experiment',
#  'data.outdoor.PCE_initial_value',
#  'data.outdoor.average_over_n_number_of_cells',
#  'data.outdoor.detaild_weather_data_available',
#  'data.outdoor.installation_cardinal_direction',
#  'data.outdoor.installation_number_of_solar_tracking_axis',
#  'data.outdoor.installation_tilt',
#  'data.outdoor.irradiance_measured',
#  'data.outdoor.link_detailed_weather_data',
#  'data.outdoor.link_irradiance_data',
#  'data.outdoor.link_raw_data_for_outdoor_trace',
#  'data.outdoor.link_spectral_data',
#  'data.outdoor.location_city',
#  'data.outdoor.location_climate_zone',
#  'data.outdoor.location_coordinates',
#  'data.outdoor.location_country',
#  'data.outdoor.periodic_JV_measurements',
#  'data.outdoor.potential_bias_load_condition',
#  'data.outdoor.potential_bias_range',
#  'data.outdoor.power_generated',
#  'data.outdoor.protocol',
#  'data.outdoor.spectral_data_available',
#  'data.outdoor.temperature_load_condition',
#  'data.outdoor.temperature_range',
#  'data.outdoor.temperature_tmodule',
#  'data.outdoor.tested',
#  'data.outdoor.time_end',
#  'data.outdoor.time_season',
#  'data.outdoor.time_start',
#  'data.outdoor.time_total_exposure',
#  'data.perovskite.additives_compounds',
#  'data.perovskite.additives_concentrations',
#  'data.perovskite.band_gap',
#  'data.perovskite.band_gap_estimation_basis',
#  'data.perovskite.band_gap_graded',
#  'data.perovskite.composition_a_ions',
#  'data.perovskite.composition_a_ions_coefficients',
#  'data.perovskite.composition_assumption',
#  'data.perovskite.composition_b_ions',
#  'data.perovskite.composition_b_ions_coefficients',
#  'data.perovskite.composition_c_ions',
#  'data.perovskite.composition_c_ions_coefficients',
#  'data.perovskite.composition_inorganic',
#  'data.perovskite.composition_leadfree',
#  'data.perovskite.composition_long_form',
#  'data.perovskite.composition_none_stoichiometry_components_in_excess',
#  'data.perovskite.composition_perovskite_ABC3_structure',
#  'data.perovskite.composition_perovskite_inspired_structure',
#  'data.perovskite.composition_short_form',
#  'data.perovskite.dimension_0D',
#  'data.perovskite.dimension_2D',
#  'data.perovskite.dimension_2D3D_mixture',
#  'data.perovskite.dimension_3D',
#  'data.perovskite.dimension_3D_with_2D_capping_layer',
#  'data.perovskite.dimension_list_of_layers',
#  'data.perovskite.ions.0.alternative_names',
#  'data.perovskite.ions.0.cas_number',
#  'data.perovskite.ions.0.coefficients',
#  'data.perovskite.ions.0.common_source_compound',
#  'data.perovskite.ions.0.ion_type',
#  'data.perovskite.ions.0.iupac_name',
#  'data.perovskite.ions.0.molecular_formula',
#  'data.perovskite.ions.0.name',
#  'data.perovskite.ions.0.smile',
#  'data.perovskite.ions.0.source_compound_cas',
#  'data.perovskite.ions.1.alternative_names',
#  'data.perovskite.ions.1.cas_number',
#  'data.perovskite.ions.1.coefficients',
#  'data.perovskite.ions.1.common_source_compound',
#  'data.perovskite.ions.1.ion_type',
#  'data.perovskite.ions.1.iupac_name',
#  'data.perovskite.ions.1.molecular_formula',
#  'data.perovskite.ions.1.name',
#  'data.perovskite.ions.1.smile',
#  'data.perovskite.ions.1.source_compound_cas',
#  'data.perovskite.ions.2.alternative_names',
#  'data.perovskite.ions.2.cas_number',
#  'data.perovskite.ions.2.coefficients',
#  'data.perovskite.ions.2.common_source_compound',
#  'data.perovskite.ions.2.ion_type',
#  'data.perovskite.ions.2.iupac_name',
#  'data.perovskite.ions.2.molecular_formula',
#  'data.perovskite.ions.2.name',
#  'data.perovskite.ions.2.smile',
#  'data.perovskite.ions.2.source_compound_cas',
#  'data.perovskite.ions.3.cas_number',
#  'data.perovskite.ions.3.coefficients',
#  'data.perovskite.ions.3.common_source_compound',
#  'data.perovskite.ions.3.ion_type',
#  'data.perovskite.ions.3.iupac_name',
#  'data.perovskite.ions.3.molecular_formula',
#  'data.perovskite.ions.3.name',
#  'data.perovskite.ions.3.smile',
#  'data.perovskite.ions.3.source_compound_cas',
#  'data.perovskite.ions.4.cas_number',
#  'data.perovskite.ions.4.coefficients',
#  'data.perovskite.ions.4.common_source_compound',
#  'data.perovskite.ions.4.ion_type',
#  'data.perovskite.ions.4.iupac_name',
#  'data.perovskite.ions.4.molecular_formula',
#  'data.perovskite.ions.4.name',
#  'data.perovskite.ions.4.smile',
#  'data.perovskite.ions.4.source_compound_cas',
#  'data.perovskite.ions.5.cas_number',
#  'data.perovskite.ions.5.coefficients',
#  'data.perovskite.ions.5.common_source_compound',
#  'data.perovskite.ions.5.ion_type',
#  'data.perovskite.ions.5.iupac_name',
#  'data.perovskite.ions.5.molecular_formula',
#  'data.perovskite.ions.5.name',
#  'data.perovskite.ions.5.smile',
#  'data.perovskite.ions.5.source_compound_cas',
#  'data.perovskite.ions.6.cas_number',
#  'data.perovskite.ions.6.coefficients',
#  'data.perovskite.ions.6.common_source_compound',
#  'data.perovskite.ions.6.ion_type',
#  'data.perovskite.ions.6.iupac_name',
#  'data.perovskite.ions.6.molecular_formula',
#  'data.perovskite.ions.6.name',
#  'data.perovskite.ions.6.smile',
#  'data.perovskite.ions.6.source_compound_cas',
#  'data.perovskite.ions.7.cas_number',
#  'data.perovskite.ions.7.coefficients',
#  'data.perovskite.ions.7.common_source_compound',
#  'data.perovskite.ions.7.ion_type',
#  'data.perovskite.ions.7.iupac_name',
#  'data.perovskite.ions.7.molecular_formula',
#  'data.perovskite.ions.7.name',
#  'data.perovskite.ions.7.smile',
#  'data.perovskite.ions.7.source_compound_cas',
#  'data.perovskite.pl_max',
#  'data.perovskite.single_crystal',
#  'data.perovskite.storage_atmosphere',
#  'data.perovskite.storage_relative_humidity',
#  'data.perovskite.storage_time_until_next_deposition_step',
#  'data.perovskite.surface_treatment_before_next_deposition_step',
#  'data.perovskite.thickness',
#  'data.perovskite_deposition.after_treatment_of_formed_perovskite',
#  'data.perovskite_deposition.after_treatment_of_formed_perovskite_met',
#  'data.perovskite_deposition.aggregation_state_of_reactants',
#  'data.perovskite_deposition.number_of_deposition_steps',
#  'data.perovskite_deposition.procedure',
#  'data.perovskite_deposition.quenching_induced_crystallisation',
#  'data.perovskite_deposition.quenching_media',
#  'data.perovskite_deposition.quenching_media_additives_compounds',
#  'data.perovskite_deposition.quenching_media_additives_concentrations',
#  'data.perovskite_deposition.quenching_media_mixing_ratios',
#  'data.perovskite_deposition.quenching_media_volume',
#  'data.perovskite_deposition.reaction_solutions_age',
#  'data.perovskite_deposition.reaction_solutions_compounds',
#  'data.perovskite_deposition.reaction_solutions_compounds_purity',
#  'data.perovskite_deposition.reaction_solutions_compounds_supplier',
#  'data.perovskite_deposition.reaction_solutions_concentrations',
#  'data.perovskite_deposition.reaction_solutions_temperature',
#  'data.perovskite_deposition.reaction_solutions_volumes',
#  'data.perovskite_deposition.solvent_annealing',
#  'data.perovskite_deposition.solvent_annealing_solvent_atmosphere',
#  'data.perovskite_deposition.solvent_annealing_temperature',
#  'data.perovskite_deposition.solvent_annealing_time',
#  'data.perovskite_deposition.solvent_annealing_timing',
#  'data.perovskite_deposition.solvents',
#  'data.perovskite_deposition.solvents_mixing_ratios',
#  'data.perovskite_deposition.solvents_purity',
#  'data.perovskite_deposition.solvents_supplier',
#  'data.perovskite_deposition.substrate_temperature',
#  'data.perovskite_deposition.synthesis_atmosphere',
#  'data.perovskite_deposition.synthesis_atmosphere_pressure_partial',
#  'data.perovskite_deposition.synthesis_atmosphere_pressure_total',
#  'data.perovskite_deposition.synthesis_atmosphere_relative_humidity',
#  'data.perovskite_deposition.thermal_annealing_atmosphere',
#  'data.perovskite_deposition.thermal_annealing_pressure',
#  'data.perovskite_deposition.thermal_annealing_relative_humidity',
#  'data.perovskite_deposition.thermal_annealing_temperature',
#  'data.perovskite_deposition.thermal_annealing_time',
#  'data.ref.DOI_number',
#  'data.ref.ID',
#  'data.ref.ID_temp',
#  'data.ref.authors.0.first_name',
#  'data.ref.authors.0.last_name',
#  'data.ref.authors.0.name',
#  'data.ref.authors.1.first_name',
#  'data.ref.authors.1.last_name',
#  'data.ref.authors.1.name',
#  'data.ref.authors.10.first_name',
#  'data.ref.authors.10.last_name',
#  'data.ref.authors.10.name',
#  'data.ref.authors.11.first_name',
#  'data.ref.authors.11.last_name',
#  'data.ref.authors.11.name',
#  'data.ref.authors.12.first_name',
#  'data.ref.authors.12.last_name',
#  'data.ref.authors.12.name',
#  'data.ref.authors.13.first_name',
#  'data.ref.authors.13.last_name',
#  'data.ref.authors.13.name',
#  'data.ref.authors.14.first_name',
#  'data.ref.authors.14.last_name',
#  'data.ref.authors.14.name',
#  'data.ref.authors.15.first_name',
#  'data.ref.authors.15.last_name',
#  'data.ref.authors.15.name',
#  'data.ref.authors.16.first_name',
#  'data.ref.authors.16.last_name',
#  'data.ref.authors.16.name',
#  'data.ref.authors.17.first_name',
#  'data.ref.authors.17.last_name',
#  'data.ref.authors.17.name',
#  'data.ref.authors.18.first_name',
#  'data.ref.authors.18.last_name',
#  'data.ref.authors.18.name',
#  'data.ref.authors.19.first_name',
#  'data.ref.authors.19.last_name',
#  'data.ref.authors.19.name',
#  'data.ref.authors.2.first_name',
#  'data.ref.authors.2.last_name',
#  'data.ref.authors.2.name',
#  'data.ref.authors.20.first_name',
#  'data.ref.authors.20.last_name',
#  'data.ref.authors.20.name',
#  'data.ref.authors.21.first_name',
#  'data.ref.authors.21.last_name',
#  'data.ref.authors.21.name',
#  'data.ref.authors.22.first_name',
#  'data.ref.authors.22.last_name',
#  'data.ref.authors.22.name',
#  'data.ref.authors.23.first_name',
#  'data.ref.authors.23.last_name',
#  'data.ref.authors.23.name',
#  'data.ref.authors.24.first_name',
#  'data.ref.authors.24.last_name',
#  'data.ref.authors.24.name',
#  'data.ref.authors.25.first_name',
#  'data.ref.authors.25.last_name',
#  'data.ref.authors.25.name',
#  'data.ref.authors.26.first_name',
#  'data.ref.authors.26.last_name',
#  'data.ref.authors.26.name',
#  'data.ref.authors.27.first_name',
#  'data.ref.authors.27.last_name',
#  'data.ref.authors.27.name',
#  'data.ref.authors.28.first_name',
#  'data.ref.authors.28.last_name',
#  'data.ref.authors.28.name',
#  'data.ref.authors.29.first_name',
#  'data.ref.authors.29.last_name',
#  'data.ref.authors.29.name',
#  'data.ref.authors.3.first_name',
#  'data.ref.authors.3.last_name',
#  'data.ref.authors.3.name',
#  'data.ref.authors.30.first_name',
#  'data.ref.authors.30.last_name',
#  'data.ref.authors.30.name',
#  'data.ref.authors.31.first_name',
#  'data.ref.authors.31.last_name',
#  'data.ref.authors.31.name',
#  'data.ref.authors.32.first_name',
#  'data.ref.authors.32.last_name',
#  'data.ref.authors.32.name',
#  'data.ref.authors.33.first_name',
#  'data.ref.authors.33.last_name',
#  'data.ref.authors.33.name',
#  'data.ref.authors.34.first_name',
#  'data.ref.authors.34.last_name',
#  'data.ref.authors.34.name',
#  'data.ref.authors.35.first_name',
#  'data.ref.authors.35.last_name',
#  'data.ref.authors.35.name',
#  'data.ref.authors.36.first_name',
#  'data.ref.authors.36.last_name',
#  'data.ref.authors.36.name',
#  'data.ref.authors.37.first_name',
#  'data.ref.authors.37.last_name',
#  'data.ref.authors.37.name',
#  'data.ref.authors.38.first_name',
#  'data.ref.authors.38.last_name',
#  'data.ref.authors.38.name',
#  'data.ref.authors.39.first_name',
#  'data.ref.authors.39.last_name',
#  'data.ref.authors.39.name',
#  'data.ref.authors.4.first_name',
#  'data.ref.authors.4.last_name',
#  'data.ref.authors.4.name',
#  'data.ref.authors.5.first_name',
#  'data.ref.authors.5.last_name',
#  'data.ref.authors.5.name',
#  'data.ref.authors.6.first_name',
#  'data.ref.authors.6.last_name',
#  'data.ref.authors.6.name',
#  'data.ref.authors.7.first_name',
#  'data.ref.authors.7.last_name',
#  'data.ref.authors.7.name',
#  'data.ref.authors.8.first_name',
#  'data.ref.authors.8.last_name',
#  'data.ref.authors.8.name',
#  'data.ref.authors.9.first_name',
#  'data.ref.authors.9.last_name',
#  'data.ref.authors.9.name',
#  'data.ref.data_entered_by_author',
#  'data.ref.extraction_method',
#  'data.ref.free_text_comment',
#  'data.ref.internal_sample_id',
#  'data.ref.journal',
#  'data.ref.lead_author',
#  'data.ref.name_of_person_entering_the_data',
#  'data.ref.original_filename_data_upload',
#  'data.ref.part_of_initial_dataset',
#  'data.ref.publication_date',
#  'data.stabilised.performance_Jmp',
#  'data.stabilised.performance_PCE',
#  'data.stabilised.performance_Vmp',
#  'data.stabilised.performance_link_raw_data',
#  'data.stabilised.performance_measured',
#  'data.stabilised.performance_measurement_time',
#  'data.stabilised.performance_procedure',
#  'data.stabilised.performance_procedure_metrics',
#  'data.stability.PCE_T80',
#  'data.stability.PCE_T95',
#  'data.stability.PCE_Te80',
#  'data.stability.PCE_Ts80',
#  'data.stability.PCE_Ts95',
#  'data.stability.PCE_Tse80',
#  'data.stability.PCE_after_1000_h',
#  'data.stability.PCE_burn_in_observed',
#  'data.stability.PCE_end_of_experiment',
#  'data.stability.PCE_initial_value',
#  'data.stability.atmosphere',
#  'data.stability.atmosphere_oxygen_concentration',
#  'data.stability.average_over_n_number_of_cells',
#  'data.stability.flexible_cell_PCE_end_of_experiment',
#  'data.stability.flexible_cell_PCE_initial_value',
#  'data.stability.flexible_cell_bending_radius',
#  'data.stability.flexible_cell_number_of_bending_cycles',
#  'data.stability.light_UV_filter',
#  'data.stability.light_cycling_times',
#  'data.stability.light_illumination_direction',
#  'data.stability.light_intensity',
#  'data.stability.light_load_condition',
#  'data.stability.light_source_brand_name',
#  'data.stability.light_source_simulator_class',
#  'data.stability.light_source_type',
#  'data.stability.light_spectra',
#  'data.stability.light_wavelength_range',
#  'data.stability.link_raw_data_for_stability_trace',
#  'data.stability.measured',
#  'data.stability.periodic_JV_measurements',
#  'data.stability.periodic_JV_measurements_time_between_jv',
#  'data.stability.potential_bias_load_condition',
#  'data.stability.potential_bias_passive_resistance',
#  'data.stability.potential_bias_range',
#  'data.stability.protocol',
#  'data.stability.relative_humidity_average_value',
#  'data.stability.relative_humidity_load_conditions',
#  'data.stability.relative_humidity_range',
#  'data.stability.temperature_cycling_times',
#  'data.stability.temperature_load_condition',
#  'data.stability.temperature_range',
#  'data.stability.time_total_exposure',
#  'data.substrate.area',
#  'data.substrate.brand_name',
#  'data.substrate.cleaning_procedure',
#  'data.substrate.deposition_procedure',
#  'data.substrate.etching_procedure',
#  'data.substrate.stack_sequence',
#  'data.substrate.supplier',
#  'data.substrate.thickness',
#  'results.material.chemical_formula_anonymous',
#  'results.material.chemical_formula_descriptive',
#  'results.material.chemical_formula_hill',
#  'results.material.chemical_formula_iupac',
#  'results.material.chemical_formula_reduced',
#  'results.material.dimensionality',
#  'results.material.elemental_composition.0.atomic_fraction',
#  'results.material.elemental_composition.0.element',
#  'results.material.elemental_composition.0.mass',
#  'results.material.elemental_composition.0.mass_fraction',
#  'results.material.elemental_composition.1.atomic_fraction',
#  'results.material.elemental_composition.1.element',
#  'results.material.elemental_composition.1.mass',
#  'results.material.elemental_composition.1.mass_fraction',
#  'results.material.elemental_composition.2.atomic_fraction',
#  'results.material.elemental_composition.2.element',
#  'results.material.elemental_composition.2.mass',
#  'results.material.elemental_composition.2.mass_fraction',
#  'results.material.elemental_composition.3.atomic_fraction',
#  'results.material.elemental_composition.3.element',
#  'results.material.elemental_composition.3.mass',
#  'results.material.elemental_composition.3.mass_fraction',
#  'results.material.elemental_composition.4.atomic_fraction',
#  'results.material.elemental_composition.4.element',
#  'results.material.elemental_composition.4.mass',
#  'results.material.elemental_composition.4.mass_fraction',
#  'results.material.elemental_composition.5.atomic_fraction',
#  'results.material.elemental_composition.5.element',
#  'results.material.elemental_composition.5.mass',
#  'results.material.elemental_composition.5.mass_fraction',
#  'results.material.elemental_composition.6.atomic_fraction',
#  'results.material.elemental_composition.6.element',
#  'results.material.elemental_composition.6.mass',
#  'results.material.elemental_composition.6.mass_fraction',
#  'results.material.elemental_composition.7.atomic_fraction',
#  'results.material.elemental_composition.7.element',
#  'results.material.elemental_composition.7.mass',
#  'results.material.elemental_composition.7.mass_fraction',
#  'results.material.elemental_composition.8.atomic_fraction',
#  'results.material.elemental_composition.8.element',
#  'results.material.elemental_composition.8.mass',
#  'results.material.elemental_composition.8.mass_fraction',
#  'results.material.elements',
#  'results.material.functional_type',
#  'results.material.structural_type',
#  'results.material.symmetry.structure_name',
#  'results.material.topology.0.chemical_formula_hill',
#  'results.material.topology.0.chemical_formula_iupac',
#  'results.material.topology.0.child_systems',
#  'results.material.topology.0.description',
#  'results.material.topology.0.elements',
#  'results.material.topology.0.label',
#  'results.material.topology.0.structural_type',
#  'results.material.topology.0.system_id',
#  'results.material.topology.0.system_relation.type',
#  'results.material.topology.1.atoms.atomic_numbers',
#  'results.material.topology.1.atoms.labels',
#  'results.material.topology.1.atoms.lattice_vectors',
#  'results.material.topology.1.atoms.m_def',
#  'results.material.topology.1.atoms.periodic',
#  'results.material.topology.1.atoms.positions',
#  'results.material.topology.1.atoms.species',
#  ...]

# %%
material_normalization = {
    # Spiro-OMeTAD variants
    'Spiro-MeOTAD': 'Spiro-OMeTAD',
    'Spiro-OMETAD': 'Spiro-OMeTAD',
    'Spiro-oMeTAD': 'Spiro-OMeTAD',
    'spiro-OMeTAD': 'Spiro-OMeTAD',
    'spiro-MeOTAD': 'Spiro-OMeTAD',
    
    # PCBM variants
    'PCBM-60': 'PCBM',
    'PCBM60': 'PCBM',
    'PC60BM': 'PCBM',
    'PC61BM': 'PCBM',
    
    # PEDOT:PSS variants
    'PEDOT-PSS': 'PEDOT:PSS',
    'PEDOT/PSS': 'PEDOT:PSS',
    'PEDOT PSS': 'PEDOT:PSS',
}

def normalize_materials(material_array, norm_dict):
    if not isinstance(material_array, np.ndarray):
        return material_array
    return np.array([norm_dict.get(m, m) for m in material_array])

print("Normalizing material names...")
for col in ['results.properties.optoelectronic.solar_cell.hole_transport_layer',
            'results.properties.optoelectronic.solar_cell.electron_transport_layer',
            'results.properties.optoelectronic.solar_cell.device_stack',
            'results.properties.optoelectronic.solar_cell.absorber']:
    df[col] = df[col].apply(lambda x: normalize_materials(x, material_normalization))

print("Normalization complete.")
# Out:
# Normalizing material names...
# Normalization complete.

# %%
def filter_theory_papers(df, text_column='data.ref.free_text_comment'):
    theory_keywords = [
        r'\bDFT\b', r'\bSCAPS\b', r'\bSCAPS-1D\b', r'density functional', r'first.?principles', 
        r'ab.?initio', r'molecular dynamics', r'\bMD\b simulation', r'VASP', r'Gaussian', 
        r'Quantum ESPRESSO', r'CASTEP', r'SIESTA', r'computational study', r'theoretical study', 
        r'theoretical investigation', r'numerical simulation', r'device simulation', 
        r'theoretical analysis', r'computational analysis', r'theoretical modeling', 
        r'computational modeling', r'simulated', r'simulation of', r'wxAMPS', r'AMPS-1D', 
        r'PC1D', r'AFORS-HET', r'theoretical optimization', r'computational optimization',
        r'simulated performance', r'theoretical efficiency', r'predicted efficiency',
    ]
    pattern = '|'.join(theory_keywords)
    if text_column not in df.columns: return df, pd.Series(False, index=df.index)
    theory_mask = df[text_column].fillna('').str.contains(pattern, case=False, regex=True, na=False)
    return df[~theory_mask].copy(), theory_mask

# %%
def filter_non_solar_cell_papers(df, text_column='data.ref.free_text_comment'):
    if text_column not in df.columns: return df, pd.Series(False, index=df.index)
    def extract_title(text):
        if pd.isna(text) or 'Publication title:' not in str(text): return ''
        try: return text.split('Publication title:')[1].split(',')[0].strip().lower()
        except: return str(text).lower()
    titles = df[text_column].apply(extract_title)
    non_solar_keywords = {
        'LED': [r'\bLED\b', r'light.?emitting diode', r'electroluminescen'],
        'Battery': [r'\bbattery\b', r'energy storage', r'rechargeable'],
        'Photodetector': [r'photodetector', r'X.?ray detector'],
        'Catalyst': [r'catalys', r'water splitting', r'hydrogen evolution'],
        'Other': [r'sensor', r'transistor', r'laser', r'memory', r'thermoelectric', r'capacitor']
    }
    solar_cell_keywords = [r'solar cell', r'photovoltaic', r'\bPV\b', r'\bPSC\b', r'\bPCE\b']
    non_solar_mask = pd.Series(False, index=df.index)
    for patterns in non_solar_keywords.values():
        non_solar_mask |= titles.str.contains('|'.join(patterns), case=False, regex=True, na=False)
    is_solar_cell = titles.str.contains('|'.join(solar_cell_keywords), case=False, regex=True, na=False)
    final_mask = non_solar_mask & ~is_solar_cell
    return df[~final_mask].copy(), final_mask

# %%
def filter_review_articles(df, text_column='data.ref.free_text_comment'):
    if text_column not in df.columns: return df, pd.Series(False, index=df.index)
    def extract_title(text):
        if pd.isna(text) or 'Publication title:' not in str(text): return ''
        try: return text.split('Publication title:')[1].split(',')[0].strip()
        except: return ''
    titles = df[text_column].apply(extract_title)
    review_patterns = [
        r'^Review\b', r'^Perspective\b', r'^Overview\b', r'^Outlook\b', r'^Minireview\b',
        r'^Critical [Rr]eview\b', r': [Aa] [Rr]eview\b', r': [Aa] [Pp]erspective\b',
        r'\b[Rr]eview of\b', r'\b[Rr]eview on\b', r'^Progress in\b', r'^Recent [Aa]dvances\b',
        r'^Advances in\b', r'^State of the art\b', r'^Current status\b'
    ]
    pattern = '|'.join(review_patterns)
    review_mask = titles.str.contains(pattern, case=False, regex=True, na=False)
    return df[~review_mask].copy(), review_mask

# %%
def filter_experimental_solar_cells(df, text_column='data.ref.free_text_comment', verbose=True):
    df_step1, theory_mask = filter_theory_papers(df, text_column)
    df_step2, non_solar_mask = filter_non_solar_cell_papers(df_step1, text_column)
    df_step3, review_mask = filter_review_articles(df_step2, text_column)
    if verbose:
        print("="*70)
        print("FILTERING SUMMARY")
        print("="*70)
        print(f"Original entries:              {len(df):,}")
        print(f"Theory papers removed:         {theory_mask.sum():,}")
        print(f"Non-solar cell papers removed: {non_solar_mask.sum():,}")
        print(f"Review articles removed:       {review_mask.sum():,}")
        print(f"Total filtered out:            {theory_mask.sum() + non_solar_mask.sum() + review_mask.sum():,}")
        print(f"Experimental research papers:  {len(df_step3):,}")
        print("="*70)
    return df_step3

# %%
def cleanup_material_morphology(df, columns_to_clean):
    """
    Cleans material names by removing morphological/processing affixes.

    This function strips common prefixes (c-, mp-), suffixes (-c, -mp, -np),
    and descriptors like dopants (:F4-TCNQ), additives (w/ TBP), and
    formulations (QDs) to leave only the core chemical composition.

    Parameters:
    -----------
    df : pandas.DataFrame
        Input dataframe.
    columns_to_clean : list of str
        A list of column names containing material arrays to be cleaned.

    Returns:
    --------
    df_cleaned : pandas.DataFrame
        A new dataframe with the specified columns cleaned.
    """
    df_cleaned = df.copy()

    def clean_single_material(name):
        if not isinstance(name, str):
            return name
        
        # Remove common suffixes like -c, -mp, -np, -bl, etc.
        cleaned_name = re.sub(r'-[a-zA-Z]+$', '', name)
        # Remove common prefixes like c-, mp-
        cleaned_name = re.sub(r'^[a-z]+-', '', cleaned_name)
        # Remove dopants and additives specified with ":"
        cleaned_name = re.sub(r':.*', '', cleaned_name)
        # Remove additives specified with "w/"
        cleaned_name = re.sub(r'\s*w/.*', '', cleaned_name)
        # Remove anything in parentheses (e.g., treatments)
        cleaned_name = re.sub(r'\s*\(.*\)$', '', cleaned_name)
        # Remove "QDs" or "QD"
        cleaned_name = re.sub(r'\s*QDs?$', '', cleaned_name)
        # Remove "mesoporous layer" and similar descriptors
        cleaned_name = re.sub(r'\s*mesoporous.*', '', cleaned_name)
        
        return cleaned_name.strip()

    def clean_material_array(material_array):
        if not isinstance(material_array, np.ndarray):
            return material_array
        return np.array([clean_single_material(m) for m in material_array])

    print("Cleaning material names to core compositions...")
    for col in columns_to_clean:
        if col in df_cleaned.columns:
            df_cleaned[col] = df_cleaned[col].apply(clean_material_array)
            print(f"  - Column '{col}' cleaned.")
    
    return df_cleaned

columns_to_process = [
    'results.properties.optoelectronic.solar_cell.hole_transport_layer',
    'results.properties.optoelectronic.solar_cell.electron_transport_layer',
    'results.properties.optoelectronic.solar_cell.device_stack'
]
df_composition = cleanup_material_morphology(df, columns_to_process)
# Out:
# Cleaning material names to core compositions...
#   - Column 'results.properties.optoelectronic.solar_cell.hole_transport_layer' cleaned.
#   - Column 'results.properties.optoelectronic.solar_cell.electron_transport_layer' cleaned.
#   - Column 'results.properties.optoelectronic.solar_cell.device_stack' cleaned.

# %%
df_composition['results.properties.optoelectronic.solar_cell.hole_transport_layer'].value_counts()
# Out:
# results.properties.optoelectronic.solar_cell.hole_transport_layer
# [Spiro]              25197
# [PEDOT]               7523
# [PTAA]                2618
# [none]                2599
# [NiO]                 2343
#                      ...
# [Spiro, MoOx]            1
# [Graphene, Spiro]        1
# [C60, BCP]               1
# [NiOx, PTAA]             1
# [TPDCN]                  1
# Name: count, Length: 4015, dtype: int64

# %%
df['results.properties.optoelectronic.solar_cell.hole_transport_layer'].value_counts()
# Out:
# results.properties.optoelectronic.solar_cell.hole_transport_layer
# [Spiro-OMeTAD]               25138
# [PEDOT:PSS]                   7374
# [none]                        2599
# [PTAA]                        2564
# [NiO-c]                       1661
#                              ...
# [Pt-np]                          1
# [CsPbI3-QD, Spiro-OMeTAD]        1
# [PEDOT:PSS, PTAA]                1
# [D18-Cl, Cl-2PACz]               1
# [TPDCN]                          1
# Name: count, Length: 4373, dtype: int64

# %%
df_clean = filter_experimental_solar_cells(df_composition)

# Final data preparation steps
df_clean['pub_year'] = pd.to_datetime(df_clean['data.ref.publication_date']).dt.year
df_clean['extraction_method'] = df_clean['data.ref.extraction_method'].fillna('Old')

def get_stack_length(stack):
    if not isinstance(stack, np.ndarray):
        return np.nan
    return len([s for s in stack if s != 'SLG'])

df_clean['stack_length'] = df_clean['results.properties.optoelectronic.solar_cell.device_stack'].apply(get_stack_length)
# Out:
# ======================================================================
# FILTERING SUMMARY
# ======================================================================
# Original entries:              53,238
# Theory papers removed:         517
# Non-solar cell papers removed: 26
# Review articles removed:       95
# Total filtered out:            638
# Experimental research papers:  52,600
# ======================================================================

# %%
print(len(df_clean[df_clean['extraction_method']=='Old']), "entries extracted with old method.")
print(len(df_clean[df_clean['extraction_method']=='LLM']), "entries extracted with LLM")
# Out:
# 42777 entries extracted with old method.
# 9823 entries extracted with LLM

# %%
nip_data = df_clean[df_clean['results.properties.optoelectronic.solar_cell.device_architecture'] == 'nip']
pin_data = df_clean[df_clean['results.properties.optoelectronic.solar_cell.device_architecture'] == 'pin']

# Group by year and calculate statistics
nip_by_year = nip_data.groupby('pub_year')['stack_length'].agg(['mean', 'std', 'count']).reset_index()
pin_by_year = pin_data.groupby('pub_year')['stack_length'].agg(['mean', 'std', 'count']).reset_index()

# Apply rolling window smoothing (2-year window, centered)
window_size = 2
nip_by_year['mean_smooth'] = nip_by_year['mean'].rolling(window=window_size, center=True, min_periods=1).mean()
pin_by_year['mean_smooth'] = pin_by_year['mean'].rolling(window=window_size, center=True, min_periods=1).mean()

# Calculate regression lines
nip_slope, nip_intercept, nip_r, nip_p, _ = stats.linregress(nip_by_year['pub_year'], nip_by_year['mean'])
pin_slope, pin_intercept, pin_r, pin_p, _ = stats.linregress(pin_by_year['pub_year'], pin_by_year['mean'])

nip_by_year['regression'] = nip_slope * nip_by_year['pub_year'] + nip_intercept
pin_by_year['regression'] = pin_slope * pin_by_year['pub_year'] + pin_intercept

# Create plotly figure
fig = go.Figure()
fig.update_layout(
    autosize=False,
    width=SINGLE_COLUMN_PX,
    height=SINGLE_COLUMN_PX /3  ,
)

# Add NIP smoothed line
fig.add_trace(go.Scatter(
    x=nip_by_year['pub_year'],
    y=nip_by_year['mean_smooth'],
    mode='lines+markers',
    name='NIP (simplifying)',
    line=dict(color='#2E86AB', width=2),
    marker=dict(size=4),
    hovertemplate='<b>NIP</b><br>Year: %{x}<br>Avg Stack Length: %{y:.2f}<extra></extra>'
))

# Add raw data points (smaller, transparent)
fig.add_trace(go.Scatter(
    x=nip_by_year['pub_year'],
    y=nip_by_year['mean'],
    mode='markers',
    name='NIP (raw)',
    marker=dict(size=2, color='#2E86AB', opacity=0.3),
    showlegend=False,
    hovertemplate='<b>NIP (raw)</b><br>Year: %{x}<br>Avg: %{y:.2f}<extra></extra>'
))

# Add regression line
fig.add_trace(go.Scatter(
    x=nip_by_year['pub_year'],
    y=nip_by_year['regression'],
    mode='lines',
    name='NIP trend',      
    line=dict(color='#145374', width=1.5, dash='dash'),
    opacity=0.6,
    showlegend=False,
))

# Add PIN smoothed line
fig.add_trace(go.Scatter(
    x=pin_by_year['pub_year'],
    y=pin_by_year['mean_smooth'],
    mode='lines+markers',
    name='PIN (complexifying)',
    line=dict(color='#F26419', width=2),
    marker=dict(size=4),
    hovertemplate='<b>PIN</b><br>Year: %{x}<br>Avg Stack Length: %{y:.2f}<extra></extra>'
))

# Add raw data points (smaller, transparent)
fig.add_trace(go.Scatter(
    x=pin_by_year['pub_year'],
    y=pin_by_year['mean'],
    mode='markers',
    name='PIN (raw)',
    marker=dict(size=2, color='#F26419', opacity=0.3),
    showlegend=False,
    hovertemplate='<b>PIN (raw)</b><br>Year: %{x}<br>Avg: %{y:.2f}<extra></extra>'
))

# Add regression line
fig.add_trace(go.Scatter(
    x=pin_by_year['pub_year'],
    y=pin_by_year['regression'],
    mode='lines',
    name='PIN trend',      
    line=dict(color='#9C2A00', width=1.5, dash='dash'),
    opacity=0.6,
    showlegend=False,
))

# Update layout
fig.update_layout(
    xaxis_title='Publication Year',
    yaxis_title='Average Device Stack Length',
)

fig.show()

# %%
# plot fraction of NIP/PIN over year

fig = go.Figure()
fig.update_layout(
    autosize=False,
    width=SINGLE_COLUMN_PX,
    height=SINGLE_COLUMN_PX/3,
)

relative_nip = nip_by_year['count'] / (nip_by_year['count'] + pin_by_year['count'])

fig.add_trace(go.Scatter(
    x=nip_by_year['pub_year'],
    y=relative_nip,
    mode='lines+markers',
    name='NIP',
    line=dict(color='#2E86AB', width=3),
    marker=dict(size=8, symbol='circle'),
    hovertemplate='<b>Relative NIP Fraction</b><br>Year: %{x}<br>Fraction: %{y:.2f}<extra></extra>'
))

relative_pin= pin_by_year['count'] / (nip_by_year['count'] + pin_by_year['count'])
fig.add_trace(go.Scatter(
    x=pin_by_year['pub_year'],
    y=relative_pin,
    mode='lines+markers',
    name='PIN',
    line=dict(color='#F26419', width=3),
    marker=dict(size=8, symbol='square'),
    hovertemplate='<b>Relative PIN Fraction</b><br>Year: %{x}<br>Fraction: %{y:.2f}<extra></extra>'
))


fig.update_layout(
    xaxis_title='Publication Year',
    yaxis_title='Relative Fraction',
)

# %%
# plot relative ratios of ETL/HTL materials over time
